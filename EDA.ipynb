# %%
# coding:u8
import json

# %%
ls data/
# Out:
# features.pkl  raw_data/

# %%
train_data = []
with open('data/raw_data/train.json','r') as f:
    for line in f:
        train_data.append(json.loads(line))

# %%
# 有效　mention　个数
for i in range(10):
    c = 0
    for item in train_data[i*10000:(i+1)*10000]:
        for m in item['mention_data']:
            if m['kb_id']!='NIL':
                c+=1
    print(c)
# Out:
# 28530
# 28919
# 28256
# 28440
# 28446
# 28678
# 28710
# 28586
# 28513
# 0

# %%
train_data[303]
# Out:
# {'text_id': '304',
#  'text': '【古月哥欠】英雄赞歌---祭戴涛《四十九日祭》_胡歌吧...',
#  'mention_data': [{'kb_id': '37646', 'mention': '古月哥欠', 'offset': '1'},
#   {'kb_id': '79058', 'mention': '英雄赞歌', 'offset': '6'},
#   {'kb_id': '37885', 'mention': '祭', 'offset': '13'},
#   {'kb_id': '238546', 'mention': '戴涛', 'offset': '14'},
#   {'kb_id': '314370', 'mention': '四十九日祭', 'offset': '17'},
#   {'kb_id': '37646', 'mention': '胡歌', 'offset': '24'}]}

# %%
kb['375989']
# Out:
# {'alias': ['戴少校', '戴涛'],
#  'subject_id': '375989',
#  'subject': '戴涛',
#  'type': ['FictionalHuman'],
#  'data': [{'predicate': '摘要',
#    'object': '戴涛是小说《金陵十三钗》中人物，在由小说改编的电视剧《四十九日·祭》中，由胡歌饰演。电影《金陵十三钗》中的李教官是以戴涛为创作蓝本。原著身份是国军七十三师二团团副，二十九岁的少校。家有一子。电视剧身份是国军教导总队督导队少尉。'},
#   {'predicate': '军阶', 'object': '少校(原著)，少尉(电视剧)'},
#   {'predicate': '饰演', 'object': '胡歌'},
#   {'predicate': '其他名称', 'object': '戴少校'},
#   {'predicate': '红粉知己', 'object': '赵玉墨'},
#   {'predicate': '中文名', 'object': '戴涛'},
#   {'predicate': '登场作品', 'object': '小说《金陵十三钗》，电视剧《四十九日·祭》'},
#   {'predicate': '配音', 'object': '姜广涛'},
#   {'predicate': '年龄', 'object': '29(原著)'},
#   {'predicate': '性别', 'object': '男'},
#   {'predicate': '义项描述', 'object': '小说《金陵十三钗》中人物'},
#   {'predicate': '标签', 'object': '艺术作品'},
#   {'predicate': '标签', 'object': '文化'}]}

# %%
kb['105944']
# Out:
# {'alias': ['璧君', '君儿', '小姐', '沈大小姐', '夫人', '沈璧君'],
#  'subject_id': '105944',
#  'subject': '沈璧君',
#  'type': ['FictionalHuman'],
#  'data': [{'predicate': '摘要',
#    'object': '沈璧君，2014年鞠觉亮、黄祖权执导的电视剧《新萧十一郎》中的女主角，由甘婷婷饰演。'},
#   {'predicate': '情敌', 'object': '风四娘、小公子、无霜、花如玉'},
#   {'predicate': '婆婆', 'object': '双钩莲花白红莲(连城璧之母)'},
#   {'predicate': '称号', 'object': '武林第一美人'},
#   {'predicate': '饰演', 'object': '甘婷婷'},
#   {'predicate': '其他名称', 'object': '璧君、君儿、小姐、沈大小姐、夫人'},
#   {'predicate': '公公', 'object': '连泽天(连城璧之父)'},
#   {'predicate': '父亲', 'object': '沈劲风'},
#   {'predicate': '中文名', 'object': '沈璧君'},
#   {'predicate': '武功', 'object': '沈家金针、走火入魔后的阴毒武功'},
#   {'predicate': '贴身丫鬟', 'object': '无霜(冰冰)'},
#   {'predicate': '登场作品', 'object': '新萧十一郎'},
#   {'predicate': '居住地', 'object': '沈家庄、无垢山庄'},
#   {'predicate': '好友', 'object': '风四娘、杨开泰'},
#   {'predicate': '配音', 'object': '季冠霖'},
#   {'predicate': '母亲', 'object': '沈飞云(武林盟主)'},
#   {'predicate': '丈夫、挚爱', 'object': '连城璧(失忆后)'},
#   {'predicate': '恋人', 'object': '萧十一郎(失忆前)'},
#   {'predicate': '结局', 'object': '为萧十一郎挡下割鹿刀而死'},
#   {'predicate': '性别', 'object': '女'},
#   {'predicate': '身份', 'object': '沈家千金、无垢山庄庄主夫人'},
#   {'predicate': '义项描述', 'object': '2014年电视剧《新萧十一郎》女主角'}]}

# %%
print('训练数据长度',len(train_data))
# Out:
# 训练数据长度 90000

# %%
# 读取知识库
kb_data = []
kb = {}
with open('data/raw_data/kb_data','r') as f:
    for line in f:
        item = json.loads(line)
        kb[item['subject_id']] = item
        kb_data.append(item)

# %%
kb['341467']
# Out:
# {'alias': ['感情'],
#  'subject_id': '341467',
#  'subject': '感情',
#  'type': ['Vocabulary'],
#  'data': [{'predicate': '摘要',
#    'object': '感情解释：1.对外界刺激的比较强烈的心理反应、动作流露。2.对人或事物关切、喜爱或厌恶的心情。'},
#   {'predicate': '外文名',
#    'object': 'emotion；sensation；affection；feeling；sentiment'},
#   {'predicate': '含义', 'object': '感情解释'},
#   {'predicate': '拼音', 'object': 'gǎnqíng'},
#   {'predicate': '中文名', 'object': '感情'},
#   {'predicate': '义项描述', 'object': '词语'},
#   {'predicate': '标签', 'object': '科学百科心理学分类'},
#   {'predicate': '标签', 'object': '学科'},
#   {'predicate': '标签', 'object': '文化活动'},
#   {'predicate': '标签', 'object': '文化'}]}

# %%
print('知识库实体个数%d'%len(kb_data))
# Out:
# 知识库实体个数399252

# %%
kb_data[0:3]
# Out:
# [{'alias': ['胜利'],
#   'subject_id': '10001',
#   'subject': '胜利',
#   'type': ['Thing'],
#   'data': [{'predicate': '摘要',
#     'object': '英雄联盟胜利系列皮肤是拳头公司制作的具有纪念意义限定系列皮肤之一。拳头公司制作的具有纪念意义限定系列皮肤还包括英雄联盟冠军系列皮肤、MSI季中冠军赛征服者系列以及英雄联盟全球总决赛冠军系列皮肤。每到赛季结束时，拳头公司都会制作胜利系列皮肤作为赛季奖励来认可那些在排位赛中勇猛拼搏达到黄金段位的玩家。'},
#    {'predicate': '制作方', 'object': 'Riot Games'},
#    {'predicate': '外文名', 'object': 'Victorious'},
#    {'predicate': '来源', 'object': '英雄联盟'},
#    {'predicate': '中文名', 'object': '胜利'},
#    {'predicate': '属性', 'object': '虚拟'},
#    {'predicate': '义项描述', 'object': '游戏《英雄联盟》胜利系列限定皮肤'}]},
#  {'alias': ['张三的歌'],
#   'subject_id': '10002',
#   'subject': '张三的歌',
#   'type': ['CreativeWork'],
#   'data': [{'predicate': '摘要',
#     'object': '《张三的歌》这首经典老歌，词曲作者是张子石。最早收录于李寿全的专辑《8又二分之一》当中。李寿全作为台湾民谣时代的推动人，在80年代中后期有着举足轻重的地位，而这首《张三的歌》出现在当时的背景之下，带来了无可比拟的社会效应，也为那个年代留下了无法抹去的回忆。随着时间的推移，陈翔、齐秦、吴宗宪、蔡琴、青鸟飞鱼等歌手都曾翻唱过。'},
#    {'predicate': '歌曲原唱', 'object': '李寿全'},
#    {'predicate': '谱曲', 'object': '张子石'},
#    {'predicate': '歌曲时长', 'object': '3分58秒'},
#    {'predicate': '歌曲语言', 'object': '普通话'},
#    {'predicate': '音乐风格', 'object': '民谣'},
#    {'predicate': '唱片公司', 'object': '飞碟唱片'},
#    {'predicate': '翻唱', 'object': '齐秦、苏芮、南方二重唱等'},
#    {'predicate': '填词', 'object': '张子石'},
#    {'predicate': '发行时间', 'object': '1986-08-01'},
#    {'predicate': '中文名称', 'object': '张三的歌'},
#    {'predicate': '所属专辑', 'object': '8又二分之一'},
#    {'predicate': '义项描述', 'object': '李寿全演唱歌曲'},
#    {'predicate': '标签', 'object': '单曲'},
#    {'predicate': '标签', 'object': '音乐作品'}]},
#  {'alias': ['七里香蔷薇', '七里香', 'Rosa banksiao R.Br', 'var.Normalis Regel'],
#   'subject_id': '10003',
#   'subject': '单瓣木香花',
#   'type': ['Plant'],
#   'data': [{'predicate': '摘要',
#     'object': '单瓣木香花为啬薇科植物单瓣木香花的根皮(俗称红根)。用于月经不调、月经过多、外伤红肿、瘀血作痛。'},
#    {'predicate': '亚目', 'object': '蔷薇亚目(Rosineae)'},
#    {'predicate': '别称', 'object': '七里香蔷薇、七里香(陕西)'},
#    {'predicate': '种', 'object': '单瓣木香花'},
#    {'predicate': '界', 'object': '植物界'},
#    {'predicate': '目', 'object': '蔷薇目(Rosales)'},
#    {'predicate': '科', 'object': '蔷薇科(Rosaceae)'},
#    {'predicate': '拉丁学名', 'object': 'Rosa banksiao R.Br， var.Normalis Regel.'},
#    {'predicate': '纲', 'object': '双子叶植物纲(Magnoliopsida)'},
#    {'predicate': '门', 'object': '被子植物门(Angiospermae)'},
#    {'predicate': '中文学名', 'object': '单瓣木香花'},
#    {'predicate': '亚科', 'object': '苹果亚科(Pomoideae或Maloideae)'},
#    {'predicate': '亚纲', 'object': '蔷薇亚纲(Rosidae)'},
#    {'predicate': '义项描述', 'object': '单瓣木香花'},
#    {'predicate': '标签', 'object': '生物物种'},
#    {'predicate': '标签', 'object': '植物'},
#    {'predicate': '标签', 'object': '中药'}]}]

# %%
# 统计标签类型
sign = {}
for item in kb_data:
    for p in item['data']:
        if p['predicate']=='标签':
            if p['object'] not in sign:
                sign[p['object']] = 1
            else:
                sign[p['object']] += 1

# %%
#结构化知识库
摘要，type,标签，属性信息

# %%
sign
# Out:
# {'单曲': 12549,
#  '音乐作品': 16059,
#  '生物物种': 5354,
#  '植物': 3423,
#  '中药': 851,
#  '政治人物': 15745,
#  '人物': 111013,
#  '将领': 874,
#  '娱乐': 17228,
#  '艺术家': 4879,
#  '书籍': 21265,
#  '小说作品': 8649,
#  '中国文学': 6277,
#  '文学作品': 12639,
#  '小说': 11058,
#  '地理': 5736,
#  '文化': 17798,
#  '文物考古': 410,
#  '景观景点': 982,
#  '建筑': 843,
#  '历史': 4359,
#  '行政区划': 2913,
#  '乡镇': 1519,
#  '官员': 7751,
#  '文学家': 814,
#  '文学': 3689,
#  '游泳': 79,
#  '体育人物': 3828,
#  '运动员': 3101,
#  '娱乐作品': 40436,
#  '电影作品': 17535,
#  '剧情电影': 10084,
#  '台湾电影': 161,
#  '行业人物': 31885,
#  '科研人员': 6381,
#  '教师': 11764,
#  '惊悚电影': 2965,
#  '电影': 22869,
#  '出版物': 12729,
#  '艺术书籍': 509,
#  '足球运动员': 2174,
#  '足球': 2341,
#  '香港电影': 946,
#  '流行音乐': 6800,
#  '文化人物': 1369,
#  '非科学': 167,
#  '组织机构': 4250,
#  '地形地貌': 904,
#  '山脉': 534,
#  '经济': 897,
#  '社会': 8350,
#  '医生': 3058,
#  '动作电影': 3136,
#  '爱情电影': 2794,
#  '人物传记': 4,
#  '喜剧电影': 2597,
#  '软件': 834,
#  '动漫形象': 3669,
#  '电视剧形象': 925,
#  '体育': 1383,
#  '科学': 4541,
#  '语言': 9968,
#  '成语': 1320,
#  '综艺节目': 950,
#  '情感节目': 49,
#  '游戏': 6634,
#  '网络小说': 3800,
#  '青春小说': 219,
#  '非娱乐作品': 511,
#  '动画': 2530,
#  '非足球': 2011,
#  '00年代电影': 239,
#  '韩国电影': 249,
#  '音乐': 10322,
#  '电视剧作品': 8570,
#  '古装剧': 1228,
#  '电视剧': 8701,
#  '科技产品': 1870,
#  '字词': 10999,
#  '村庄': 816,
#  '地点': 6590,
#  '足球教练': 51,
#  '教练': 178,
#  '科学百科航空航天分类': 61,
#  '大陆演员': 3713,
#  '演员': 8292,
#  '娱乐人物': 15710,
#  '歌手': 4011,
#  '言情小说': 1062,
#  '外国文学': 382,
#  '美国电影': 1030,
#  '文学形象': 1363,
#  '日本电影': 254,
#  '城市': 513,
#  '旅游': 1120,
#  '外国历史': 324,
#  '科学百科中医药分类': 269,
#  '漫画作品': 1300,
#  '漫画': 2091,
#  '自然现象': 185,
#  '自然': 3790,
#  '搞笑节目': 38,
#  '大陆节目': 294,
#  '犯罪电影': 1138,
#  '90年代电影': 292,
#  '恐怖电影': 277,
#  '剧情剧': 4934,
#  '恐怖剧': 272,
#  '搞笑剧': 912,
#  '犯罪剧': 640,
#  '动作剧': 744,
#  '历史人物': 1286,
#  '中国历史人物': 151,
#  '80年代演员': 902,
#  '经济人物': 2811,
#  '工程师': 827,
#  '文化活动': 708,
#  '舞蹈术语': 13,
#  '舞蹈': 286,
#  '科学百科数理科学分类': 163,
#  '教育': 1325,
#  '宗教人物': 794,
#  '中国力学学会': 74,
#  '娱乐设备': 84,
#  '文化用品': 66,
#  '曲艺': 589,
#  '医学书籍': 172,
#  '战争剧': 776,
#  '爱情剧': 1999,
#  '大陆剧': 215,
#  '台湾演员': 251,
#  '导演': 1035,
#  '学科': 1252,
#  '经济术语': 144,
#  '2012年电视剧': 82,
#  '80年代电影': 154,
#  '虚拟人物': 2604,
#  '动画作品': 1468,
#  '科幻小说': 149,
#  '科学百科生命科学分类': 810,
#  '菜品': 122,
#  '食品': 364,
#  '美剧': 97,
#  '疗法': 21,
#  '医学': 803,
#  '医学术语': 487,
#  '疾病': 529,
#  '60年代演员': 309,
#  '港剧': 179,
#  '学校': 1402,
#  '诗词': 1283,
#  '模特': 1160,
#  '生活': 2372,
#  '科学家': 800,
#  '哲学家': 73,
#  '考试书籍': 78,
#  '高中教师': 115,
#  '演出': 596,
#  '航空航天': 100,
#  '科研机构': 550,
#  '中国高校': 384,
#  '教育部隶属高校': 70,
#  '公办高校': 354,
#  '财经类高校': 29,
#  '本科高校': 349,
#  '北京高校': 42,
#  '211高校': 106,
#  '大学': 437,
#  '音乐人物': 849,
#  '经管书籍': 489,
#  '手机游戏': 779,
#  '游戏作品': 3682,
#  '棋牌游戏': 94,
#  '古代史': 986,
#  '非地理': 573,
#  '军事人物': 408,
#  '军事': 501,
#  '中国化工学会': 12,
#  '科幻电影': 1586,
#  '策略游戏': 331,
#  '网络游戏': 511,
#  '古典音乐': 139,
#  '草本植物': 71,
#  '天体': 95,
#  '美术作品': 148,
#  '美术': 753,
#  '品牌': 947,
#  '奖项': 127,
#  '日本演员': 150,
#  '动物': 1665,
#  '艺术作品': 1773,
#  '民族': 527,
#  '影视演员': 132,
#  '君主': 288,
#  '公文': 211,
#  '交通': 215,
#  '病毒': 72,
#  '网站': 2172,
#  '编剧': 432,
#  '互联网': 754,
#  '历史事件': 281,
#  '专辑': 2024,
#  '模拟游戏': 319,
#  '冒险游戏': 335,
#  '动作游戏': 493,
#  '科幻剧': 439,
#  '物理学家': 99,
#  '药品': 103,
#  '70年代演员': 396,
#  '电影形象': 241,
#  '民族音乐': 351,
#  '篮球': 459,
#  '戏剧': 1420,
#  '游戏形象': 1274,
#  '非体育': 422,
#  '医院': 291,
#  '烈士': 753,
#  '90年代电视剧': 153,
#  '益智游戏': 381,
#  '网页游戏': 842,
#  '教育学家': 204,
#  '话题人物': 601,
#  '恐怖小说': 148,
#  '体育其他': 859,
#  '公司': 1843,
#  '摄影': 204,
#  '益智 棋牌': 3,
#  '政治军事书籍': 246,
#  '街区路': 407,
#  '报纸': 283,
#  '2011年电影': 184,
#  '体育项目': 346,
#  '清朝': 236,
#  '大牌': 161,
#  '户外运动品牌': 23,
#  '服装鞋靴品牌': 22,
#  '中国品牌': 67,
#  '知名品牌': 130,
#  '科学百科心理学分类': 130,
#  '中国气象学会': 4,
#  '中国行政区划': 103,
#  '2014年电影': 191,
#  '中国其他行政区划': 146,
#  '中国心理学会': 59,
#  '楼盘': 143,
#  '台剧': 126,
#  '古生物': 69,
#  '政治': 400,
#  '贵族': 199,
#  '社会事件': 438,
#  '技术': 345,
#  '推理小说': 158,
#  '玄幻小说': 886,
#  '武侠小说': 193,
#  '工业书籍': 306,
#  '励志书籍': 262,
#  '角色扮演游戏': 716,
#  '娱乐术语': 355,
#  '数理科学': 23,
#  '文化术语': 1096,
#  '大陆电影': 243,
#  '股票传媒': 7,
#  '股票创业板': 5,
#  '股票名称': 130,
#  '社科书籍': 388,
#  '科学百科化学分类': 20,
#  '科技术语': 237,
#  '互联网产品': 415,
#  '医学家': 51,
#  '射击游戏': 293,
#  '大学教师': 518,
#  '香港演员': 312,
#  '大陆音乐人': 222,
#  '生活节目': 55,
#  '体育组织': 89,
#  '政治家': 3,
#  '皇帝': 1,
#  '汉朝': 1,
#  '制作人': 355,
#  '外国行政区划': 428,
#  '法律': 293,
#  '历史书籍': 351,
#  '水上项目': 33,
#  '动画电影': 447,
#  '2011年电视剧': 95,
#  '书法': 57,
#  '语言术语': 221,
#  '男': 71,
#  '战争': 314,
#  '科学百科工程技术分类': 213,
#  '社会团体': 393,
#  '足球俱乐部': 130,
#  '俱乐部': 139,
#  '化妆品': 110,
#  '手机': 145,
#  '韩剧': 221,
#  '宗教': 592,
#  '2013年电影': 195,
#  '鸟类': 86,
#  '二战': 137,
#  '二战影视作品': 45,
#  '历史著作': 304,
#  '美术家': 64,
#  '美国演员': 269,
#  '股票其他': 85,
#  '股票深市A股': 13,
#  '汽车': 72,
#  '影视作品': 608,
#  '英国电影': 233,
#  '乒乓球': 71,
#  '韩国演员': 195,
#  '非遗-非遗': 141,
#  '国家级-非遗': 130,
#  '传统戏剧-非遗': 57,
#  '60年代音乐人': 22,
#  '武器装备': 359,
#  '音乐节目': 60,
#  '会计师': 127,
#  '期刊': 703,
#  '演艺人物': 45,
#  '娱乐明星': 46,
#  '纪实节目': 258,
#  '工业产品': 106,
#  '虚拟物品': 209,
#  '90年代演员': 439,
#  '古诗': 45,
#  '词语': 62,
#  '信息科学': 126,
#  '中国通信学会': 143,
#  '2013年电视剧': 132,
#  '笔记本电脑': 9,
#  '外国历史事件': 55,
#  '摇滚音乐': 347,
#  '微生物': 45,
#  '文言文': 92,
#  '营业场所': 143,
#  '文化设施': 41,
#  '心理书籍': 113,
#  '教育机构': 56,
#  '神话人物': 241,
#  '旅游机构': 17,
#  '自然地理': 314,
#  '中国大学': 499,
#  '篮球运动员': 28,
#  '科技': 91,
#  '中国电子学会': 96,
#  '保健书籍': 68,
#  '互联网人物': 237,
#  '生物学家': 55,
#  '作家': 93,
#  '编曲': 69,
#  '2014年电视剧': 104,
#  '交通线路': 90,
#  '00年代音乐人': 52,
#  '水利部发展研究中心': 48,
#  '河流': 90,
#  '生物学': 108,
#  '政府机构': 163,
#  '外国大学': 152,
#  '木本植物': 89,
#  '社会活动': 447,
#  '物理学': 49,
#  '法律术语': 238,
#  '家具': 41,
#  '00后演员': 12,
#  '悬疑剧': 114,
#  '中国历史事件': 36,
#  '泰国演员': 35,
#  '泰剧': 105,
#  '非生物': 219,
#  '书画家': 9,
#  '泰国电影': 64,
#  '海盗': 1,
#  '曲艺-非遗': 23,
#  '文学作品(202)': 12,
#  '科学百科信息科学分类': 160,
#  '穿越小说': 184,
#  '近代史': 225,
#  '交通工具': 104,
#  '计算机书籍': 158,
#  '公园': 191,
#  '交通术语': 8,
#  '车站': 82,
#  '交通设施': 108,
#  '网球': 64,
#  '科学百科天文学分类': 78,
#  '操作系统': 1,
#  '日剧': 192,
#  '体育赛事': 152,
#  '散文': 107,
#  '画家': 17,
#  '通信技术': 84,
#  '宠物': 200,
#  '中学': 89,
#  '短期职业大学': 1,
#  '专科高校': 205,
#  '理工类高校': 108,
#  '地方所属高校': 283,
#  '湖北高校': 19,
#  '博物馆': 63,
#  '文化节': 80,
#  '生命科学': 17,
#  '足球术语': 54,
#  '中国体育学会': 44,
#  '电子游戏': 62,
#  '学院': 111,
#  '江西高校': 19,
#  '法律书籍': 93,
#  '政治学家': 28,
#  '人类学': 27,
#  '排球': 63,
#  '美国': 9,
#  '饮品': 29,
#  '化学': 93,
#  '节日': 67,
#  '非教师': 115,
#  '羽毛球': 51,
#  '访谈节目': 70,
#  '港台节目': 28,
#  '国家': 149,
#  '历史机构': 121,
#  '生物': 21,
#  '2012年电影': 174,
#  '农林类高校': 13,
#  '河北高校': 11,
#  '日韩节目': 25,
#  '文学书籍': 93,
#  '2015年电视剧': 55,
#  '历史学家': 45,
#  '佛教': 116,
#  '手表品牌': 14,
#  '美国品牌': 26,
#  '曲艺家': 38,
#  '女': 73,
#  '综合类高校': 111,
#  '广东高校': 25,
#  '元首': 100,
#  '党务知识': 17,
#  '雕塑': 85,
#  '初中教师': 13,
#  '80年代电视剧': 132,
#  '事业单位': 43,
#  '中医': 43,
#  '枪支': 1,
#  '单机游戏': 13,
#  '即时战略游戏': 2,
#  '专有名词': 74,
#  '经济学家': 64,
#  '生命值，回复，冷却缩减': 1,
#  '中国水产学会': 103,
#  '多肉植物': 15,
#  '现代史': 149,
#  '建筑工程': 12,
#  '格斗游戏': 92,
#  '中国地名': 210,
#  '桌游': 52,
#  '电力工程': 7,
#  '花儿朵朵': 1,
#  '科学百科疾病症状分类': 120,
#  '歌曲': 39,
#  '软体动物': 26,
#  '舒畅': 1,
#  '童星': 2,
#  '宋祖儿': 1,
#  '小哪吒': 1,
#  '宝莲灯前传': 1,
#  '英剧': 37,
#  '遗址': 59,
#  '二战战役': 19,
#  '军事事件': 59,
#  '日本音乐人': 8,
#  '律师': 185,
#  '家电品牌': 15,
#  '奢侈品牌': 45,
#  '动漫': 34,
#  '医学仪器': 13,
#  '外国历史人物': 31,
#  '生活术语': 68,
#  '主持人': 23,
#  '娱乐主持人': 30,
#  '非娱乐': 8,
#  '英国演员': 86,
#  '00年代电视剧': 130,
#  '金融': 126,
#  '历史年代': 90,
#  '其他中央部委隶属高校': 25,
#  '民族类高校': 9,
#  '科学百科农业科学分类': 20,
#  '摄影家': 2,
#  '民俗': 96,
#  '文物古迹': 7,
#  '研究生院高校': 58,
#  '985高校': 40,
#  '酒店': 81,
#  '中国食品科学技术学会': 58,
#  '神话': 14,
#  '汽车品牌': 39,
#  '医药类高校': 31,
#  '安徽高校': 14,
#  '陕西高校': 15,
#  '影视': 7,
#  '连续剧': 2,
#  '棋类': 64,
#  '现代历史事件': 41,
#  '瑞士品牌': 8,
#  '心理学家': 31,
#  '自然资源': 70,
#  '足球官员': 13,
#  '建筑术语': 17,
#  '80后演员': 29,
#  '港口': 49,
#  '昆虫': 51,
#  '名著': 47,
#  '非社会': 3,
#  '老友记': 2,
#  '母婴品牌': 7,
#  '射击、动作': 1,
#  '河南高校': 18,
#  '数学家': 66,
#  '机械工程': 20,
#  '独立学院': 37,
#  '四川高校': 18,
#  '科学百科环境生态分类': 142,
#  '股票类术语': 77,
#  '股票经济术语': 41,
#  '股票进阶术语': 53,
#  '语言类高校': 9,
#  '90年代音乐人': 29,
#  '政治术语': 1,
#  '农业科学': 55,
#  '观赏植物': 78,
#  '地球科学': 34,
#  '水利工程': 8,
#  '上海高校': 23,
#  '民办高校': 27,
#  '股票交易术语': 10,
#  '股票基础术语': 18,
#  '手机品牌': 15,
#  '珠宝配饰品牌': 24,
#  '箱包品牌': 12,
#  '法国品牌': 10,
#  '小学教师': 21,
#  '研究院': 64,
#  '80年代音乐人': 46,
#  '日本动画': 39,
#  '中国汽车学会': 46,
#  '工程技术': 11,
#  '新加坡演员': 11,
#  '网络词语': 2,
#  '词': 9,
#  '管理学': 18,
#  '动漫人物': 22,
#  '地理学术语': 23,
#  '娱乐活动': 32,
#  '股票美股': 47,
#  '电影百科': 1,
#  '化妆品品牌': 6,
#  '摄影术语': 59,
#  '农学': 18,
#  '70年代音乐人': 23,
#  '辽宁高校': 15,
#  '女歌手': 1,
#  '韩国Solo': 1,
#  '统计学': 6,
#  '冬季项目': 50,
#  '哲学': 34,
#  '商业俱乐部': 20,
#  '传统美术-非遗': 10,
#  '校园类动漫': 2,
#  '天文': 39,
#  '生活用品': 86,
#  '田径': 99,
#  '日韩品牌': 18,
#  '化学家': 48,
#  '矿物': 4,
#  '特产': 77,
#  '工业技术': 20,
#  '中国': 34,
#  '内地艺人': 1,
#  '英国音乐人': 6,
#  '乡村音乐': 26,
#  '景点': 59,
#  '网络用语': 14,
#  '股票食品饮料': 7,
#  '股票沪市A股': 36,
#  '真菌': 15,
#  '小说家': 4,
#  '天文学家': 39,
#  '90后演员': 19,
#  '对战、写实、中国风、DOTA': 1,
#  '中国历史': 42,
#  '数学': 29,
#  '理学': 21,
#  '二战人物': 25,
#  '相机': 5,
#  '名人': 5,
#  '音乐家': 1,
#  '学者': 25,
#  '教授': 9,
#  '研究员': 3,
#  '艺术品': 5,
#  '茶': 36,
#  '其他书籍': 1,
#  '江苏菜': 1,
#  '火车站': 33,
#  '专科专业': 4,
#  '旅游类专业': 1,
#  '化学品': 12,
#  '贝类动物': 1,
#  '足球比赛': 35,
#  '体育设施': 30,
#  '股票中小板': 10,
#  '欧洲历史': 18,
#  '县级行政区划': 11,
#  '外国': 69,
#  '心理学': 35,
#  '传记': 20,
#  '烹饪书籍': 25,
#  '电影术语': 14,
#  '福建高校': 9,
#  '足球其他': 23,
#  '裁判': 26,
#  '欧美音乐': 6,
#  '杂文': 6,
#  '古代历史事件': 21,
#  '82': 2,
#  '70后演员': 7,
#  '采矿工程': 24,
#  '小学': 26,
#  '音乐人': 1,
#  '经济组织': 7,
#  '江南水乡': 1,
#  '游记': 1,
#  '古镇西塘': 1,
#  '法律法规': 50,
#  '城镇': 16,
#  '2015年电影': 32,
#  '动漫作品': 19,
#  '江苏高校': 26,
#  '师范类高校': 37,
#  '疾病症状': 12,
#  '二战会议协定': 4,
#  '女性': 3,
#  '台湾': 2,
#  '文学术语': 8,
#  '吉林高校': 5,
#  '伊雪枫叶三生三世': 1,
#  '爱情小说': 1,
#  '网络文学': 1,
#  '文学体裁': 1,
#  '古言小说': 1,
#  '非生活': 8,
#  '居家生活品牌': 15,
#  '民俗-非遗': 13,
#  '中国节日': 3,
#  '传统节日': 4,
#  '哲学书籍': 3,
#  '中小学': 30,
#  '天津高校': 11,
#  '制片人': 4,
#  '股票最新术语': 4,
#  '股票高级术语': 5,
#  '国产动画': 9,
#  '古代文学': 2,
#  '浙江高校': 17,
#  '艺术类高校': 25,
#  '日本小说': 4,
#  '山西高校': 10,
#  '曲艺作品': 2,
#  '美女 办公室 性感': 1,
#  '考古学': 1,
#  '考试科目': 1,
#  '重竞技运动员': 7,
#  '湖南高校': 16,
#  '股票H股': 18,
#  '四川县城。地理': 1,
#  '达州': 1,
#  '自然学科': 20,
#  '小吃': 34,
#  '武术': 2,
#  '二战参战国家': 41,
#  '鱼类': 55,
#  '选秀节目': 43,
#  '武术家': 2,
#  '其他': 2,
#  '科学百科地球科学分类': 27,
#  'TVB': 2,
#  '港剧经典': 1,
#  '冲上云霄': 1,
#  '轴承': 3,
#  '股票采掘': 1,
#  '管理学类专业': 2,
#  '本科专业': 22,
#  '爱情': 2,
#  '音乐术语': 12,
#  'Alisa': 1,
#  '高昱寰': 1,
#  '专辑《ALISA》': 1,
#  'Tekken': 1,
#  '明星偶像': 1,
#  '美国音乐人': 6,
#  '保健品': 1,
#  '细菌': 6,
#  '船舶工程': 10,
#  '医药': 1,
#  '电影奖项': 8,
#  '其他文化': 7,
#  '世界级-非遗': 11,
#  '喜剧': 3,
#  '搞笑': 1,
#  '欧洲': 1,
#  '世界': 1,
#  '百科': 1,
#  '文娱比赛': 11,
#  '内蒙古 歌手 凤凰传奇': 1,
#  '向上吧！少年': 1,
#  '计算机学': 25,
#  '民间文学-非遗': 6,
#  '股票行情术语': 12,
#  '韩国电视剧': 4,
#  '社会学科': 4,
#  '当代历史事件': 14,
#  '传统音乐-非遗': 14,
#  '农作物': 2,
#  '陈海瀛': 1,
#  '国家一级美术师': 1,
#  '英雄 rpg 传说': 1,
#  '童话': 20,
#  '称号': 1,
#  '股票机械设备': 1,
#  '306': 4,
#  '71637': 1,
#  '71673': 2,
#  '射击 警察': 1,
#  '香港音乐人': 4,
#  '电器': 6,
#  '电子产品': 43,
#  '益智': 2,
#  '高等职业技术院校': 28,
#  '古色古香 宫心宅斗 美男': 1,
#  '土木工程': 6,
#  '职业学校': 10,
#  '寺庙': 4,
#  '台湾音乐人': 11,
#  '简介': 1,
#  '州名': 1,
#  '医学人物': 8,
#  '电视': 1,
#  '休闲 美女': 1,
#  '果蔬': 7,
#  '百合': 1,
#  '情感类动漫': 1,
#  '体育协会': 3,
#  '花卉': 5,
#  '杜鹃花科': 1,
#  '金喜善': 1,
#  '池贤宇': 1,
#  '金裕贞': 1,
#  '网络红人': 10,
#  '喜剧片': 1,
#  '行政区域': 6,
#  '国学': 2,
#  '法学家': 10,
#  'flash游戏': 7,
#  '法学类专业': 2,
#  '时尚': 8,
#  '科学百科其他分类': 23,
#  '广西高校': 7,
#  '地区': 4,
#  '台州': 1,
#  '浙江': 1,
#  '盛大': 1,
#  '2D': 1,
#  '角色扮演': 1,
#  '初中': 1,
#  '初级中学': 1,
#  '各国历史': 12,
#  '电影 战争片 剧情片': 1,
#  '国家机构': 6,
#  '股票财务术语': 3,
#  '休闲食品': 6,
#  '187': 1,
#  '302': 25,
#  '437': 2,
#  '赛车': 1,
#  '通讯': 1,
#  '热点人物': 2,
#  '俗语': 7,
#  '内蒙古高校': 1,
#  '清朝人物': 5,
#  '摄影作品': 2,
#  '动漫同人': 1,
#  '电视台': 2,
#  '重庆高校': 8,
#  '地名': 9,
#  '蜀文化': 1,
#  '古蜀': 1,
#  '杜宇': 1,
#  '东周历史': 1,
#  '司马错': 1,
#  '意大利': 1,
#  '兰博基尼': 1,
#  '汽车公司': 1,
#  '非自然': 3,
#  '明星': 20,
#  '人物介绍': 1,
#  '影帝': 1,
#  '教育书籍': 41,
#  '80后创业者': 1,
#  '欧美节目': 5,
#  '瑞典品牌': 1,
#  '股票纺织服装': 2,
#  '乐队': 6,
#  '美容书籍': 5,
#  '哺乳动物': 16,
#  '罗田刘颖': 1,
#  '黑龙江高校': 11,
#  '组合': 16,
#  '图书': 3,
#  '航空公司': 1,
#  '自然灾害': 1,
#  '云南高校': 8,
#  '体育 驾驶': 1,
#  '旅游节目': 18,
#  '参议员': 1,
#  '前总统夫人': 1,
#  '股票技术术语': 5,
#  '图书馆': 5,
#  '足球国家队': 8,
#  '犯罪': 1,
#  '惊悚': 1,
#  '动作': 2,
#  '机场': 17,
#  '抗日': 1,
#  '剧情': 2,
#  '动作片': 5,
#  '日本动漫': 1,
#  '中国动画': 1,
#  '神话形象': 9,
#  '22': 9,
#  '相声': 1,
#  '少年热血': 1,
#  '历法': 2,
#  '娱乐团体': 4,
#  '工学类专业': 5,
#  '社会学家': 2,
#  '武术指导': 1,
#  '功夫演员': 1,
#  '建筑学': 4,
#  '国产剧': 1,
#  '典故': 3,
#  '数码': 4,
#  '建筑师': 7,
#  '市辖区': 2,
#  '华东': 1,
#  '苏中': 1,
#  '泰州市': 1,
#  '江苏省': 1,
#  '魔法': 1,
#  '战斗': 1,
#  '卡牌': 1,
#  '少女': 1,
#  '单机游戏星之卡比': 1,
#  'GBA': 1,
#  'NDS': 1,
#  '山东高校': 24,
#  '黔西南州': 1,
#  '黔西南首府': 1,
#  '贵州兴义': 1,
#  '兴义市': 1,
#  '兴义城市': 1,
#  '校长': 2,
#  '钢琴家': 1,
#  '钢琴': 1,
#  '传统体育、游艺与杂技-非遗': 6,
#  '用户突破5000家': 1,
#  'MC': 1,
#  '美少女战士': 1,
#  'RAPPER': 1,
#  '勇士 格斗': 1,
#  '巧克力': 1,
#  '后援会': 1,
#  '粉丝团': 1,
#  '英国品牌': 8,
#  '好莱坞': 2,
#  '游戏角色': 2,
#  '书法家': 10,
#  '哲学类专业': 2,
#  '亚洲历史': 6,
#  '戏剧术语': 4,
#  '设施仪器': 7,
#  '从零开始、扮猪吃虎': 1,
#  '艺人': 6,
#  '陈意涵': 1,
#  '诗诗': 1,
#  '音乐奖项': 5,
#  '戛纳': 1,
#  '影后': 1,
#  '股票银行': 9,
#  '媒体': 1,
#  '综合': 1,
#  'CCTV': 1,
#  '频道': 1,
#  '原创言情；架空历史；忠犬；甜文': 1,
#  '益智 闯关 搞笑': 1,
#  '资源': 1,
#  '溶洞': 1,
#  '地质': 2,
#  '地质公园': 1,
#  '风景名胜': 1,
#  '江苏': 3,
#  '著名事件': 1,
#  '东线': 1,
#  '大屠杀': 1,
#  '战争罪': 1,
#  '饮食': 9,
#  '传统舞蹈-非遗': 5,
#  '德国品牌': 5,
#  '粤东': 2,
#  '海贼王': 1,
#  '忠心可爱的小狗': 1,
#  '英国王室成员': 1,
#  '犬': 1,
#  '贵州高校': 4,
#  '发展经济学': 1,
#  '社会发展': 1,
#  '经济学': 1,
#  '计算机术语': 9,
#  'R&B': 3,
#  'S.H.E': 1,
#  '体育术语': 20,
#  '舞蹈作品': 2,
#  '搞笑类动漫': 1,
#  '蓝燕': 1,
#  '李威': 1,
#  '美食节目': 15,
#  '股票基金术语': 2,
#  '休闲 动作 冒险': 1,
#  '手机软件': 3,
#  '非地点': 5,
#  '韩国明星': 5,
#  '韩国童星': 1,
#  '国民妹妹': 1,
#  'My boy': 1,
#  '幼儿园': 10,
#  '鼓手': 1,
#  '日韩明星': 3,
#  '广东': 3,
#  '县级市': 1,
#  '广州': 3,
#  '鸡蛋': 1,
#  '鸡': 1,
#  '禽蛋': 1,
#  '营养品': 1,
#  '157': 1,
#  '159': 1,
#  '196': 1,
#  '71037': 1,
#  '股票商业贸易': 3,
#  '商业贸易': 3,
#  '换装 换装 影视 明星': 1,
#  '战争电影': 3,
#  '都市小说': 3,
#  '美国小说': 1,
#  '李宗翰': 1,
#  '科学奖项': 3,
#  '团队': 13,
#  '省份': 6,
#  '诗人': 18,
#  '检查项目': 8,
#  '影视剧形象': 4,
#  '外国城市': 1,
#  '中华古王国': 1,
#  'TVB艺人': 1,
#  '香港艺人': 1,
#  '音乐风格': 4,
#  '粤菜': 1,
#  '传播学': 6,
#  '园林': 2,
#  '玄参目': 1,
#  '韩星': 2,
#  '青岛': 1,
#  '青岛黄海学院': 1,
#  '青岛黄海职业学院': 1,
#  '理学类专业': 3,
#  '去海边吧': 1,
#  '股票房地产': 3,
#  '古籍': 1,
#  '甜点': 2,
#  '字典': 16,
#  '韩国模特': 1,
#  '中国环境科学学会': 1,
#  '塔': 1,
#  '田径运动员': 5,
#  '昵称': 1,
#  '大熊猫': 1,
#  '非文化': 6,
#  '海南高校': 2,
#  '水生植物': 2,
#  '艺术设计传媒类专业': 1,
#  ...}

# %%
# 统计各个实体类型出现次数
alia_count = {}
for item in kb_data:
    alias = item['type'][0]
    if alias not in alia_count:
        alia_count[alias] = 1
    else:
        alia_count[alias] += 1
print(alia_count)
# Out:
# {'Thing': 122182, 'CreativeWork': 50733, 'Plant': 3896, 'HistoricalPerson': 1349, 'Human': 81787, 'Place': 11893, 'Movie': 22421, 'EntertainmentPerson': 18184, 'FictionalHuman': 18259, 'CommunicationMedium': 13465, 'Athlete': 714, 'Vocabulary': 18948, 'Game': 6237, 'TVShow': 503, 'TVPlay': 14235, 'Tool': 553, 'Material': 533, 'Event': 1065, 'Organization': 4136, 'ScientificOrganization': 846, 'CollegeOrUniversity': 548, 'Language': 167, 'Product': 997, 'Organism': 139, 'Animal': 1928, 'Building': 266, 'Brand': 700, 'Country': 128, 'MedicalCondition': 180, 'Person': 312, 'Food': 620, 'FictionalThing': 278, 'FamilyName': 338, 'CulturalHeritage': 94, 'ZodiacSign': 9, 'Nation': 70, 'Currency': 42, 'AstronomicalObject': 102, 'HistoricalPeriod': 99, 'Symbol': 12, 'AcademicDiscipline': 158, 'Curriculum': 25, 'EducationMajor': 46, 'AwardEventSeries': 29, 'InternationalOrganization': 19, 'Formula': 4, 'MedicalDepartmentType': 1, 'Theorem': 1, 'Dynasty': 1}

# %%
# 打印出名字为英国的实体
for item in kb_data:
    if item['alias'][0]=='英国':
        print(item)
# Out:
# {'alias': ['英国'], 'subject_id': '174860', 'subject': '英国', 'type': ['CommunicationMedium'], 'data': [{'predicate': '摘要', 'object': '《英国》，(英)提姆·洛克著，何良英，么少芳译图书，探险家旅游系列丛书的一本。'}, {'predicate': '原版名称', 'object': 'Britain'}, {'predicate': 'ISBN', 'object': '7-101-03904-9'}, {'predicate': '语种', 'object': '汉语'}, {'predicate': '出版、发行地', 'object': '北京'}, {'predicate': '分类', 'object': '中图分类:K956.19'}, {'predicate': '页数', 'object': '288页'}, {'predicate': '书名', 'object': '英国'}, {'predicate': '义项描述', 'object': '中华书局书籍'}, {'predicate': '标签', 'object': '文化'}]}
# {'alias': ['英国'], 'subject_id': '203473', 'subject': '英国', 'type': ['Thing'], 'data': [{'predicate': '摘要', 'object': '英国，是中国历史上周代的诸侯国，为皋陶之后裔，入春秋时期后沦为楚国的附庸，终为楚成王所灭。英国是一个十分弱小的诸侯国，国君姓氏为偃姓。《史记·十二诸侯年表》记载楚成王熊恽二十六年“灭六英”，即在楚成王熊恽二十六年，楚国灭英国与六国。'}, {'predicate': '灭亡原因', 'object': '为楚成王吞并'}, {'predicate': '起止年代', 'object': '？——前646年'}, {'predicate': '所属洲', 'object': '亚洲'}, {'predicate': '国君姓氏', 'object': '偃姓'}, {'predicate': '疆域', 'object': '今安徽金寨、霍山等地'}, {'predicate': '政治体制', 'object': '君主制'}, {'predicate': '简称', 'object': '英'}, {'predicate': '中文名称', 'object': '英国'}, {'predicate': '史书记载', 'object': '《春秋》，《左传》和《史记》'}, {'predicate': '首都', 'object': '安徽省六安西南，湖北省英山县'}, {'predicate': '官方语言', 'object': '上古汉语'}, {'predicate': '义项描述', 'object': '中国春秋时期诸侯国'}, {'predicate': '标签', 'object': '外国历史'}, {'predicate': '标签', 'object': '社会'}, {'predicate': '标签', 'object': '历史'}]}
# {'alias': ['英国'], 'subject_id': '211773', 'subject': '英国', 'type': ['CommunicationMedium'], 'data': [{'predicate': '摘要', 'object': '《英国》是一本自助出国旅游指南，由中资海派商务管理有限公司编写。该书内容包括：出国常识、留学、移民、探亲、商务、旅游、英国生活等，解答了常见的出国问题。'}, {'predicate': '义项描述', 'object': '机械工业出版社图书'}, {'predicate': '标签', 'object': '文化'}, {'predicate': '标签', 'object': '出版物'}, {'predicate': '标签', 'object': '美术'}]}
# {'alias': ['英国'], 'subject_id': '283001', 'subject': '英国', 'type': ['CommunicationMedium'], 'data': [{'predicate': '摘要', 'object': '《英国》化学工业出版社出版的图书。'}, {'predicate': '语种', 'object': 'Chinese 汉语'}, {'predicate': '出版社', 'object': '化学工业出版社'}, {'predicate': 'ISBN', 'object': '978-7-122-05941-3'}, {'predicate': '书名', 'object': '英国'}, {'predicate': '页数', 'object': '152页'}, {'predicate': '义项描述', 'object': '化学工业出版社出版图书'}, {'predicate': '标签', 'object': '文化'}, {'predicate': '标签', 'object': '文学作品'}]}
# {'alias': ['英国'], 'subject_id': '303720', 'subject': '英国', 'type': ['CommunicationMedium'], 'data': [{'predicate': '摘要', 'object': '本书包括：英国大观、伦敦、英格兰东南部、英格兰西部、英格兰中部、英格兰北部、威尔士、苏格兰、旅行者须知及旅游指南等内容。'}, {'predicate': '作者', 'object': 'Michael leapman'}, {'predicate': '书名', 'object': '英国'}, {'predicate': '出版社', 'object': '北京'}, {'predicate': '页数', 'object': '694页'}, {'predicate': '义项描述', 'object': 'Michael leapman主编图书'}, {'predicate': '标签', 'object': '文化'}, {'predicate': '标签', 'object': '出版物'}]}
# {'alias': ['英国'], 'subject_id': '346720', 'subject': '英国', 'type': ['CommunicationMedium'], 'data': [{'predicate': '摘要', 'object': '《英国》是2014年出版的图书，作者是APA Publications。'}, {'predicate': '分类', 'object': 'K956.1'}, {'predicate': 'ISBN', 'object': '7-5084-2246-5'}, {'predicate': '语种', 'object': 'Chinese 汉语'}, {'predicate': '关键词', 'object': '英国-概况英国'}, {'predicate': '页数', 'object': '413页'}, {'predicate': '发行地', 'object': '北京'}, {'predicate': '作者', 'object': '[德]APA Publications[原著]'}, {'predicate': '书名', 'object': '英国'}, {'predicate': '义项描述', 'object': 'APA Publications编著书籍'}, {'predicate': '标签', 'object': '文化'}, {'predicate': '标签', 'object': '出版物'}]}
# {'alias': ['英国'], 'subject_id': '405290', 'subject': '英国', 'type': ['CommunicationMedium'], 'data': [{'predicate': '摘要', 'object': '本书从自然到人文，从历史到现实，全面地介绍了英国的国情。内容涵盖国土与人民、历史、政治、经济与社会生活，教育、科学和文化，军事以及对外关系等七部分。'}, {'predicate': 'ISBN', 'object': '7-80149-924-7'}, {'predicate': '关键词', 'object': '英国-概况英国'}, {'predicate': '页数', 'object': '15,489页'}, {'predicate': '作者', 'object': '王振华'}, {'predicate': '内容', 'object': '国土与人民、历史、政治等'}, {'predicate': '类别', 'object': '中图分类:K956.1'}, {'predicate': '书名', 'object': '英国'}, {'predicate': '义项描述', 'object': '王振华编著书籍'}, {'predicate': '标签', 'object': '文化'}, {'predicate': '标签', 'object': '文学作品'}]}

# %%
# 统计训练集中的实体名称
m_list = []
for item in train_data:
    for m in item['mention_data']:
        m_list.append(m['mention'])

# %%
print('训练集一共有%d个不同实体'%len(set(m_list)))
# Out:
# 训练集一共有116924个不同实体

# %%
# 载入bert预训练token
vocab = []
with open('data/bert-base-chinese-vocab.txt','r') as f:
    for line in f.readlines():
        vocab.append(line.strip())

# %%
# 统计训练集中的字符串种类
m_list = []
for item in train_data:
    for t in item['text']:
        m_list.append(t)

# %%
w_f = {}
for item in m_list:
    if item not in w_f:
        w_f[item] = 1
    else:
        w_f[item] += 1

# %%
m_list = set(m_list)
vocab = set(vocab)

# %%
oov = []
for i in m_list:
    if i not in vocab:
        oov.append(i)

# %%
print('输入字符中有%d种字符，有%d个不再bert token中'%(len(m_list),len(oov)))
# Out:
# 输入字符中有6466种字符，有1019个不再bert token中

# %%
# 统计训练集中的字符串种类
m_list = ''
for item in train_data:
    for t in item['mention_data']:
        
        m_list+=t['mention']
m_list = set(m_list)

# %%
oov = []
for i in m_list:
    if i not in vocab:
        oov.append(i)

# %%
print('输入mention中有%d种字符，有%d个不再bert token中'%(len(m_list),len(oov)))
# Out:
# 输入mention中有5635种字符，有583个不再bert token中

# %%
oov[0:20]
# Out:
# ['苴',
#  '琾',
#  '郯',
#  'Ⅱ',
#  '魃',
#  '倥',
#  '⊱',
#  '萢',
#  '﹋',
#  'Ï',
#  '噉',
#  '╧',
#  '성',
#  '\ufeff',
#  '蛩',
#  '昺',
#  '琯',
#  '聃',
#  '猢',
#  '獀']

# %%
oov_f = dict((x,w_f[x]) for x in oov)

# %%
train_data[0:3]
# Out:
# [{'text_id': '1',
#   'text': '南京南站:坐高铁在南京南站下。南京南站',
#   'mention_data': [{'kb_id': '311223', 'mention': '南京南站', 'offset': '0'},
#    {'kb_id': '341096', 'mention': '高铁', 'offset': '6'},
#    {'kb_id': '311223', 'mention': '南京南站', 'offset': '9'},
#    {'kb_id': '311223', 'mention': '南京南站', 'offset': '15'}]},
#  {'text_id': '2',
#   'text': '比特币吸粉无数,但央行的心另有所属|界面新闻 · jmedia',
#   'mention_data': [{'kb_id': '278410', 'mention': '比特币', 'offset': '0'},
#    {'kb_id': '199602', 'mention': '央行', 'offset': '9'},
#    {'kb_id': '215472', 'mention': '界面新闻', 'offset': '18'}]},
#  {'text_id': '3',
#   'text': '解读《万历十五年》',
#   'mention_data': [{'kb_id': '131751', 'mention': '万历十五年', 'offset': '3'}]}]

# %%
l = []
for t  in train_data:
    l.append(len(t['text']))

# %%
import numpy as np
print('最大长度%d，平均长度%f'%(max(l),np.mean(l)))
# Out:
# 最大长度49，平均长度21.716822

# %%
"""
总体设计思想
１　编码方式
    BMEO编码
２　网络设计
    实体识别
    2.1 lstm+crf
    2.2 bert+crf
    2.3 bert+finetune
    2.4 bert+crf+finetune
    类型判断
    2.5 bert　语言模型向量输出
    最终分类
    待定
３  loss　function
    两种loss，BMEO　loss和entity loss 倾向于识别出实体
"""
# Out:
# '\n总体设计思想\n１\u3000编码方式\n    BMEO编码\n２\u3000网络设计\n    实体识别\n    2.1 lstm+crf\n    2.2 bert+crf\n    2.3 bert+finetune\n    2.4 bert+crf+finetune\n    类型判断\n    2.5 bert\u3000语言模型向量输出\n    最终分类\n    待定\n３  loss\u3000function\n    两种loss，BMEO\u3000loss和entity loss 倾向于识别出实体\n'
