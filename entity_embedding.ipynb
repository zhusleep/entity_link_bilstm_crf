# %%
"""
todo
三种方法：
1 gensim 训练　embedding
2 openKE 训练　embedding
3 openKE　分词训练　embedding　
"""
# Out:
# '\ntodo\n三种方法：\n1 gensim 训练\u3000embedding\n2 openKE 训练\u3000embedding\n3 openKE\u3000分词训练\u3000embedding\u3000\n'

# %%
# coding:u8
import json
import numpy as np
from collections import defaultdict
from tqdm import tqdm as tqdm

# %%
# 读取知识库
kb_data = []
kb = {}
with open('data/raw_data/kb_data','r') as f:
    for line in f:
        item = json.loads(line)
        kb[item['subject_id']] = item
        kb_data.append(item)

# %%
kb_data[5:20]
# Out:
# [{'alias': ['王超'],
#   'subject_id': '10006',
#   'subject': '王超',
#   'type': ['Human'],
#   'data': [{'predicate': '义项描述', 'object': '齐鲁书画研究院书画家'},
#    {'predicate': '标签', 'object': '人物'},
#    {'predicate': '标签', 'object': '艺术家'}]},
#  {'alias': ['无尽武道'],
#   'subject_id': '10007',
#   'subject': '无尽武道',
#   'type': ['CreativeWork'],
#   'data': [{'predicate': '摘要',
#     'object': '《无尽武道》是一部爱情类的小说，作者是穿越梦竹，小说仍在连载中，连载网站是晋江文学城。'},
#    {'predicate': '连载网站', 'object': '晋江文学城'},
#    {'predicate': '小说进度', 'object': '连载'},
#    {'predicate': '作者', 'object': '穿越梦竹'},
#    {'predicate': '中文名', 'object': '无尽武道'},
#    {'predicate': '小说类型', 'object': '爱情'},
#    {'predicate': '义项描述', 'object': '穿越梦竹著作小说'},
#    {'predicate': '标签', 'object': '书籍'},
#    {'predicate': '标签', 'object': '小说作品'},
#    {'predicate': '标签', 'object': '中国文学'},
#    {'predicate': '标签', 'object': '文学作品'},
#    {'predicate': '标签', 'object': '小说'}]},
#  {'alias': ['滕王阁序'],
#   'subject_id': '10008',
#   'subject': '滕王阁序',
#   'type': ['Thing'],
#   'data': [{'predicate': '摘要', 'object': '《滕王阁序》是佚名的音乐作品,收录在《诗词歌赋大集合》专辑中。'},
#    {'predicate': '音乐时长', 'object': '3分50秒'},
#    {'predicate': '所属专辑', 'object': '诗词歌赋大集合'},
#    {'predicate': '义项描述', 'object': '佚名演唱歌曲'}]},
#  {'alias': ['莲宗寺'],
#   'subject_id': '10009',
#   'subject': '莲宗寺',
#   'type': ['Place'],
#   'data': [{'predicate': '摘要',
#     'object': '莲宗寺位于天津市和平区保安大街，是1949年后天津仅存的一座尼僧寺院。创建者际然法师在开山时所发的愿言“来僧不赶，去僧不留，自己不亲度徒众”的愿言，使此寺十方丛林的清严道风名闻遐迩。此道风被际然尼师的接班人圣慧法师继承至今，并将作为莲宗寺的传院家风而保留。2014年2月14日(正月十五)莲宗寺落地大修工程正式启动，莲宗寺所有宗教佛事活动均转移至莲宗寺临时活动道场进行(甘肃路32号，在甘肃路上万全道与鞍山道之间)。'},
#    {'predicate': '类型', 'object': '尼僧寺院'},
#    {'predicate': '中文名称', 'object': '莲宗寺'},
#    {'predicate': '占地面积', 'object': '一亩一分'},
#    {'predicate': '地理位置', 'object': '天津市和平区'},
#    {'predicate': '义项描述', 'object': '天津'},
#    {'predicate': '标签', 'object': '地理'},
#    {'predicate': '标签', 'object': '文化'},
#    {'predicate': '标签', 'object': '文物考古'},
#    {'predicate': '标签', 'object': '景观景点'},
#    {'predicate': '标签', 'object': '建筑'},
#    {'predicate': '标签', 'object': '历史'}]},
#  {'alias': ['裙子'],
#   'subject_id': '10010',
#   'subject': '裙子',
#   'type': ['Thing'],
#   'data': [{'predicate': '摘要',
#     'object': '《裙子》是一部由[瑞士]杰曼诺·祖罗所著图画书籍，新星出版社出版发行。'},
#    {'predicate': '作者', 'object': '[瑞士]杰曼诺·祖罗'},
#    {'predicate': 'ISBN', 'object': '9787513307017'},
#    {'predicate': '书名', 'object': '裙子'},
#    {'predicate': '出版社', 'object': '新星出版社'},
#    {'predicate': '义项描述', 'object': '[瑞士]杰曼诺·祖罗所著书籍'}]},
#  {'alias': ['东泉镇'],
#   'subject_id': '10011',
#   'subject': '东泉镇',
#   'type': ['Place'],
#   'data': [{'predicate': '摘要',
#     'object': '巴南区东温泉镇地处巴南区东部，巴南旅游双环线上。2001年7月，乡镇建制调整后由原来东泉、五布镇、天赐镇、清和乡合并而成。东与南川市白沙镇接壤，南与石龙镇、姜家镇为邻，西连二圣镇，北接木洞、丰盛镇。幅员面积122.70平方公里，耕地面积50862亩，其中田25376亩。镇政府所在地距重庆市区50余公里。现辖14个行政村、4个居委会、136个村民小组，总户数11869户，总人口37856人，其中农业人口35188人，非农业人口2668人。'},
#    {'predicate': '行政区类别', 'object': '重庆市'},
#    {'predicate': '所属地区', 'object': '重庆市巴南区'},
#    {'predicate': '下辖地区', 'object': '辖14个行政村、4个居委会'},
#    {'predicate': '电话区号', 'object': '023'},
#    {'predicate': '方言', 'object': '重庆方言'},
#    {'predicate': '邮政区码', 'object': '401320'},
#    {'predicate': '面积', 'object': '122.70平方公里'},
#    {'predicate': '车牌代码', 'object': '渝'},
#    {'predicate': '人口', 'object': '37856人'},
#    {'predicate': '著名景点', 'object': '东温泉'},
#    {'predicate': '中文名称', 'object': '巴南区东温泉镇'},
#    {'predicate': '气候条件', 'object': '亚热带湿润气候'},
#    {'predicate': '义项描述', 'object': '重庆市巴南区东温泉镇'},
#    {'predicate': '标签', 'object': '行政区划'},
#    {'predicate': '标签', 'object': '乡镇'}]},
#  {'alias': ['王峰'],
#   'subject_id': '10012',
#   'subject': '王峰',
#   'type': ['Human'],
#   'data': [{'predicate': '摘要',
#     'object': '王峰，男，蒙古族，1958年9月出生，内蒙古鄂托克旗人，中央党校大学学历，1980年1月加入中国共产党，1974年6月参加工作。现任内蒙古自治区鄂尔多斯市人大常委会主任、党组书记。'},
#    {'predicate': '出生地', 'object': '内蒙古鄂托克旗'},
#    {'predicate': '毕业院校', 'object': '中央党校'},
#    {'predicate': '中文名', 'object': '王峰'},
#    {'predicate': '国籍', 'object': '中国'},
#    {'predicate': '出生日期', 'object': '1958年9月'},
#    {'predicate': '民族', 'object': '蒙古族'},
#    {'predicate': '义项描述', 'object': '内蒙古鄂尔多斯市人大常委会主任'},
#    {'predicate': '标签', 'object': '政治人物'},
#    {'predicate': '标签', 'object': '人物'},
#    {'predicate': '标签', 'object': '官员'}]},
#  {'alias': ['男子汉大丈夫'],
#   'subject_id': '10013',
#   'subject': '男子汉大丈夫',
#   'type': ['CreativeWork'],
#   'data': [{'predicate': '摘要', 'object': '《男子汉大丈夫》是李海强填词谱曲并演唱的一首歌曲。'},
#    {'predicate': '歌曲原唱', 'object': '李海强'},
#    {'predicate': '谱曲', 'object': '李海强'},
#    {'predicate': '歌曲语言', 'object': '普通话'},
#    {'predicate': '填词', 'object': '李海强'},
#    {'predicate': '发行时间', 'object': '2015年3月10日'},
#    {'predicate': '中文名称', 'object': '男子汉大丈夫'},
#    {'predicate': '义项描述', 'object': '男子汉大丈夫-李海强歌曲'},
#    {'predicate': '标签', 'object': '人物'}]},
#  {'alias': ['Giovanni Boccaccio',
#    '乔万尼·薄伽丘',
#    '卜伽丘',
#    '薄伽丘',
#    '乔凡尼·卜迦丘',
#    '乔万尼·卜伽丘',
#    '薄伽丘，G.'],
#   'subject_id': '10014',
#   'subject': '乔万尼·薄伽丘',
#   'type': ['Human'],
#   'data': [{'predicate': '摘要',
#     'object': '乔万尼·薄伽丘(Giovanni Boccaccio，1313年——1375年12月21日)，意大利文艺复兴运动的杰出代表，人文主义杰出作家。与诗人但丁、彼特拉克并称为佛罗伦萨文学“三杰”。其代表作《十日谈》是欧洲文学史上第一部现实主义作品。它批判宗教守旧思想，主张“幸福在人间”，被视为文艺复兴的宣言。'},
#    {'predicate': '出生地', 'object': '巴黎或契塔尔多'},
#    {'predicate': '外文名', 'object': 'Giovanni Boccaccio'},
#    {'predicate': '逝世日期', 'object': '1375年12月21日'},
#    {'predicate': '星座', 'object': '双子座'},
#    {'predicate': '别名', 'object': '卜伽丘'},
#    {'predicate': '代表作品', 'object': '《十日谈》、《菲洛柯洛》、《苔塞伊达》《但丁传》'},
#    {'predicate': '中文名', 'object': '乔万尼·薄伽丘'},
#    {'predicate': '国籍', 'object': '佛罗伦萨共和国'},
#    {'predicate': '出生日期', 'object': '1313(癸丑年)6月16日'},
#    {'predicate': '职业', 'object': '作家，诗人'},
#    {'predicate': '民族', 'object': '意大利人'},
#    {'predicate': '主要成就', 'object': '意大利文艺复兴先驱，人文主义杰出作家'},
#    {'predicate': '义项描述', 'object': '乔万尼·薄伽丘'},
#    {'predicate': '标签', 'object': '人物'},
#    {'predicate': '标签', 'object': '文学家'},
#    {'predicate': '标签', 'object': '文学'}]},
#  {'alias': ['李青'],
#   'subject_id': '10015',
#   'subject': '李青',
#   'type': ['Human'],
#   'data': [{'predicate': '摘要',
#     'object': '李青，汉族，1972年出生，湖北应城人，女子跳水运动员，国际级运动健将，湖北省劳动模范。1988年4月，在中国国际跳水公开赛上获得跳板季军。1988年6月，在韩国汉城国际跳水获得跳板跳水冠军。'},
#    {'predicate': '出生地', 'object': '湖北应城'},
#    {'predicate': '中文名', 'object': '李青'},
#    {'predicate': '主要奖项',
#     'object': '1988年4月，在中国国际跳水公开赛上获得跳板季军,1988年6月，在韩国汉城国际跳水获得跳板跳水冠军。,湖北省劳动模范'},
#    {'predicate': '出生日期', 'object': '1972年'},
#    {'predicate': '国籍', 'object': '中国'},
#    {'predicate': '运动项目', 'object': '跳水'},
#    {'predicate': '性别', 'object': '女'},
#    {'predicate': '民族', 'object': '汉族'},
#    {'predicate': '义项描述', 'object': '女子跳水运动员'},
#    {'predicate': '标签', 'object': '游泳'},
#    {'predicate': '标签', 'object': '体育人物'},
#    {'predicate': '标签', 'object': '人物'},
#    {'predicate': '标签', 'object': '运动员'}]},
#  {'alias': ['Salty soy milk', '咸豆浆', 'xían dòu jiāng'],
#   'subject_id': '10016',
#   'subject': '咸豆浆',
#   'type': ['Movie'],
#   'data': [{'predicate': '摘要',
#     'object': '《咸豆浆》是2002年上映的台湾电影，由王明台导演。范植伟，马志翔等人主演。《咸豆浆》讲述明贤深爱著他所不该爱的静芬，因为静芬已经有了在PUB演唱的男友阿翔。但也因为他心中无怨无悔的爱，他毫不犹豫地答应了静芬一块从事仙人跳的勾当，目的却是为了要买一把吉他送给阿翔。陪著明贤一起做出拒绝联考的决定，启文不仅失去了女友，彷佛也失去了对自我生命的自信。这时候，他发现楼下的神秘女郎总被一个黑道大哥欺负，他的心中突然萌生了为解救女郎而和黑道大哥奋力对抗的勇敢念头。'},
#    {'predicate': '出品时间', 'object': '2002'},
#    {'predicate': '导演', 'object': '王明台'},
#    {'predicate': '制片地区', 'object': '中国台湾'},
#    {'predicate': '外文名', 'object': 'Salty soy milk'},
#    {'predicate': '片长', 'object': '103分钟'},
#    {'predicate': '对白语言', 'object': '汉语普通话，台语'},
#    {'predicate': '编剧', 'object': '王明台'},
#    {'predicate': '中文名', 'object': '咸豆浆'},
#    {'predicate': '上映时间', 'object': '2002年'},
#    {'predicate': '主演', 'object': '范植伟，马志翔，简沛恩，黄嘉千'},
#    {'predicate': '类型', 'object': '剧情'},
#    {'predicate': '其它译名', 'object': 'xían dòu jiāng'},
#    {'predicate': '义项描述', 'object': '2002年王明台执导电影'},
#    {'predicate': '标签', 'object': '娱乐作品'},
#    {'predicate': '标签', 'object': '电影作品'},
#    {'predicate': '标签', 'object': '剧情电影'},
#    {'predicate': '标签', 'object': '台湾电影'}]},
#  {'alias': ['Guan Jian', '关键'],
#   'subject_id': '10017',
#   'subject': '关键',
#   'type': ['EntertainmentPerson'],
#   'data': [{'predicate': '摘要',
#     'object': '关键，出生于中华人民共和国，CCTV-7《军事报道》节目主持人，陆军中校军衔。'},
#    {'predicate': '外文名', 'object': 'Guan Jian'},
#    {'predicate': '军衔', 'object': '中校'},
#    {'predicate': '中文名', 'object': '关键'},
#    {'predicate': '代表作品', 'object': '《军事报道》'},
#    {'predicate': '所属公司', 'object': '中国中央电视台'},
#    {'predicate': '国籍', 'object': '中华人民共和国'},
#    {'predicate': '所属军队', 'object': '中国人民解放军总政治部'},
#    {'predicate': '职业', 'object': '主持人、军人'},
#    {'predicate': '民族', 'object': '汉族'},
#    {'predicate': '义项描述', 'object': '中央电视台军事报道节目主持人'}]},
#  {'alias': ['周永康', '香港周永康'],
#   'subject_id': '10018',
#   'subject': '周永康',
#   'type': ['Human'],
#   'data': [{'predicate': '摘要',
#     'object': '周永康，汉族，香港大学学生，香港“占中运动”发起者，并且担任“占中运动”领导。2018年2月6日，周永康就闯入政府总部东翼前地案被改判监后提出上诉，终审法院裁定3人上诉成功，维持原审判决。'},
#    {'predicate': '毕业院校', 'object': '香港大学'},
#    {'predicate': '中文名', 'object': '周永康'},
#    {'predicate': '主要成就', 'object': '发起香港占中运动，并担任领导'},
#    {'predicate': '国籍', 'object': '中华人民共和国'},
#    {'predicate': '职业', 'object': '学生'},
#    {'predicate': '民族', 'object': '汉族'},
#    {'predicate': '义项描述', 'object': '香港学联秘书长'},
#    {'predicate': '标签', 'object': '人物'}]},
#  {'alias': ['郭斌'],
#   'subject_id': '10019',
#   'subject': '郭斌',
#   'type': ['Human'],
#   'data': [{'predicate': '摘要', 'object': '男，经济学与金融学系，副教授，学历：博士。'},
#    {'predicate': '性别', 'object': '男'},
#    {'predicate': '职业', 'object': '副教授'},
#    {'predicate': '学位', 'object': '博士'},
#    {'predicate': '中文名', 'object': '郭斌'},
#    {'predicate': '义项描述', 'object': '电子科技大学经济学与金融学系教授'},
#    {'predicate': '标签', 'object': '行业人物'},
#    {'predicate': '标签', 'object': '人物'},
#    {'predicate': '标签', 'object': '科研人员'},
#    {'predicate': '标签', 'object': '教师'}]},
#  {'alias': ['食尸鬼2012', '盗墓者'],
#   'subject_id': '10020',
#   'subject': '食尸鬼2012',
#   'type': ['Movie'],
#   'data': [{'predicate': '摘要',
#     'object': '《食尸鬼2012》是2012年上映的美国恐怖电影，由Gary Jones执导，诺兰·古尔德、安德烈等主演。影片讲述了公共墓地有某种恐怖物体在不停游荡，潜伏的恶魔伤害人类的故事。'},
#    {'predicate': '导演', 'object': 'Gary Jones'},
#    {'predicate': '制片地区', 'object': '美国'},
#    {'predicate': '片长', 'object': '80分钟'},
#    {'predicate': '对白语言', 'object': '英语'},
#    {'predicate': '中文名', 'object': '食尸鬼2012'},
#    {'predicate': '上映时间', 'object': '2012年'},
#    {'predicate': '类型', 'object': '剧情 / 悬疑 / 惊悚 / 恐怖'},
#    {'predicate': '其它译名', 'object': '盗墓者'},
#    {'predicate': '义项描述', 'object': '食尸鬼2012'},
#    {'predicate': '标签', 'object': '娱乐作品'},
#    {'predicate': '标签', 'object': '电影作品'},
#    {'predicate': '标签', 'object': '惊悚电影'},
#    {'predicate': '标签', 'object': '剧情电影'},
#    {'predicate': '标签', 'object': '电影'}]}]

# %%
# OpenKE 默认方法

# %%
predicate = {}
subject = {}
type_object = {}

# %%
for item in tqdm(kb_data):
    if item['subject_id'] not in subject:
        subject[item['subject_id']] = len(subject)
    for t in item['data']:
        if t['predicate'] == '摘要':continue
        if t['predicate'] not in predicate:
            predicate[t['predicate']] = len(predicate)
        if t['object'] not in type_object:
            type_object[t['object']] = len(type_object)
    for t_type in item['type']:
        if t_type not in type_object:
            type_object[t_type] = len(type_object)
if 'type' not in predicate:
    predicate['type'] = len(predicate)
# Out:
# 100%|██████████| 399252/399252 [00:03<00:00, 129751.49it/s]

# %%
predicate
# Out:
# {'制作方': 0,
#  '外文名': 1,
#  '来源': 2,
#  '中文名': 3,
#  '属性': 4,
#  '义项描述': 5,
#  '歌曲原唱': 6,
#  '谱曲': 7,
#  '歌曲时长': 8,
#  '歌曲语言': 9,
#  '音乐风格': 10,
#  '唱片公司': 11,
#  '翻唱': 12,
#  '填词': 13,
#  '发行时间': 14,
#  '中文名称': 15,
#  '所属专辑': 16,
#  '标签': 17,
#  '亚目': 18,
#  '别称': 19,
#  '种': 20,
#  '界': 21,
#  '目': 22,
#  '科': 23,
#  '拉丁学名': 24,
#  '纲': 25,
#  '门': 26,
#  '中文学名': 27,
#  '亚科': 28,
#  '亚纲': 29,
#  '出生地': 30,
#  '爵位': 31,
#  '官职': 32,
#  '所处时代': 33,
#  '本名': 34,
#  '字号': 35,
#  '民族族群': 36,
#  '主要成就': 37,
#  '去世时间': 38,
#  '连载网站': 39,
#  '小说进度': 40,
#  '作者': 41,
#  '小说类型': 42,
#  '音乐时长': 43,
#  '类型': 44,
#  '占地面积': 45,
#  '地理位置': 46,
#  'ISBN': 47,
#  '书名': 48,
#  '出版社': 49,
#  '行政区类别': 50,
#  '所属地区': 51,
#  '下辖地区': 52,
#  '电话区号': 53,
#  '方言': 54,
#  '邮政区码': 55,
#  '面积': 56,
#  '车牌代码': 57,
#  '人口': 58,
#  '著名景点': 59,
#  '气候条件': 60,
#  '毕业院校': 61,
#  '国籍': 62,
#  '出生日期': 63,
#  '民族': 64,
#  '逝世日期': 65,
#  '星座': 66,
#  '别名': 67,
#  '代表作品': 68,
#  '职业': 69,
#  '主要奖项': 70,
#  '运动项目': 71,
#  '性别': 72,
#  '出品时间': 73,
#  '导演': 74,
#  '制片地区': 75,
#  '片长': 76,
#  '对白语言': 77,
#  '编剧': 78,
#  '上映时间': 79,
#  '主演': 80,
#  '其它译名': 81,
#  '军衔': 82,
#  '所属公司': 83,
#  '所属军队': 84,
#  '学位': 85,
#  '登场作品': 86,
#  '配音': 87,
#  '饰演': 88,
#  '开本': 89,
#  '制片人': 90,
#  '色彩': 91,
#  '出品公司': 92,
#  '语言': 93,
#  '歌手': 94,
#  '拼音': 95,
#  '注音': 96,
#  '最新章节': 97,
#  '连载平台': 98,
#  '连载状态': 99,
#  '是否出版': 100,
#  '作曲': 101,
#  '装帧': 102,
#  '页数': 103,
#  '定价': 104,
#  '出版时间': 105,
#  '缩写': 106,
#  '原名': 107,
#  '含义': 108,
#  '影响因素': 109,
#  '温度数据': 110,
#  '信仰': 111,
#  '幅面': 112,
#  'imdb编码': 113,
#  '分级': 114,
#  '软件名称': 115,
#  '软件平台': 116,
#  '软件版本': 117,
#  '声优': 118,
#  '编曲': 119,
#  '读音': 120,
#  '解释': 121,
#  '出处': 122,
#  '分类': 123,
#  '其他名称': 124,
#  '执业地点': 125,
#  '临床职称': 126,
#  '节目方式': 127,
#  '地址': 128,
#  '内容': 129,
#  '游戏类型': 130,
#  '首播时间': 131,
#  '国家/地区': 132,
#  '播出频道': 133,
#  '播出状态': 134,
#  '主持人': 135,
#  '每季期数': 136,
#  '每集长度': 137,
#  '季度冠名': 138,
#  '主要嘉宾': 139,
#  '外文名称': 140,
#  '播出时间': 141,
#  '制作公司': 142,
#  '在线播放平台': 143,
#  '海拔': 144,
#  '授权状态': 145,
#  '写作进程': 146,
#  '小说类别': 147,
#  '身高': 148,
#  '作品名称': 149,
#  '作品别名': 150,
#  '文学体裁': 151,
#  '创作年代': 152,
#  '代表作': 153,
#  '原版名称': 154,
#  '地区': 155,
#  '其他出版社': 156,
#  '插画': 157,
#  '学历': 158,
#  '参加工作': 159,
#  '发行公司': 160,
#  '乐器普遍音阶': 161,
#  '应用谱号': 162,
#  '任职': 163,
#  '副标题': 164,
#  '集数': 165,
#  '拍摄地点': 166,
#  '拍摄日期': 167,
#  '票房': 168,
#  '译者': 169,
#  '演唱者': 170,
#  '亦作': 171,
#  '出自': 172,
#  '释义': 173,
#  '原作': 174,
#  '出版期间': 175,
#  '实质': 176,
#  '用处': 177,
#  '所属系列': 178,
#  '游戏大小': 179,
#  '具体内容': 180,
#  '单位': 181,
#  '简写': 182,
#  '血型': 183,
#  '经纪人': 184,
#  '体重': 185,
#  '经纪公司': 186,
#  '字数': 187,
#  '妻子': 188,
#  '女儿': 189,
#  '年龄': 190,
#  '变身者': 191,
#  '机场': 192,
#  '分布区域': 193,
#  '采收时间': 194,
#  '用量': 195,
#  '毒性': 196,
#  '属': 197,
#  '单行本册数': 198,
#  '连载期间': 199,
#  '连载杂志': 200,
#  '类别': 201,
#  '形成地点': 202,
#  '形成时间': 203,
#  '评分': 204,
#  '嘉宾主持': 205,
#  '制片成本': 206,
#  '主唱': 207,
#  '成立时间': 208,
#  '吉他': 209,
#  '鼓手': 210,
#  '贝斯': 211,
#  '首播频道': 212,
#  '音乐谱曲': 213,
#  '衍生剧': 214,
#  'IMDb评分': 215,
#  '地位': 216,
#  '发行': 217,
#  '政治面貌': 218,
#  '职称': 219,
#  '原曲': 220,
#  '动作': 221,
#  '符号': 222,
#  '所属国家': 223,
#  '源于': 224,
#  '曾任职务': 225,
#  '调查时间': 226,
#  '首次登场': 227,
#  '定义': 228,
#  '所属学科': 229,
#  '栏目特点': 230,
#  '栏目介绍': 231,
#  '揭载号': 232,
#  '日语': 233,
#  '创始人': 234,
#  '梵名': 235,
#  '出生时间': 236,
#  '兄弟': 237,
#  '父亲': 238,
#  '又名': 239,
#  '国家领袖': 240,
#  '简称': 241,
#  '所处时期': 242,
#  '主要城市': 243,
#  '首都': 244,
#  '脚本': 245,
#  '更新': 246,
#  '摄影指导': 247,
#  '上映平台': 248,
#  '专辑': 249,
#  '演唱': 250,
#  '混音': 251,
#  '录音': 252,
#  '和声': 253,
#  '反义词': 254,
#  '侄子': 255,
#  '最难忘的': 256,
#  '挚爱&初恋': 257,
#  '定情信物': 258,
#  '兴趣': 259,
#  '卫视首播': 260,
#  '拍摄时间': 261,
#  '专业': 262,
#  '专辑语言': 263,
#  '专辑歌手': 264,
#  '发行地区': 265,
#  '片尾曲': 266,
#  '卡牌品质': 267,
#  '特征': 268,
#  '优点': 269,
#  '性质': 270,
#  '谥号': 271,
#  '主要配音': 272,
#  '动画制作': 273,
#  '音乐': 274,
#  '播放期间': 275,
#  '出品': 276,
#  '角色设计': 277,
#  '网络播放': 278,
#  '剧本': 279,
#  '首播电视台': 280,
#  '适用': 281,
#  '涵义': 282,
#  '注重': 283,
#  '中药名称': 284,
#  '主办单位': 285,
#  '主管单位': 286,
#  '编辑单位': 287,
#  '出版周期': 288,
#  '誉为': 289,
#  '又称': 290,
#  '原产于': 291,
#  '提出者': 292,
#  '提出时间': 293,
#  '最喜欢的颜色': 294,
#  '最喜欢的演员': 295,
#  '祖籍': 296,
#  '羁绊': 297,
#  '伙伴': 298,
#  '生日': 299,
#  '职务': 300,
#  '学位/学历': 301,
#  '词目': 302,
#  '示例': 303,
#  '品牌': 304,
#  '丛书': 305,
#  '火车站': 306,
#  '政府驻地': 307,
#  '外来人口': 308,
#  '首任校长': 309,
#  '创办时间': 310,
#  '主要院系': 311,
#  '校训': 312,
#  '末任校长': 313,
#  '知名校友': 314,
#  '作品体裁': 315,
#  '词牌': 316,
#  '作品出处': 317,
#  '意义': 318,
#  '做法': 319,
#  '主要基地': 320,
#  '机队情况': 321,
#  '总部地点': 322,
#  '两字代码': 323,
#  '公司名称': 324,
#  '剧本策划': 325,
#  '官方微博': 326,
#  '百度贴吧': 327,
#  '出品人': 328,
#  '美术': 329,
#  '联合摄制': 330,
#  '赛区': 331,
#  '上星平台': 332,
#  '首播平台': 333,
#  '作用': 334,
#  '知名教授': 335,
#  '现任校长': 336,
#  '粉丝名': 337,
#  '公益基金': 338,
#  '生肖': 339,
#  '应援色': 340,
#  '就读学校': 341,
#  '特长': 342,
#  '主要作品': 343,
#  '魔法': 344,
#  '害怕的东西': 345,
#  '喜欢的东西': 346,
#  '药效': 347,
#  '来历': 348,
#  '本质': 349,
#  '相对': 350,
#  '录音师': 351,
#  '制作人': 352,
#  '混音师': 353,
#  'MV导演': 354,
#  'MV出演': 355,
#  '籍贯': 356,
#  '创作时间': 357,
#  '副局长': 358,
#  '官网': 359,
#  '员工': 360,
#  '总部': 361,
#  '局长': 362,
#  '学校类型': 363,
#  '主管部门': 364,
#  '英文名': 365,
#  '博士后流动站': 366,
#  '目标定位': 367,
#  '长江学者': 368,
#  '硕士点': 369,
#  '党委书记': 370,
#  '国家重点学科': 371,
#  '学校代码': 372,
#  '博士点': 373,
#  '学校地址': 374,
#  '校歌': 375,
#  '教学职称': 376,
#  '专属驾驶员': 377,
#  '等级': 378,
#  '喜欢的明星': 379,
#  '微博': 380,
#  '粉丝口号': 381,
#  '粉丝称呼': 382,
#  '开发公司': 383,
#  '运营公司': 384,
#  '软件大小': 385,
#  '软件语言': 386,
#  '操作平台': 387,
#  '更新日期': 388,
#  '收费模式': 389,
#  '分享类型': 390,
#  '基本解释': 391,
#  '剧种': 392,
#  '时间': 393,
#  '座右铭': 394,
#  '陵墓': 395,
#  '上市时间': 396,
#  '生产状态': 397,
#  '品牌类型': 398,
#  '指导价': 399,
#  '生产厂家': 400,
#  '排量': 401,
#  '近义词': 402,
#  '感情色彩': 403,
#  '比喻义': 404,
#  '时段': 405,
#  '挚友': 406,
#  '喜欢的人': 407,
#  '妹妹': 408,
#  '爱丽丝能力': 409,
#  '爱丽丝石颜色': 410,
#  '母亲': 411,
#  '爱丽丝系别': 412,
#  '星阶级': 413,
#  '玩家人数': 414,
#  '游戏平台': 415,
#  '发行日期': 416,
#  '开发商': 417,
#  '发行商': 418,
#  '出生年月': 419,
#  '化学式': 420,
#  '外观': 421,
#  '沸点': 422,
#  '闪点': 423,
#  '熔点': 424,
#  '密度': 425,
#  '水溶性': 426,
#  '应用': 427,
#  '内容主题': 428,
#  '对象': 429,
#  '表现': 430,
#  '创作灵感': 431,
#  '意指': 432,
#  '同义词': 433,
#  '公会口号': 434,
#  '公会创始人': 435,
#  '身份证前六位': 436,
#  '所属运动队': 437,
#  '重要事件': 438,
#  'IMDB评分': 439,
#  '职责': 440,
#  '推出': 441,
#  '英文': 442,
#  '主要势力': 443,
#  '所属组合': 444,
#  '家庭成员': 445,
#  '爱好': 446,
#  '宗教': 447,
#  '生活地域': 448,
#  '发现者': 449,
#  '魅力': 450,
#  '标志物': 451,
#  '中国获奖导演': 452,
#  '属于': 453,
#  '开始颁发时间': 454,
#  '曲目数量': 455,
#  '专辑时长': 456,
#  '唱片销量': 457,
#  '所属洲': 458,
#  '国家': 459,
#  '编号': 460,
#  '情报': 461,
#  '儿女': 462,
#  '队伍': 463,
#  '丈夫': 464,
#  '前世': 465,
#  '初恋': 466,
#  '武器': 467,
#  '好友': 468,
#  '年代': 469,
#  '身份': 470,
#  '摄制格式': 471,
#  '功能': 472,
#  '洗印格式': 473,
#  '员工数': 474,
#  '版权公司': 475,
#  '最新版本': 476,
#  '特技': 477,
#  '最早版本': 478,
#  '原型': 479,
#  '搭档': 480,
#  '师父': 481,
#  '州府': 482,
#  '总人口': 483,
#  '主要民族': 484,
#  '主要宗教': 485,
#  '平均寿命': 486,
#  '官方语言': 487,
#  '位置': 488,
#  '两支支流': 489,
#  '胶片长度': 490,
#  '栏目': 491,
#  '录制频道': 492,
#  '全称': 493,
#  '旧名': 494,
#  '赐名时间': 495,
#  '始建于': 496,
#  '监制': 497,
#  '原著': 498,
#  '二名法': 499,
#  '特点': 500,
#  '拉丁': 501,
#  '注释': 502,
#  '笔顺编号': 503,
#  '部外笔画': 504,
#  '部首': 505,
#  '仓颉': 506,
#  '四角号码': 507,
#  '五笔86': 508,
#  'Unicode': 509,
#  '总笔画': 510,
#  '五笔98': 511,
#  '统一汉字': 512,
#  '主要客运工具': 513,
#  '包括': 514,
#  '气候类型': 515,
#  '门票价格': 516,
#  '开放时间': 517,
#  '景点级别': 518,
#  '专业方向': 519,
#  '学术代表作': 520,
#  '仓颉遗迹': 521,
#  '类似': 522,
#  '拉丁名': 523,
#  '科属': 524,
#  '原产': 525,
#  '旧友': 526,
#  '网站类别': 527,
#  '涉及范围': 528,
#  '从事': 529,
#  '产生根源': 530,
#  '组织门派': 531,
#  '上司': 532,
#  '同修': 533,
#  '根据地': 534,
#  '现任': 535,
#  '简介': 536,
#  '录混': 537,
#  '糖果王国': 538,
#  '游戏': 539,
#  '花果岛': 540,
#  '演奏': 541,
#  '流派': 542,
#  '主要角色': 543,
#  '字': 544,
#  '灼华信息': 545,
#  '制片': 546,
#  '总监制': 547,
#  '正片片长': 548,
#  '执行导演': 549,
#  '潜地速度': 550,
#  '活动时间': 551,
#  '水中速度': 552,
#  '力量': 553,
#  '行走速度': 554,
#  '飞行速度': 555,
#  '跳跃力': 556,
#  '变身道具': 557,
#  '人间体': 558,
#  '哥哥': 559,
#  '儿子': 560,
#  '婆婆': 561,
#  '石材编号': 562,
#  '主产地': 563,
#  '出品年份': 564,
#  '原著作者': 565,
#  '场务组长': 566,
#  '灯光': 567,
#  '服装、化妆': 568,
#  '制作周期': 569,
#  '现场制片': 570,
#  '摄影师': 571,
#  '梳妆': 572,
#  '英语': 573,
#  'belongwith': 574,
#  '弟弟': 575,
#  '养女': 576,
#  '经营范围': 577,
#  '作画': 578,
#  '种族': 579,
#  '欲求': 580,
#  '热线电话': 581,
#  '功效': 582,
#  '采集时间': 583,
#  '作画监督': 584,
#  '代理发行': 585,
#  '最新作品为': 586,
#  '说明': 587,
#  '举例': 588,
#  '出现剧集': 589,
#  '精通语言': 590,
#  '导演作品': 591,
#  '上映日期': 592,
#  'NBA选秀': 593,
#  '场上位置': 594,
#  '专业特点': 595,
#  '球衣号码': 596,
#  '最怕的事物': 597,
#  '职能': 598,
#  '推广公司': 599,
#  '体力': 600,
#  '武将定位': 601,
#  '势力': 602,
#  '称号': 603,
#  '画师': 604,
#  '技能': 605,
#  '车号': 606,
#  '处子秀': 607,
#  '最好成绩': 608,
#  '居住地': 609,
#  '总指挥': 610,
#  '领导者': 611,
#  '副总指挥': 612,
#  '总兵力': 613,
#  '下辖': 614,
#  '婚生子': 615,
#  '私生子': 616,
#  '情敌': 617,
#  '后任': 618,
#  '情人': 619,
#  '要素': 620,
#  '内涵': 621,
#  '医院院训': 622,
#  '游戏画面': 623,
#  '发行阶段': 624,
#  '目的': 625,
#  '外形': 626,
#  '名称来源': 627,
#  '同名游戏': 628,
#  '网站类型': 629,
#  '网站口号': 630,
#  '网站名称': 631,
#  '词语': 632,
#  '简体总笔画': 633,
#  '郑码': 634,
#  'UNICODE': 635,
#  '电码': 636,
#  '登场游戏': 637,
#  '主体': 638,
#  '或指': 639,
#  '作品': 640,
#  '行为': 641,
#  '大陆首播': 642,
#  '香港首播': 643,
#  '建立时间': 644,
#  '授权': 645,
#  '更新时间': 646,
#  '版本': 647,
#  '影响': 648,
#  '所属行业': 649,
#  '隶属': 650,
#  '创建时间': 651,
#  '主要有': 652,
#  '体现': 653,
#  '革命圣地': 654,
#  '笔名': 655,
#  '词性': 656,
#  '惯用脚': 657,
#  '曾效力球队': 658,
#  '地区生产总值': 659,
#  '企划': 660,
#  '工艺': 661,
#  '首播': 662,
#  '作词': 663,
#  '配乐': 664,
#  '出品方': 665,
#  '所属类别': 666,
#  '游戏引擎': 667,
#  '总监': 668,
#  '主治': 669,
#  '释名': 670,
#  '气味': 671,
#  '政治体制': 672,
#  '卫视口号': 673,
#  '卫视剧场': 674,
#  '地点': 675,
#  '昵称': 676,
#  '上星时间': 677,
#  '主打栏目': 678,
#  '视频格式': 679,
#  '公司性质': 680,
#  '公司口号': 681,
#  '播出方式': 682,
#  '出版方': 683,
#  '香港播出时间': 684,
#  '香港播出频道': 685,
#  '动词形式': 686,
#  '娱乐项目': 687,
#  '景点': 688,
#  '特色': 689,
#  '主角': 690,
#  '剧情类别': 691,
#  '完成字数': 692,
#  '厂房面积': 693,
#  '照明': 694,
#  '化妆师': 695,
#  '海报拍摄': 696,
#  '国内刊号': 697,
#  '国际刊号': 698,
#  '邮发代号': 699,
#  '创刊时间': 700,
#  '企业精神': 701,
#  '会长': 702,
#  '原著编剧': 703,
#  '爱奇艺': 704,
#  '腾讯视频': 705,
#  '人物原型': 706,
#  '公公': 707,
#  '侍从': 708,
#  '妹夫': 709,
#  '丈夫/挚爱': 710,
#  '养子': 711,
#  '笔画': 712,
#  '洪武正韵': 713,
#  '偏旁部首': 714,
#  '康熙笔画': 715,
#  '小学': 716,
#  '中学': 717,
#  '日文名': 718,
#  '擅长语言': 719,
#  '喜欢': 720,
#  '师兄': 721,
#  '声道': 722,
#  '外名别名': 723,
#  '猎人等级': 724,
#  '异能': 725,
#  '版面': 726,
#  '朋友': 727,
#  '担任职务': 728,
#  '就职': 729,
#  '象征': 730,
#  '司掌': 731,
#  '居所': 732,
#  '神话体系': 733,
#  '配偶': 734,
#  '所属': 735,
#  '开机时间': 736,
#  '获得奖项': 737,
#  '位分变化': 738,
#  '股票代码': 739,
#  '上市日期': 740,
#  '年营业额': 741,
#  '首席执行官': 742,
#  '上市地点': 743,
#  '董事局主席': 744,
#  '其他电视台': 745,
#  '状态': 746,
#  '现女友': 747,
#  '前女友': 748,
#  '行政级别': 749,
#  '混缩': 750,
#  '学科别称': 751,
#  '研究对象': 752,
#  '学科分类': 753,
#  '代表研究者': 754,
#  '现任主任': 755,
#  '语种': 756,
#  '出版日期': 757,
#  '完成时间': 758,
#  '维也纳马克': 759,
#  '应用平台': 760,
#  '应用版本': 761,
#  '应用名称': 762,
#  '人均GDP': 763,
#  'GDP': 764,
#  '古代名人': 765,
#  '原理': 766,
#  '学名': 767,
#  '单性本册数': 768,
#  '医院类型': 769,
#  '医保定点': 770,
#  '医院等级': 771,
#  '经济类型': 772,
#  '正式国名': 773,
#  '城市': 774,
#  '货币': 775,
#  '历史范围': 776,
#  '主要邦国': 777,
#  '族': 778,
#  '推广宣传': 779,
#  '执导': 780,
#  '相关术语': 781,
#  '学科分支': 782,
#  '演奏乐器': 783,
#  '音乐类型': 784,
#  '圈中好友': 785,
#  '出生年份': 786,
#  '网络名称': 787,
#  '姓名': 788,
#  '提供': 789,
#  '耕地面积': 790,
#  '行政代码': 791,
#  '名': 792,
#  '复姓': 793,
#  '发布人': 794,
#  '发布网站': 795,
#  '报道国家': 796,
#  '连载作品': 797,
#  '婚姻状况': 798,
#  '签约网站': 799,
#  '系别': 800,
#  '个性': 801,
#  '道路通行': 802,
#  '国际电话区号': 803,
#  '水域率': 804,
#  '人口数量': 805,
#  '国土面积': 806,
#  '英文名称': 807,
#  '国庆日': 808,
#  '人口密度': 809,
#  'GDP总计': 810,
#  '时区': 811,
#  '国际域名缩写': 812,
#  '国家代码': 813,
#  '国歌': 814,
#  '季数': 815,
#  '音频码率': 816,
#  '专职院士': 817,
#  '现任所长': 818,
#  '研究所地址': 819,
#  '丛书系列': 820,
#  '统一书号': 821,
#  '才艺': 822,
#  '应用学科': 823,
#  '应用范围': 824,
#  '总建筑面积': 825,
#  '首映地点': 826,
#  '香料分类': 827,
#  '种类': 828,
#  '香草分类': 829,
#  '医院': 830,
#  '医生姓名': 831,
#  '五大流派': 832,
#  '初始记载': 833,
#  '徒弟': 834,
#  '职权': 835,
#  '成员': 836,
#  '生活地点': 837,
#  '亚门': 838,
#  '食物': 839,
#  '灭绝原因': 840,
#  '灭绝时间': 841,
#  '背景': 842,
#  '文物等级': 843,
#  '曾用名': 844,
#  '用途': 845,
#  '制作者': 846,
#  '原作者': 847,
#  '投资特长': 848,
#  '公司': 849,
#  '研究领域': 850,
#  '闺蜜': 851,
#  '倾心之人': 852,
#  '方向': 853,
#  '正式成立': 854,
#  '相关典故': 855,
#  '总点击': 856,
#  '总字数': 857,
#  '作品类别': 858,
#  '首发网站': 859,
#  '连载进度': 860,
#  '总推荐': 861,
#  '首演时间': 862,
#  '手下': 863,
#  '能力': 864,
#  '弱点': 865,
#  '发表处': 866,
#  '发表时间': 867,
#  '世代': 868,
#  '师承': 869,
#  '创立时间': 870,
#  '职位': 871,
#  '总策划': 872,
#  '播出电视台': 873,
#  '史载': 874,
#  '现今位置': 875,
#  '所属山脉': 876,
#  '漫画地区': 877,
#  '融资状态': 878,
#  '模式': 879,
#  '深圳老字号': 880,
#  '恋情': 881,
#  '亚种': 882,
#  '宣传': 883,
#  '文案': 884,
#  '英雄定位': 885,
#  '最高等级': 886,
#  '魔法值': 887,
#  '攻击力': 888,
#  '定位': 889,
#  '现已重做': 890,
#  '生命值': 891,
#  '北临': 892,
#  '西临': 893,
#  '全村经济来源': 894,
#  '学生人数': 895,
#  '办学指导思想': 896,
#  '名誉校长': 897,
#  '职工人数': 898,
#  '当前版本': 899,
#  '应用语言': 900,
#  '高音区': 901,
#  '低音区': 902,
#  '命名人及年代': 903,
#  '格式': 904,
#  '症状表现': 905,
#  '进度': 906,
#  '环境': 907,
#  '玩法': 908,
#  '其他亲戚': 909,
#  '假扮样型': 910,
#  '土地面积': 911,
#  '提出人': 912,
#  '所属时代': 913,
#  '人物关系': 914,
#  '应用行业': 915,
#  '术语属性': 916,
#  '应用领域': 917,
#  '其他相关作品': 918,
#  '开始创作时间': 919,
#  '是否完结': 920,
#  '作品标签': 921,
#  '常住人口': 922,
#  '总面积': 923,
#  '五笔': 924,
#  '笔画数': 925,
#  '嗜好': 926,
#  '百度ID': 927,
#  '相关文献': 928,
#  '详细解释': 929,
#  '专辑类别': 930,
#  '出版地': 931,
#  '周刊': 932,
#  '适用领域范围': 933,
#  '表达式': 934,
#  '主营': 935,
#  '是否处方药': 936,
#  '包装': 937,
#  '成份': 938,
#  '药品名称': 939,
#  '特产': 940,
#  '画派': 941,
#  '标准': 942,
#  '差异': 943,
#  '山高': 944,
#  '位于': 945,
#  '规划': 946,
#  '半岛数量': 947,
#  '喜欢的音乐': 948,
#  '好感类型': 949,
#  '喜欢的作者': 950,
#  '喜欢的漫画': 951,
#  '速度': 952,
#  '游戏类别': 953,
#  '创立人': 954,
#  '养父': 955,
#  '生父': 956,
#  '生母': 957,
#  '追求者': 958,
#  '养母': 959,
#  '攻击属性': 960,
#  '港口': 961,
#  '颜色': 962,
#  '电影公司': 963,
#  '成名足迹': 964,
#  '雅号': 965,
#  '节目口号': 966,
#  '公测时间': 967,
#  '游戏题材': 968,
#  '口号': 969,
#  '参赛对象': 970,
#  '协办': 971,
#  '举办时间': 972,
#  '活动类型': 973,
#  '发展': 974,
#  '组成': 975,
#  '开始': 976,
#  'DNA的复制': 977,
#  '起源年代': 978,
#  '相关作品': 979,
#  '电影': 980,
#  '好处': 981,
#  '游戏分类': 982,
#  '号': 983,
#  '饰演者': 984,
#  '性格': 985,
#  '球衣颜色': 986,
#  '容纳人数': 987,
#  '现任主教练': 988,
#  '主场馆': 989,
#  '分区': 990,
#  '外号': 991,
#  '知名人物': 992,
#  '拥有者': 993,
#  '中文队名': 994,
#  '角逐赛事': 995,
#  '外文队名': 996,
#  '主要荣誉': 997,
#  '在位时间': 998,
#  '年号': 999,
#  ...}

# %%
kb_data[7:15]
# Out:
# [{'alias': ['滕王阁序'],
#   'subject_id': '10008',
#   'subject': '滕王阁序',
#   'type': ['Thing'],
#   'data': [{'predicate': '摘要', 'object': '《滕王阁序》是佚名的音乐作品,收录在《诗词歌赋大集合》专辑中。'},
#    {'predicate': '音乐时长', 'object': '3分50秒'},
#    {'predicate': '所属专辑', 'object': '诗词歌赋大集合'},
#    {'predicate': '义项描述', 'object': '佚名演唱歌曲'}]},
#  {'alias': ['莲宗寺'],
#   'subject_id': '10009',
#   'subject': '莲宗寺',
#   'type': ['Place'],
#   'data': [{'predicate': '摘要',
#     'object': '莲宗寺位于天津市和平区保安大街，是1949年后天津仅存的一座尼僧寺院。创建者际然法师在开山时所发的愿言“来僧不赶，去僧不留，自己不亲度徒众”的愿言，使此寺十方丛林的清严道风名闻遐迩。此道风被际然尼师的接班人圣慧法师继承至今，并将作为莲宗寺的传院家风而保留。2014年2月14日(正月十五)莲宗寺落地大修工程正式启动，莲宗寺所有宗教佛事活动均转移至莲宗寺临时活动道场进行(甘肃路32号，在甘肃路上万全道与鞍山道之间)。'},
#    {'predicate': '类型', 'object': '尼僧寺院'},
#    {'predicate': '中文名称', 'object': '莲宗寺'},
#    {'predicate': '占地面积', 'object': '一亩一分'},
#    {'predicate': '地理位置', 'object': '天津市和平区'},
#    {'predicate': '义项描述', 'object': '天津'},
#    {'predicate': '标签', 'object': '地理'},
#    {'predicate': '标签', 'object': '文化'},
#    {'predicate': '标签', 'object': '文物考古'},
#    {'predicate': '标签', 'object': '景观景点'},
#    {'predicate': '标签', 'object': '建筑'},
#    {'predicate': '标签', 'object': '历史'}]},
#  {'alias': ['裙子'],
#   'subject_id': '10010',
#   'subject': '裙子',
#   'type': ['Thing'],
#   'data': [{'predicate': '摘要',
#     'object': '《裙子》是一部由[瑞士]杰曼诺·祖罗所著图画书籍，新星出版社出版发行。'},
#    {'predicate': '作者', 'object': '[瑞士]杰曼诺·祖罗'},
#    {'predicate': 'ISBN', 'object': '9787513307017'},
#    {'predicate': '书名', 'object': '裙子'},
#    {'predicate': '出版社', 'object': '新星出版社'},
#    {'predicate': '义项描述', 'object': '[瑞士]杰曼诺·祖罗所著书籍'}]},
#  {'alias': ['东泉镇'],
#   'subject_id': '10011',
#   'subject': '东泉镇',
#   'type': ['Place'],
#   'data': [{'predicate': '摘要',
#     'object': '巴南区东温泉镇地处巴南区东部，巴南旅游双环线上。2001年7月，乡镇建制调整后由原来东泉、五布镇、天赐镇、清和乡合并而成。东与南川市白沙镇接壤，南与石龙镇、姜家镇为邻，西连二圣镇，北接木洞、丰盛镇。幅员面积122.70平方公里，耕地面积50862亩，其中田25376亩。镇政府所在地距重庆市区50余公里。现辖14个行政村、4个居委会、136个村民小组，总户数11869户，总人口37856人，其中农业人口35188人，非农业人口2668人。'},
#    {'predicate': '行政区类别', 'object': '重庆市'},
#    {'predicate': '所属地区', 'object': '重庆市巴南区'},
#    {'predicate': '下辖地区', 'object': '辖14个行政村、4个居委会'},
#    {'predicate': '电话区号', 'object': '023'},
#    {'predicate': '方言', 'object': '重庆方言'},
#    {'predicate': '邮政区码', 'object': '401320'},
#    {'predicate': '面积', 'object': '122.70平方公里'},
#    {'predicate': '车牌代码', 'object': '渝'},
#    {'predicate': '人口', 'object': '37856人'},
#    {'predicate': '著名景点', 'object': '东温泉'},
#    {'predicate': '中文名称', 'object': '巴南区东温泉镇'},
#    {'predicate': '气候条件', 'object': '亚热带湿润气候'},
#    {'predicate': '义项描述', 'object': '重庆市巴南区东温泉镇'},
#    {'predicate': '标签', 'object': '行政区划'},
#    {'predicate': '标签', 'object': '乡镇'}]},
#  {'alias': ['王峰'],
#   'subject_id': '10012',
#   'subject': '王峰',
#   'type': ['Human'],
#   'data': [{'predicate': '摘要',
#     'object': '王峰，男，蒙古族，1958年9月出生，内蒙古鄂托克旗人，中央党校大学学历，1980年1月加入中国共产党，1974年6月参加工作。现任内蒙古自治区鄂尔多斯市人大常委会主任、党组书记。'},
#    {'predicate': '出生地', 'object': '内蒙古鄂托克旗'},
#    {'predicate': '毕业院校', 'object': '中央党校'},
#    {'predicate': '中文名', 'object': '王峰'},
#    {'predicate': '国籍', 'object': '中国'},
#    {'predicate': '出生日期', 'object': '1958年9月'},
#    {'predicate': '民族', 'object': '蒙古族'},
#    {'predicate': '义项描述', 'object': '内蒙古鄂尔多斯市人大常委会主任'},
#    {'predicate': '标签', 'object': '政治人物'},
#    {'predicate': '标签', 'object': '人物'},
#    {'predicate': '标签', 'object': '官员'}]},
#  {'alias': ['男子汉大丈夫'],
#   'subject_id': '10013',
#   'subject': '男子汉大丈夫',
#   'type': ['CreativeWork'],
#   'data': [{'predicate': '摘要', 'object': '《男子汉大丈夫》是李海强填词谱曲并演唱的一首歌曲。'},
#    {'predicate': '歌曲原唱', 'object': '李海强'},
#    {'predicate': '谱曲', 'object': '李海强'},
#    {'predicate': '歌曲语言', 'object': '普通话'},
#    {'predicate': '填词', 'object': '李海强'},
#    {'predicate': '发行时间', 'object': '2015年3月10日'},
#    {'predicate': '中文名称', 'object': '男子汉大丈夫'},
#    {'predicate': '义项描述', 'object': '男子汉大丈夫-李海强歌曲'},
#    {'predicate': '标签', 'object': '人物'}]},
#  {'alias': ['Giovanni Boccaccio',
#    '乔万尼·薄伽丘',
#    '卜伽丘',
#    '薄伽丘',
#    '乔凡尼·卜迦丘',
#    '乔万尼·卜伽丘',
#    '薄伽丘，G.'],
#   'subject_id': '10014',
#   'subject': '乔万尼·薄伽丘',
#   'type': ['Human'],
#   'data': [{'predicate': '摘要',
#     'object': '乔万尼·薄伽丘(Giovanni Boccaccio，1313年——1375年12月21日)，意大利文艺复兴运动的杰出代表，人文主义杰出作家。与诗人但丁、彼特拉克并称为佛罗伦萨文学“三杰”。其代表作《十日谈》是欧洲文学史上第一部现实主义作品。它批判宗教守旧思想，主张“幸福在人间”，被视为文艺复兴的宣言。'},
#    {'predicate': '出生地', 'object': '巴黎或契塔尔多'},
#    {'predicate': '外文名', 'object': 'Giovanni Boccaccio'},
#    {'predicate': '逝世日期', 'object': '1375年12月21日'},
#    {'predicate': '星座', 'object': '双子座'},
#    {'predicate': '别名', 'object': '卜伽丘'},
#    {'predicate': '代表作品', 'object': '《十日谈》、《菲洛柯洛》、《苔塞伊达》《但丁传》'},
#    {'predicate': '中文名', 'object': '乔万尼·薄伽丘'},
#    {'predicate': '国籍', 'object': '佛罗伦萨共和国'},
#    {'predicate': '出生日期', 'object': '1313(癸丑年)6月16日'},
#    {'predicate': '职业', 'object': '作家，诗人'},
#    {'predicate': '民族', 'object': '意大利人'},
#    {'predicate': '主要成就', 'object': '意大利文艺复兴先驱，人文主义杰出作家'},
#    {'predicate': '义项描述', 'object': '乔万尼·薄伽丘'},
#    {'predicate': '标签', 'object': '人物'},
#    {'predicate': '标签', 'object': '文学家'},
#    {'predicate': '标签', 'object': '文学'}]},
#  {'alias': ['李青'],
#   'subject_id': '10015',
#   'subject': '李青',
#   'type': ['Human'],
#   'data': [{'predicate': '摘要',
#     'object': '李青，汉族，1972年出生，湖北应城人，女子跳水运动员，国际级运动健将，湖北省劳动模范。1988年4月，在中国国际跳水公开赛上获得跳板季军。1988年6月，在韩国汉城国际跳水获得跳板跳水冠军。'},
#    {'predicate': '出生地', 'object': '湖北应城'},
#    {'predicate': '中文名', 'object': '李青'},
#    {'predicate': '主要奖项',
#     'object': '1988年4月，在中国国际跳水公开赛上获得跳板季军,1988年6月，在韩国汉城国际跳水获得跳板跳水冠军。,湖北省劳动模范'},
#    {'predicate': '出生日期', 'object': '1972年'},
#    {'predicate': '国籍', 'object': '中国'},
#    {'predicate': '运动项目', 'object': '跳水'},
#    {'predicate': '性别', 'object': '女'},
#    {'predicate': '民族', 'object': '汉族'},
#    {'predicate': '义项描述', 'object': '女子跳水运动员'},
#    {'predicate': '标签', 'object': '游泳'},
#    {'predicate': '标签', 'object': '体育人物'},
#    {'predicate': '标签', 'object': '人物'},
#    {'predicate': '标签', 'object': '运动员'}]}]

# %%
spo = []
for item in tqdm(kb_data):
    subject_id = subject[item['subject_id']]
    for t_type in item['type']:
        spo.append([subject_id,predicate['type'],type_object[t_type]])
    for p in item['data']:
        if p['predicate'] == '摘要':continue
        spo.append([subject_id,predicate[p['predicate']],type_object[p['object']]])
# Out:
# 100%|██████████| 399252/399252 [00:07<00:00, 55923.03it/s]

# %%
with open('entity_embedding/train2id.txt','w') as f:
    #0 1 0
    f.write(str(len(spo))+'\n')
    for spo_line in spo:
        f.write(str(spo_line[0])+' '+str(spo_line[1])+' '+str(spo_line[2])+'\n')

# %%
# 14951
# /m/027rn	0
with open('entity_embedding/entity2id.txt','w') as f:
    f.write(str(len(type_object))+'\n')
    for key in type_object:
        f.write(str(key)+' '+str(type_object[key])+'\n')

# %%
with open('entity_embedding/relation2id.txt','w') as f:
    f.write(str(len(predicate))+'\n')
    for key in predicate:
        f.write(str(key)+' '+str(predicate[key])+'\n')

# %%
# gensim method

# %%
from gensim.models import word2vec
import jieba

sentence = []
for item in tqdm(kb_data):

    sentence.append([item['subject_id'],item['type'][0]])
    if item['subject_id'] == '172568':
        print('found it',[item['subject_id'],item['type'][0]])
    jieba.add_word(item['subject'],freq=10000)
    for t in item['data']:
        temp = []
        if t['predicate'] == '摘要':
            abstract = jieba.lcut(t['object'])
            for word in abstract:
                if word !=item['subject']:
                    temp.append(word)
                else:
                    temp.append(item['subject_id'])
            sentence.append(temp)
        else:
            temp.append(item['subject_id'])
            temp.append(t['predicate'])
            for w in jieba.lcut(t['object']):
                temp.append(w)
            sentence.append(temp)
# Out:
#  41%|████      | 162878/399252 [01:36<02:21, 1674.51it/s]
# found it ['172568', 'TVPlay']
# 100%|██████████| 399252/399252 [03:55<00:00, 1697.86it/s]

# %%
model = word2vec.Word2Vec(sentence, size=100, window=5, min_count=1, workers=10)
# 打印单词'good'的词向量
print(model.wv.word_vec('good'))
# 打印和'good'相似的前2个单词
print(model.wv.most_similar('good', topn=2))
# 保存模型到文件
model.save('embedding/w2v.model')
# Out:
# [-0.08884988 -0.43458417 -0.04649175  0.52209866  0.5967359   0.3575565
#   0.28515497  0.1681679  -0.26661298  0.578764   -0.03379836 -0.9270413
#  -0.17918614 -0.28689063 -0.425115    0.22716597  0.5265403   0.23897702
#  -0.37848145  0.03892595 -0.46802658  0.22492336  0.37370256 -0.71953994
#   0.586224   -0.2994675   0.35762447  0.7709816  -0.50722873  1.2170842
#  -0.06222146 -0.4186518  -0.12093468  0.93958956  0.07840901 -0.5593111
#  -0.23369573  0.09138527  0.5654404  -0.22509794 -0.15406132 -0.42482126
#   0.40492302  0.14890729  0.61443603 -0.55439657  0.691009   -0.20795709
#   1.0494735  -0.0156721   0.42399386 -0.2687647  -0.153714    0.4443031
#  -0.036926    0.69158703 -0.30075544 -0.78112525  0.62194276  0.13307565
#   0.7356175   0.48647153 -0.17589325 -0.14792234 -0.8359036   0.33305815
#   0.40223414 -0.13634983  0.57597816  0.39706823 -0.77788675  0.08536794
#  -0.7431647  -0.12798493  0.24313745  0.6899068  -0.42629093  0.1912721
#   0.29319683  0.5890647  -0.12232187  0.962851   -0.25115702  0.28590956
#   0.4250141   0.4182884  -0.5605426  -0.13405237  0.32765123 -0.13831052
#  -0.28827015  0.2808165  -0.18601036  0.09783139  0.15895608 -0.05440732
#   0.68253344  0.02665147 -0.30908358  0.8101575 ]
# [('not', 0.9241173267364502), ('life', 0.9188977479934692)]
# /home/zhukaihua/anaconda3/lib/python3.7/site-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
from gensim.models import Word2Vec

entity_embedding = Word2Vec.load('embedding/w2v.model')
print(entity_embedding.wv.word_vec('172568'))
# Out:
# /home/zhukaihua/anaconda3/lib/python3.7/site-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# [ 8.27378407e-03 -3.79925184e-02 -1.58234630e-02  1.61781558e-04
#  -2.86142603e-02 -2.23460961e-02 -2.19265912e-02  8.00999068e-03
#  -5.37989102e-03 -2.73190923e-02  2.27546301e-02 -1.44539550e-02
#   2.25096624e-02  2.10429654e-02 -5.57085173e-03 -8.84834863e-03
#   1.87226254e-02  1.79934446e-02 -3.44104460e-03 -1.56729221e-02
#   3.64831202e-02  2.98406612e-02  3.97054851e-02 -1.04410574e-05
#  -3.83564504e-04 -2.01038625e-02  1.63456518e-02  3.04100430e-03
#  -1.61068812e-02 -1.21692782e-02  3.31445523e-02 -1.17100738e-02
#  -3.69428238e-03 -1.38899963e-02 -4.49881190e-03 -2.61406880e-03
#  -1.77351397e-03  1.62939914e-02  1.41669279e-02 -9.99757927e-03
#   1.95471589e-02  3.56523017e-03 -5.01139229e-03  1.18404310e-02
#   1.45685277e-03  1.49886904e-03  4.46770377e-02  2.90570483e-02
#   2.26773564e-02  1.20850913e-02  3.44440783e-03  1.13797747e-02
#  -7.43344519e-03  5.65704610e-03  2.11350285e-02 -2.46288758e-02
#   7.81059265e-04  8.30001431e-04 -1.13808177e-02 -3.34872492e-02
#  -4.95162047e-03 -3.80223850e-03 -9.01823770e-03 -1.04030743e-02
#   2.43404675e-02 -3.94153688e-03 -8.28376599e-03 -7.21381558e-03
#   3.35547864e-03  2.79700290e-03 -1.65243782e-02 -1.74203666e-03
#  -1.24974120e-02  1.29126431e-02 -4.98306192e-03  4.26084884e-02
#  -4.88412008e-03  2.70248530e-03 -2.42321379e-02  3.49854939e-02
#  -2.75208931e-02  5.75407408e-02 -2.37570740e-02 -5.18212374e-03
#   1.38135385e-02 -1.34547716e-02  3.19078076e-03  4.56956401e-03
#   1.47649366e-02  3.32577503e-03  3.60064767e-02 -1.63791049e-02
#  -8.37693643e-03  2.37042317e-04  1.03412967e-04 -7.40302075e-03
#   2.48695295e-02  3.55921173e-03 -7.85816088e-03  1.65189151e-02]

# %%
kb['172568']
# Out:
# {'alias': ['only You'],
#  'subject_id': '172568',
#  'subject': '威尼斯',
#  'type': ['TVPlay'],
#  'data': []}

# %%
for item in tqdm(kb_data):
    if item['subject_id'] == '172568':
        print('found it')
# Out:
# 100%|██████████| 399252/399252 [00:00<00:00, 1251896.45it/s]
# found it
