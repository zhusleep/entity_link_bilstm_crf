# %%
"""
todo
三种方法：
1 gensim 训练　embedding
2 openKE 训练　embedding
3 openKE　分词训练　embedding　
"""
# Out:
# '\ntodo\n三种方法：\n1 gensim 训练\u3000embedding\n2 openKE 训练\u3000embedding\n3 openKE\u3000分词训练\u3000embedding\u3000\n'

# %%
# coding:u8
import json
import numpy as np
from collections import defaultdict
from tqdm import tqdm as tqdm

# %%
# 读取知识库
kb_data = []
kb = {}
with open('data/raw_data/kb_data','r') as f:
    for line in f:
        item = eval(str(json.loads(line)).lower())
        kb[item['subject_id']] = item
        kb_data.append(item)

# %%
kb_data[5:20]
# Out:
# [{'alias': ['王超'],
#   'subject_id': '10006',
#   'subject': '王超',
#   'type': ['human'],
#   'data': [{'predicate': '义项描述', 'object': '齐鲁书画研究院书画家'},
#    {'predicate': '标签', 'object': '人物'},
#    {'predicate': '标签', 'object': '艺术家'}]},
#  {'alias': ['无尽武道'],
#   'subject_id': '10007',
#   'subject': '无尽武道',
#   'type': ['creativework'],
#   'data': [{'predicate': '摘要',
#     'object': '《无尽武道》是一部爱情类的小说，作者是穿越梦竹，小说仍在连载中，连载网站是晋江文学城。'},
#    {'predicate': '连载网站', 'object': '晋江文学城'},
#    {'predicate': '小说进度', 'object': '连载'},
#    {'predicate': '作者', 'object': '穿越梦竹'},
#    {'predicate': '中文名', 'object': '无尽武道'},
#    {'predicate': '小说类型', 'object': '爱情'},
#    {'predicate': '义项描述', 'object': '穿越梦竹著作小说'},
#    {'predicate': '标签', 'object': '书籍'},
#    {'predicate': '标签', 'object': '小说作品'},
#    {'predicate': '标签', 'object': '中国文学'},
#    {'predicate': '标签', 'object': '文学作品'},
#    {'predicate': '标签', 'object': '小说'}]},
#  {'alias': ['滕王阁序'],
#   'subject_id': '10008',
#   'subject': '滕王阁序',
#   'type': ['thing'],
#   'data': [{'predicate': '摘要', 'object': '《滕王阁序》是佚名的音乐作品,收录在《诗词歌赋大集合》专辑中。'},
#    {'predicate': '音乐时长', 'object': '3分50秒'},
#    {'predicate': '所属专辑', 'object': '诗词歌赋大集合'},
#    {'predicate': '义项描述', 'object': '佚名演唱歌曲'}]},
#  {'alias': ['莲宗寺'],
#   'subject_id': '10009',
#   'subject': '莲宗寺',
#   'type': ['place'],
#   'data': [{'predicate': '摘要',
#     'object': '莲宗寺位于天津市和平区保安大街，是1949年后天津仅存的一座尼僧寺院。创建者际然法师在开山时所发的愿言“来僧不赶，去僧不留，自己不亲度徒众”的愿言，使此寺十方丛林的清严道风名闻遐迩。此道风被际然尼师的接班人圣慧法师继承至今，并将作为莲宗寺的传院家风而保留。2014年2月14日(正月十五)莲宗寺落地大修工程正式启动，莲宗寺所有宗教佛事活动均转移至莲宗寺临时活动道场进行(甘肃路32号，在甘肃路上万全道与鞍山道之间)。'},
#    {'predicate': '类型', 'object': '尼僧寺院'},
#    {'predicate': '中文名称', 'object': '莲宗寺'},
#    {'predicate': '占地面积', 'object': '一亩一分'},
#    {'predicate': '地理位置', 'object': '天津市和平区'},
#    {'predicate': '义项描述', 'object': '天津'},
#    {'predicate': '标签', 'object': '地理'},
#    {'predicate': '标签', 'object': '文化'},
#    {'predicate': '标签', 'object': '文物考古'},
#    {'predicate': '标签', 'object': '景观景点'},
#    {'predicate': '标签', 'object': '建筑'},
#    {'predicate': '标签', 'object': '历史'}]},
#  {'alias': ['裙子'],
#   'subject_id': '10010',
#   'subject': '裙子',
#   'type': ['thing'],
#   'data': [{'predicate': '摘要',
#     'object': '《裙子》是一部由[瑞士]杰曼诺·祖罗所著图画书籍，新星出版社出版发行。'},
#    {'predicate': '作者', 'object': '[瑞士]杰曼诺·祖罗'},
#    {'predicate': 'isbn', 'object': '9787513307017'},
#    {'predicate': '书名', 'object': '裙子'},
#    {'predicate': '出版社', 'object': '新星出版社'},
#    {'predicate': '义项描述', 'object': '[瑞士]杰曼诺·祖罗所著书籍'}]},
#  {'alias': ['东泉镇'],
#   'subject_id': '10011',
#   'subject': '东泉镇',
#   'type': ['place'],
#   'data': [{'predicate': '摘要',
#     'object': '巴南区东温泉镇地处巴南区东部，巴南旅游双环线上。2001年7月，乡镇建制调整后由原来东泉、五布镇、天赐镇、清和乡合并而成。东与南川市白沙镇接壤，南与石龙镇、姜家镇为邻，西连二圣镇，北接木洞、丰盛镇。幅员面积122.70平方公里，耕地面积50862亩，其中田25376亩。镇政府所在地距重庆市区50余公里。现辖14个行政村、4个居委会、136个村民小组，总户数11869户，总人口37856人，其中农业人口35188人，非农业人口2668人。'},
#    {'predicate': '行政区类别', 'object': '重庆市'},
#    {'predicate': '所属地区', 'object': '重庆市巴南区'},
#    {'predicate': '下辖地区', 'object': '辖14个行政村、4个居委会'},
#    {'predicate': '电话区号', 'object': '023'},
#    {'predicate': '方言', 'object': '重庆方言'},
#    {'predicate': '邮政区码', 'object': '401320'},
#    {'predicate': '面积', 'object': '122.70平方公里'},
#    {'predicate': '车牌代码', 'object': '渝'},
#    {'predicate': '人口', 'object': '37856人'},
#    {'predicate': '著名景点', 'object': '东温泉'},
#    {'predicate': '中文名称', 'object': '巴南区东温泉镇'},
#    {'predicate': '气候条件', 'object': '亚热带湿润气候'},
#    {'predicate': '义项描述', 'object': '重庆市巴南区东温泉镇'},
#    {'predicate': '标签', 'object': '行政区划'},
#    {'predicate': '标签', 'object': '乡镇'}]},
#  {'alias': ['王峰'],
#   'subject_id': '10012',
#   'subject': '王峰',
#   'type': ['human'],
#   'data': [{'predicate': '摘要',
#     'object': '王峰，男，蒙古族，1958年9月出生，内蒙古鄂托克旗人，中央党校大学学历，1980年1月加入中国共产党，1974年6月参加工作。现任内蒙古自治区鄂尔多斯市人大常委会主任、党组书记。'},
#    {'predicate': '出生地', 'object': '内蒙古鄂托克旗'},
#    {'predicate': '毕业院校', 'object': '中央党校'},
#    {'predicate': '中文名', 'object': '王峰'},
#    {'predicate': '国籍', 'object': '中国'},
#    {'predicate': '出生日期', 'object': '1958年9月'},
#    {'predicate': '民族', 'object': '蒙古族'},
#    {'predicate': '义项描述', 'object': '内蒙古鄂尔多斯市人大常委会主任'},
#    {'predicate': '标签', 'object': '政治人物'},
#    {'predicate': '标签', 'object': '人物'},
#    {'predicate': '标签', 'object': '官员'}]},
#  {'alias': ['男子汉大丈夫'],
#   'subject_id': '10013',
#   'subject': '男子汉大丈夫',
#   'type': ['creativework'],
#   'data': [{'predicate': '摘要', 'object': '《男子汉大丈夫》是李海强填词谱曲并演唱的一首歌曲。'},
#    {'predicate': '歌曲原唱', 'object': '李海强'},
#    {'predicate': '谱曲', 'object': '李海强'},
#    {'predicate': '歌曲语言', 'object': '普通话'},
#    {'predicate': '填词', 'object': '李海强'},
#    {'predicate': '发行时间', 'object': '2015年3月10日'},
#    {'predicate': '中文名称', 'object': '男子汉大丈夫'},
#    {'predicate': '义项描述', 'object': '男子汉大丈夫-李海强歌曲'},
#    {'predicate': '标签', 'object': '人物'}]},
#  {'alias': ['giovanni boccaccio',
#    '乔万尼·薄伽丘',
#    '卜伽丘',
#    '薄伽丘',
#    '乔凡尼·卜迦丘',
#    '乔万尼·卜伽丘',
#    '薄伽丘，g.'],
#   'subject_id': '10014',
#   'subject': '乔万尼·薄伽丘',
#   'type': ['human'],
#   'data': [{'predicate': '摘要',
#     'object': '乔万尼·薄伽丘(giovanni boccaccio，1313年——1375年12月21日)，意大利文艺复兴运动的杰出代表，人文主义杰出作家。与诗人但丁、彼特拉克并称为佛罗伦萨文学“三杰”。其代表作《十日谈》是欧洲文学史上第一部现实主义作品。它批判宗教守旧思想，主张“幸福在人间”，被视为文艺复兴的宣言。'},
#    {'predicate': '出生地', 'object': '巴黎或契塔尔多'},
#    {'predicate': '外文名', 'object': 'giovanni boccaccio'},
#    {'predicate': '逝世日期', 'object': '1375年12月21日'},
#    {'predicate': '星座', 'object': '双子座'},
#    {'predicate': '别名', 'object': '卜伽丘'},
#    {'predicate': '代表作品', 'object': '《十日谈》、《菲洛柯洛》、《苔塞伊达》《但丁传》'},
#    {'predicate': '中文名', 'object': '乔万尼·薄伽丘'},
#    {'predicate': '国籍', 'object': '佛罗伦萨共和国'},
#    {'predicate': '出生日期', 'object': '1313(癸丑年)6月16日'},
#    {'predicate': '职业', 'object': '作家，诗人'},
#    {'predicate': '民族', 'object': '意大利人'},
#    {'predicate': '主要成就', 'object': '意大利文艺复兴先驱，人文主义杰出作家'},
#    {'predicate': '义项描述', 'object': '乔万尼·薄伽丘'},
#    {'predicate': '标签', 'object': '人物'},
#    {'predicate': '标签', 'object': '文学家'},
#    {'predicate': '标签', 'object': '文学'}]},
#  {'alias': ['李青'],
#   'subject_id': '10015',
#   'subject': '李青',
#   'type': ['human'],
#   'data': [{'predicate': '摘要',
#     'object': '李青，汉族，1972年出生，湖北应城人，女子跳水运动员，国际级运动健将，湖北省劳动模范。1988年4月，在中国国际跳水公开赛上获得跳板季军。1988年6月，在韩国汉城国际跳水获得跳板跳水冠军。'},
#    {'predicate': '出生地', 'object': '湖北应城'},
#    {'predicate': '中文名', 'object': '李青'},
#    {'predicate': '主要奖项',
#     'object': '1988年4月，在中国国际跳水公开赛上获得跳板季军,1988年6月，在韩国汉城国际跳水获得跳板跳水冠军。,湖北省劳动模范'},
#    {'predicate': '出生日期', 'object': '1972年'},
#    {'predicate': '国籍', 'object': '中国'},
#    {'predicate': '运动项目', 'object': '跳水'},
#    {'predicate': '性别', 'object': '女'},
#    {'predicate': '民族', 'object': '汉族'},
#    {'predicate': '义项描述', 'object': '女子跳水运动员'},
#    {'predicate': '标签', 'object': '游泳'},
#    {'predicate': '标签', 'object': '体育人物'},
#    {'predicate': '标签', 'object': '人物'},
#    {'predicate': '标签', 'object': '运动员'}]},
#  {'alias': ['salty soy milk', '咸豆浆', 'xían dòu jiāng'],
#   'subject_id': '10016',
#   'subject': '咸豆浆',
#   'type': ['movie'],
#   'data': [{'predicate': '摘要',
#     'object': '《咸豆浆》是2002年上映的台湾电影，由王明台导演。范植伟，马志翔等人主演。《咸豆浆》讲述明贤深爱著他所不该爱的静芬，因为静芬已经有了在pub演唱的男友阿翔。但也因为他心中无怨无悔的爱，他毫不犹豫地答应了静芬一块从事仙人跳的勾当，目的却是为了要买一把吉他送给阿翔。陪著明贤一起做出拒绝联考的决定，启文不仅失去了女友，彷佛也失去了对自我生命的自信。这时候，他发现楼下的神秘女郎总被一个黑道大哥欺负，他的心中突然萌生了为解救女郎而和黑道大哥奋力对抗的勇敢念头。'},
#    {'predicate': '出品时间', 'object': '2002'},
#    {'predicate': '导演', 'object': '王明台'},
#    {'predicate': '制片地区', 'object': '中国台湾'},
#    {'predicate': '外文名', 'object': 'salty soy milk'},
#    {'predicate': '片长', 'object': '103分钟'},
#    {'predicate': '对白语言', 'object': '汉语普通话，台语'},
#    {'predicate': '编剧', 'object': '王明台'},
#    {'predicate': '中文名', 'object': '咸豆浆'},
#    {'predicate': '上映时间', 'object': '2002年'},
#    {'predicate': '主演', 'object': '范植伟，马志翔，简沛恩，黄嘉千'},
#    {'predicate': '类型', 'object': '剧情'},
#    {'predicate': '其它译名', 'object': 'xían dòu jiāng'},
#    {'predicate': '义项描述', 'object': '2002年王明台执导电影'},
#    {'predicate': '标签', 'object': '娱乐作品'},
#    {'predicate': '标签', 'object': '电影作品'},
#    {'predicate': '标签', 'object': '剧情电影'},
#    {'predicate': '标签', 'object': '台湾电影'}]},
#  {'alias': ['guan jian', '关键'],
#   'subject_id': '10017',
#   'subject': '关键',
#   'type': ['entertainmentperson'],
#   'data': [{'predicate': '摘要',
#     'object': '关键，出生于中华人民共和国，cctv-7《军事报道》节目主持人，陆军中校军衔。'},
#    {'predicate': '外文名', 'object': 'guan jian'},
#    {'predicate': '军衔', 'object': '中校'},
#    {'predicate': '中文名', 'object': '关键'},
#    {'predicate': '代表作品', 'object': '《军事报道》'},
#    {'predicate': '所属公司', 'object': '中国中央电视台'},
#    {'predicate': '国籍', 'object': '中华人民共和国'},
#    {'predicate': '所属军队', 'object': '中国人民解放军总政治部'},
#    {'predicate': '职业', 'object': '主持人、军人'},
#    {'predicate': '民族', 'object': '汉族'},
#    {'predicate': '义项描述', 'object': '中央电视台军事报道节目主持人'}]},
#  {'alias': ['周永康', '香港周永康'],
#   'subject_id': '10018',
#   'subject': '周永康',
#   'type': ['human'],
#   'data': [{'predicate': '摘要',
#     'object': '周永康，汉族，香港大学学生，香港“占中运动”发起者，并且担任“占中运动”领导。2018年2月6日，周永康就闯入政府总部东翼前地案被改判监后提出上诉，终审法院裁定3人上诉成功，维持原审判决。'},
#    {'predicate': '毕业院校', 'object': '香港大学'},
#    {'predicate': '中文名', 'object': '周永康'},
#    {'predicate': '主要成就', 'object': '发起香港占中运动，并担任领导'},
#    {'predicate': '国籍', 'object': '中华人民共和国'},
#    {'predicate': '职业', 'object': '学生'},
#    {'predicate': '民族', 'object': '汉族'},
#    {'predicate': '义项描述', 'object': '香港学联秘书长'},
#    {'predicate': '标签', 'object': '人物'}]},
#  {'alias': ['郭斌'],
#   'subject_id': '10019',
#   'subject': '郭斌',
#   'type': ['human'],
#   'data': [{'predicate': '摘要', 'object': '男，经济学与金融学系，副教授，学历：博士。'},
#    {'predicate': '性别', 'object': '男'},
#    {'predicate': '职业', 'object': '副教授'},
#    {'predicate': '学位', 'object': '博士'},
#    {'predicate': '中文名', 'object': '郭斌'},
#    {'predicate': '义项描述', 'object': '电子科技大学经济学与金融学系教授'},
#    {'predicate': '标签', 'object': '行业人物'},
#    {'predicate': '标签', 'object': '人物'},
#    {'predicate': '标签', 'object': '科研人员'},
#    {'predicate': '标签', 'object': '教师'}]},
#  {'alias': ['食尸鬼2012', '盗墓者'],
#   'subject_id': '10020',
#   'subject': '食尸鬼2012',
#   'type': ['movie'],
#   'data': [{'predicate': '摘要',
#     'object': '《食尸鬼2012》是2012年上映的美国恐怖电影，由gary jones执导，诺兰·古尔德、安德烈等主演。影片讲述了公共墓地有某种恐怖物体在不停游荡，潜伏的恶魔伤害人类的故事。'},
#    {'predicate': '导演', 'object': 'gary jones'},
#    {'predicate': '制片地区', 'object': '美国'},
#    {'predicate': '片长', 'object': '80分钟'},
#    {'predicate': '对白语言', 'object': '英语'},
#    {'predicate': '中文名', 'object': '食尸鬼2012'},
#    {'predicate': '上映时间', 'object': '2012年'},
#    {'predicate': '类型', 'object': '剧情 / 悬疑 / 惊悚 / 恐怖'},
#    {'predicate': '其它译名', 'object': '盗墓者'},
#    {'predicate': '义项描述', 'object': '食尸鬼2012'},
#    {'predicate': '标签', 'object': '娱乐作品'},
#    {'predicate': '标签', 'object': '电影作品'},
#    {'predicate': '标签', 'object': '惊悚电影'},
#    {'predicate': '标签', 'object': '剧情电影'},
#    {'predicate': '标签', 'object': '电影'}]}]

# %%
# OpenKE 默认方法

# %%
predicate = {}
subject = {}
type_object = {}

# %%
for item in tqdm(kb_data):
    if item['subject_id'] not in subject:
        subject[item['subject_id']] = len(subject)
    for t in item['data']:
        if t['predicate'] == '摘要':continue
        if t['predicate'] not in predicate:
            predicate[t['predicate']] = len(predicate)
        if t['object'] not in type_object:
            type_object[t['object']] = len(type_object)
    for t_type in item['type']:
        if t_type not in type_object:
            type_object[t_type] = len(type_object)
if 'type' not in predicate:
    predicate['type'] = len(predicate)
# Out:
# 100%|██████████| 399252/399252 [00:03<00:00, 102765.64it/s]

# %%
predicate
# Out:
# {'制作方': 0,
#  '外文名': 1,
#  '来源': 2,
#  '中文名': 3,
#  '属性': 4,
#  '义项描述': 5,
#  '歌曲原唱': 6,
#  '谱曲': 7,
#  '歌曲时长': 8,
#  '歌曲语言': 9,
#  '音乐风格': 10,
#  '唱片公司': 11,
#  '翻唱': 12,
#  '填词': 13,
#  '发行时间': 14,
#  '中文名称': 15,
#  '所属专辑': 16,
#  '标签': 17,
#  '亚目': 18,
#  '别称': 19,
#  '种': 20,
#  '界': 21,
#  '目': 22,
#  '科': 23,
#  '拉丁学名': 24,
#  '纲': 25,
#  '门': 26,
#  '中文学名': 27,
#  '亚科': 28,
#  '亚纲': 29,
#  '出生地': 30,
#  '爵位': 31,
#  '官职': 32,
#  '所处时代': 33,
#  '本名': 34,
#  '字号': 35,
#  '民族族群': 36,
#  '主要成就': 37,
#  '去世时间': 38,
#  '连载网站': 39,
#  '小说进度': 40,
#  '作者': 41,
#  '小说类型': 42,
#  '音乐时长': 43,
#  '类型': 44,
#  '占地面积': 45,
#  '地理位置': 46,
#  'isbn': 47,
#  '书名': 48,
#  '出版社': 49,
#  '行政区类别': 50,
#  '所属地区': 51,
#  '下辖地区': 52,
#  '电话区号': 53,
#  '方言': 54,
#  '邮政区码': 55,
#  '面积': 56,
#  '车牌代码': 57,
#  '人口': 58,
#  '著名景点': 59,
#  '气候条件': 60,
#  '毕业院校': 61,
#  '国籍': 62,
#  '出生日期': 63,
#  '民族': 64,
#  '逝世日期': 65,
#  '星座': 66,
#  '别名': 67,
#  '代表作品': 68,
#  '职业': 69,
#  '主要奖项': 70,
#  '运动项目': 71,
#  '性别': 72,
#  '出品时间': 73,
#  '导演': 74,
#  '制片地区': 75,
#  '片长': 76,
#  '对白语言': 77,
#  '编剧': 78,
#  '上映时间': 79,
#  '主演': 80,
#  '其它译名': 81,
#  '军衔': 82,
#  '所属公司': 83,
#  '所属军队': 84,
#  '学位': 85,
#  '登场作品': 86,
#  '配音': 87,
#  '饰演': 88,
#  '开本': 89,
#  '制片人': 90,
#  '色彩': 91,
#  '出品公司': 92,
#  '语言': 93,
#  '歌手': 94,
#  '拼音': 95,
#  '注音': 96,
#  '最新章节': 97,
#  '连载平台': 98,
#  '连载状态': 99,
#  '是否出版': 100,
#  '作曲': 101,
#  '装帧': 102,
#  '页数': 103,
#  '定价': 104,
#  '出版时间': 105,
#  '缩写': 106,
#  '原名': 107,
#  '含义': 108,
#  '影响因素': 109,
#  '温度数据': 110,
#  '信仰': 111,
#  '幅面': 112,
#  'imdb编码': 113,
#  '分级': 114,
#  '软件名称': 115,
#  '软件平台': 116,
#  '软件版本': 117,
#  '声优': 118,
#  '编曲': 119,
#  '读音': 120,
#  '解释': 121,
#  '出处': 122,
#  '分类': 123,
#  '其他名称': 124,
#  '执业地点': 125,
#  '临床职称': 126,
#  '节目方式': 127,
#  '地址': 128,
#  '内容': 129,
#  '游戏类型': 130,
#  '首播时间': 131,
#  '国家/地区': 132,
#  '播出频道': 133,
#  '播出状态': 134,
#  '主持人': 135,
#  '每季期数': 136,
#  '每集长度': 137,
#  '季度冠名': 138,
#  '主要嘉宾': 139,
#  '外文名称': 140,
#  '播出时间': 141,
#  '制作公司': 142,
#  '在线播放平台': 143,
#  '海拔': 144,
#  '授权状态': 145,
#  '写作进程': 146,
#  '小说类别': 147,
#  '身高': 148,
#  '作品名称': 149,
#  '作品别名': 150,
#  '文学体裁': 151,
#  '创作年代': 152,
#  '代表作': 153,
#  '原版名称': 154,
#  '地区': 155,
#  '其他出版社': 156,
#  '插画': 157,
#  '学历': 158,
#  '参加工作': 159,
#  '发行公司': 160,
#  '乐器普遍音阶': 161,
#  '应用谱号': 162,
#  '任职': 163,
#  '副标题': 164,
#  '集数': 165,
#  '拍摄地点': 166,
#  '拍摄日期': 167,
#  '票房': 168,
#  '译者': 169,
#  '演唱者': 170,
#  '亦作': 171,
#  '出自': 172,
#  '释义': 173,
#  '原作': 174,
#  '出版期间': 175,
#  '实质': 176,
#  '用处': 177,
#  '所属系列': 178,
#  '游戏大小': 179,
#  '具体内容': 180,
#  '单位': 181,
#  '简写': 182,
#  '血型': 183,
#  '经纪人': 184,
#  '体重': 185,
#  '经纪公司': 186,
#  '字数': 187,
#  '妻子': 188,
#  '女儿': 189,
#  '年龄': 190,
#  '变身者': 191,
#  '机场': 192,
#  '分布区域': 193,
#  '采收时间': 194,
#  '用量': 195,
#  '毒性': 196,
#  '属': 197,
#  '单行本册数': 198,
#  '连载期间': 199,
#  '连载杂志': 200,
#  '类别': 201,
#  '形成地点': 202,
#  '形成时间': 203,
#  '评分': 204,
#  '嘉宾主持': 205,
#  '制片成本': 206,
#  '主唱': 207,
#  '成立时间': 208,
#  '吉他': 209,
#  '鼓手': 210,
#  '贝斯': 211,
#  '首播频道': 212,
#  '音乐谱曲': 213,
#  '衍生剧': 214,
#  'imdb评分': 215,
#  '地位': 216,
#  '发行': 217,
#  '政治面貌': 218,
#  '职称': 219,
#  '原曲': 220,
#  '动作': 221,
#  '符号': 222,
#  '所属国家': 223,
#  '源于': 224,
#  '曾任职务': 225,
#  '调查时间': 226,
#  '首次登场': 227,
#  '定义': 228,
#  '所属学科': 229,
#  '栏目特点': 230,
#  '栏目介绍': 231,
#  '揭载号': 232,
#  '日语': 233,
#  '创始人': 234,
#  '梵名': 235,
#  '出生时间': 236,
#  '兄弟': 237,
#  '父亲': 238,
#  '又名': 239,
#  '国家领袖': 240,
#  '简称': 241,
#  '所处时期': 242,
#  '主要城市': 243,
#  '首都': 244,
#  '脚本': 245,
#  '更新': 246,
#  '摄影指导': 247,
#  '上映平台': 248,
#  '专辑': 249,
#  '演唱': 250,
#  '混音': 251,
#  '录音': 252,
#  '和声': 253,
#  '反义词': 254,
#  '侄子': 255,
#  '最难忘的': 256,
#  '挚爱&初恋': 257,
#  '定情信物': 258,
#  '兴趣': 259,
#  '卫视首播': 260,
#  '拍摄时间': 261,
#  '专业': 262,
#  '专辑语言': 263,
#  '专辑歌手': 264,
#  '发行地区': 265,
#  '片尾曲': 266,
#  '卡牌品质': 267,
#  '特征': 268,
#  '优点': 269,
#  '性质': 270,
#  '谥号': 271,
#  '主要配音': 272,
#  '动画制作': 273,
#  '音乐': 274,
#  '播放期间': 275,
#  '出品': 276,
#  '角色设计': 277,
#  '网络播放': 278,
#  '剧本': 279,
#  '首播电视台': 280,
#  '适用': 281,
#  '涵义': 282,
#  '注重': 283,
#  '中药名称': 284,
#  '主办单位': 285,
#  '主管单位': 286,
#  '编辑单位': 287,
#  '出版周期': 288,
#  '誉为': 289,
#  '又称': 290,
#  '原产于': 291,
#  '提出者': 292,
#  '提出时间': 293,
#  '最喜欢的颜色': 294,
#  '最喜欢的演员': 295,
#  '祖籍': 296,
#  '羁绊': 297,
#  '伙伴': 298,
#  '生日': 299,
#  '职务': 300,
#  '学位/学历': 301,
#  '词目': 302,
#  '示例': 303,
#  '品牌': 304,
#  '丛书': 305,
#  '火车站': 306,
#  '政府驻地': 307,
#  '外来人口': 308,
#  '首任校长': 309,
#  '创办时间': 310,
#  '主要院系': 311,
#  '校训': 312,
#  '末任校长': 313,
#  '知名校友': 314,
#  '作品体裁': 315,
#  '词牌': 316,
#  '作品出处': 317,
#  '意义': 318,
#  '做法': 319,
#  '主要基地': 320,
#  '机队情况': 321,
#  '总部地点': 322,
#  '两字代码': 323,
#  '公司名称': 324,
#  '剧本策划': 325,
#  '官方微博': 326,
#  '百度贴吧': 327,
#  '出品人': 328,
#  '美术': 329,
#  '联合摄制': 330,
#  '赛区': 331,
#  '上星平台': 332,
#  '首播平台': 333,
#  '作用': 334,
#  '知名教授': 335,
#  '现任校长': 336,
#  '粉丝名': 337,
#  '公益基金': 338,
#  '生肖': 339,
#  '应援色': 340,
#  '就读学校': 341,
#  '特长': 342,
#  '主要作品': 343,
#  '魔法': 344,
#  '害怕的东西': 345,
#  '喜欢的东西': 346,
#  '药效': 347,
#  '来历': 348,
#  '本质': 349,
#  '相对': 350,
#  '录音师': 351,
#  '制作人': 352,
#  '混音师': 353,
#  'mv导演': 354,
#  'mv出演': 355,
#  '籍贯': 356,
#  '创作时间': 357,
#  '副局长': 358,
#  '官网': 359,
#  '员工': 360,
#  '总部': 361,
#  '局长': 362,
#  '学校类型': 363,
#  '主管部门': 364,
#  '英文名': 365,
#  '博士后流动站': 366,
#  '目标定位': 367,
#  '长江学者': 368,
#  '硕士点': 369,
#  '党委书记': 370,
#  '国家重点学科': 371,
#  '学校代码': 372,
#  '博士点': 373,
#  '学校地址': 374,
#  '校歌': 375,
#  '教学职称': 376,
#  '专属驾驶员': 377,
#  '等级': 378,
#  '喜欢的明星': 379,
#  '微博': 380,
#  '粉丝口号': 381,
#  '粉丝称呼': 382,
#  '开发公司': 383,
#  '运营公司': 384,
#  '软件大小': 385,
#  '软件语言': 386,
#  '操作平台': 387,
#  '更新日期': 388,
#  '收费模式': 389,
#  '分享类型': 390,
#  '基本解释': 391,
#  '剧种': 392,
#  '时间': 393,
#  '座右铭': 394,
#  '陵墓': 395,
#  '上市时间': 396,
#  '生产状态': 397,
#  '品牌类型': 398,
#  '指导价': 399,
#  '生产厂家': 400,
#  '排量': 401,
#  '近义词': 402,
#  '感情色彩': 403,
#  '比喻义': 404,
#  '时段': 405,
#  '挚友': 406,
#  '喜欢的人': 407,
#  '妹妹': 408,
#  '爱丽丝能力': 409,
#  '爱丽丝石颜色': 410,
#  '母亲': 411,
#  '爱丽丝系别': 412,
#  '星阶级': 413,
#  '玩家人数': 414,
#  '游戏平台': 415,
#  '发行日期': 416,
#  '开发商': 417,
#  '发行商': 418,
#  '出生年月': 419,
#  '化学式': 420,
#  '外观': 421,
#  '沸点': 422,
#  '闪点': 423,
#  '熔点': 424,
#  '密度': 425,
#  '水溶性': 426,
#  '应用': 427,
#  '内容主题': 428,
#  '对象': 429,
#  '表现': 430,
#  '创作灵感': 431,
#  '意指': 432,
#  '同义词': 433,
#  '公会口号': 434,
#  '公会创始人': 435,
#  '身份证前六位': 436,
#  '所属运动队': 437,
#  '重要事件': 438,
#  '职责': 439,
#  '推出': 440,
#  '英文': 441,
#  '主要势力': 442,
#  '所属组合': 443,
#  '家庭成员': 444,
#  '爱好': 445,
#  '宗教': 446,
#  '生活地域': 447,
#  '发现者': 448,
#  '魅力': 449,
#  '标志物': 450,
#  '中国获奖导演': 451,
#  '属于': 452,
#  '开始颁发时间': 453,
#  '曲目数量': 454,
#  '专辑时长': 455,
#  '唱片销量': 456,
#  '所属洲': 457,
#  '国家': 458,
#  '编号': 459,
#  '情报': 460,
#  '儿女': 461,
#  '队伍': 462,
#  '丈夫': 463,
#  '前世': 464,
#  '初恋': 465,
#  '武器': 466,
#  '好友': 467,
#  '年代': 468,
#  '身份': 469,
#  '摄制格式': 470,
#  '功能': 471,
#  '洗印格式': 472,
#  '员工数': 473,
#  '版权公司': 474,
#  '最新版本': 475,
#  '特技': 476,
#  '最早版本': 477,
#  '原型': 478,
#  '搭档': 479,
#  '师父': 480,
#  '州府': 481,
#  '总人口': 482,
#  '主要民族': 483,
#  '主要宗教': 484,
#  '平均寿命': 485,
#  '官方语言': 486,
#  '位置': 487,
#  '两支支流': 488,
#  '胶片长度': 489,
#  '栏目': 490,
#  '录制频道': 491,
#  '全称': 492,
#  '旧名': 493,
#  '赐名时间': 494,
#  '始建于': 495,
#  '监制': 496,
#  '原著': 497,
#  '二名法': 498,
#  '特点': 499,
#  '拉丁': 500,
#  '注释': 501,
#  '笔顺编号': 502,
#  '部外笔画': 503,
#  '部首': 504,
#  '仓颉': 505,
#  '四角号码': 506,
#  '五笔86': 507,
#  'unicode': 508,
#  '总笔画': 509,
#  '五笔98': 510,
#  '统一汉字': 511,
#  '主要客运工具': 512,
#  '包括': 513,
#  '气候类型': 514,
#  '门票价格': 515,
#  '开放时间': 516,
#  '景点级别': 517,
#  '专业方向': 518,
#  '学术代表作': 519,
#  '仓颉遗迹': 520,
#  '类似': 521,
#  '拉丁名': 522,
#  '科属': 523,
#  '原产': 524,
#  '旧友': 525,
#  '网站类别': 526,
#  '涉及范围': 527,
#  '从事': 528,
#  '产生根源': 529,
#  '组织门派': 530,
#  '上司': 531,
#  '同修': 532,
#  '根据地': 533,
#  '现任': 534,
#  '简介': 535,
#  '录混': 536,
#  '糖果王国': 537,
#  '游戏': 538,
#  '花果岛': 539,
#  '演奏': 540,
#  '流派': 541,
#  '主要角色': 542,
#  '字': 543,
#  '灼华信息': 544,
#  '制片': 545,
#  '总监制': 546,
#  '正片片长': 547,
#  '执行导演': 548,
#  '潜地速度': 549,
#  '活动时间': 550,
#  '水中速度': 551,
#  '力量': 552,
#  '行走速度': 553,
#  '飞行速度': 554,
#  '跳跃力': 555,
#  '变身道具': 556,
#  '人间体': 557,
#  '哥哥': 558,
#  '儿子': 559,
#  '婆婆': 560,
#  '石材编号': 561,
#  '主产地': 562,
#  '出品年份': 563,
#  '原著作者': 564,
#  '场务组长': 565,
#  '灯光': 566,
#  '服装、化妆': 567,
#  '制作周期': 568,
#  '现场制片': 569,
#  '摄影师': 570,
#  '梳妆': 571,
#  '英语': 572,
#  'belongwith': 573,
#  '弟弟': 574,
#  '养女': 575,
#  '经营范围': 576,
#  '作画': 577,
#  '种族': 578,
#  '欲求': 579,
#  '热线电话': 580,
#  '功效': 581,
#  '采集时间': 582,
#  '作画监督': 583,
#  '代理发行': 584,
#  '最新作品为': 585,
#  '说明': 586,
#  '举例': 587,
#  '出现剧集': 588,
#  '精通语言': 589,
#  '导演作品': 590,
#  '上映日期': 591,
#  'nba选秀': 592,
#  '场上位置': 593,
#  '专业特点': 594,
#  '球衣号码': 595,
#  '最怕的事物': 596,
#  '职能': 597,
#  '推广公司': 598,
#  '体力': 599,
#  '武将定位': 600,
#  '势力': 601,
#  '称号': 602,
#  '画师': 603,
#  '技能': 604,
#  '车号': 605,
#  '处子秀': 606,
#  '最好成绩': 607,
#  '居住地': 608,
#  '总指挥': 609,
#  '领导者': 610,
#  '副总指挥': 611,
#  '总兵力': 612,
#  '下辖': 613,
#  '婚生子': 614,
#  '私生子': 615,
#  '情敌': 616,
#  '后任': 617,
#  '情人': 618,
#  '要素': 619,
#  '内涵': 620,
#  '医院院训': 621,
#  '游戏画面': 622,
#  '发行阶段': 623,
#  '目的': 624,
#  '外形': 625,
#  '名称来源': 626,
#  '同名游戏': 627,
#  '网站类型': 628,
#  '网站口号': 629,
#  '网站名称': 630,
#  '词语': 631,
#  '简体总笔画': 632,
#  '郑码': 633,
#  '电码': 634,
#  '登场游戏': 635,
#  '主体': 636,
#  '或指': 637,
#  '作品': 638,
#  '行为': 639,
#  '大陆首播': 640,
#  '香港首播': 641,
#  '建立时间': 642,
#  '授权': 643,
#  '更新时间': 644,
#  '版本': 645,
#  '影响': 646,
#  '所属行业': 647,
#  '隶属': 648,
#  '创建时间': 649,
#  '主要有': 650,
#  '体现': 651,
#  '革命圣地': 652,
#  '笔名': 653,
#  '词性': 654,
#  '惯用脚': 655,
#  '曾效力球队': 656,
#  '地区生产总值': 657,
#  '企划': 658,
#  '工艺': 659,
#  '首播': 660,
#  '作词': 661,
#  '配乐': 662,
#  '出品方': 663,
#  '所属类别': 664,
#  '游戏引擎': 665,
#  '总监': 666,
#  '主治': 667,
#  '释名': 668,
#  '气味': 669,
#  '政治体制': 670,
#  '卫视口号': 671,
#  '卫视剧场': 672,
#  '地点': 673,
#  '昵称': 674,
#  '上星时间': 675,
#  '主打栏目': 676,
#  '视频格式': 677,
#  '公司性质': 678,
#  '公司口号': 679,
#  '播出方式': 680,
#  '出版方': 681,
#  '香港播出时间': 682,
#  '香港播出频道': 683,
#  '动词形式': 684,
#  '娱乐项目': 685,
#  '景点': 686,
#  '特色': 687,
#  '主角': 688,
#  '剧情类别': 689,
#  '完成字数': 690,
#  '厂房面积': 691,
#  '照明': 692,
#  '化妆师': 693,
#  '海报拍摄': 694,
#  '国内刊号': 695,
#  '国际刊号': 696,
#  '邮发代号': 697,
#  '创刊时间': 698,
#  '企业精神': 699,
#  '会长': 700,
#  '原著编剧': 701,
#  '爱奇艺': 702,
#  '腾讯视频': 703,
#  '人物原型': 704,
#  '公公': 705,
#  '侍从': 706,
#  '妹夫': 707,
#  '丈夫/挚爱': 708,
#  '养子': 709,
#  '笔画': 710,
#  '洪武正韵': 711,
#  '偏旁部首': 712,
#  '康熙笔画': 713,
#  '小学': 714,
#  '中学': 715,
#  '日文名': 716,
#  '擅长语言': 717,
#  '喜欢': 718,
#  '师兄': 719,
#  '声道': 720,
#  '外名别名': 721,
#  '猎人等级': 722,
#  '异能': 723,
#  '版面': 724,
#  '朋友': 725,
#  '担任职务': 726,
#  '就职': 727,
#  '象征': 728,
#  '司掌': 729,
#  '居所': 730,
#  '神话体系': 731,
#  '配偶': 732,
#  '所属': 733,
#  '开机时间': 734,
#  '获得奖项': 735,
#  '位分变化': 736,
#  '股票代码': 737,
#  '上市日期': 738,
#  '年营业额': 739,
#  '首席执行官': 740,
#  '上市地点': 741,
#  '董事局主席': 742,
#  '其他电视台': 743,
#  '状态': 744,
#  '现女友': 745,
#  '前女友': 746,
#  '行政级别': 747,
#  '混缩': 748,
#  '学科别称': 749,
#  '研究对象': 750,
#  '学科分类': 751,
#  '代表研究者': 752,
#  '现任主任': 753,
#  '语种': 754,
#  '出版日期': 755,
#  '完成时间': 756,
#  '维也纳马克': 757,
#  '应用平台': 758,
#  '应用版本': 759,
#  '应用名称': 760,
#  '人均gdp': 761,
#  'gdp': 762,
#  '古代名人': 763,
#  '原理': 764,
#  '学名': 765,
#  '单性本册数': 766,
#  '医院类型': 767,
#  '医保定点': 768,
#  '医院等级': 769,
#  '经济类型': 770,
#  '正式国名': 771,
#  '城市': 772,
#  '货币': 773,
#  '历史范围': 774,
#  '主要邦国': 775,
#  '族': 776,
#  '推广宣传': 777,
#  '执导': 778,
#  '相关术语': 779,
#  '学科分支': 780,
#  '演奏乐器': 781,
#  '音乐类型': 782,
#  '圈中好友': 783,
#  '出生年份': 784,
#  '网络名称': 785,
#  '姓名': 786,
#  '提供': 787,
#  '耕地面积': 788,
#  '行政代码': 789,
#  '名': 790,
#  '复姓': 791,
#  '发布人': 792,
#  '发布网站': 793,
#  '报道国家': 794,
#  '连载作品': 795,
#  '婚姻状况': 796,
#  '签约网站': 797,
#  '系别': 798,
#  '个性': 799,
#  '道路通行': 800,
#  '国际电话区号': 801,
#  '水域率': 802,
#  '人口数量': 803,
#  '国土面积': 804,
#  '英文名称': 805,
#  '国庆日': 806,
#  '人口密度': 807,
#  'gdp总计': 808,
#  '时区': 809,
#  '国际域名缩写': 810,
#  '国家代码': 811,
#  '国歌': 812,
#  '季数': 813,
#  '音频码率': 814,
#  '专职院士': 815,
#  '现任所长': 816,
#  '研究所地址': 817,
#  '丛书系列': 818,
#  '统一书号': 819,
#  '才艺': 820,
#  '应用学科': 821,
#  '应用范围': 822,
#  '总建筑面积': 823,
#  '首映地点': 824,
#  '香料分类': 825,
#  '种类': 826,
#  '香草分类': 827,
#  '医院': 828,
#  '医生姓名': 829,
#  '五大流派': 830,
#  '初始记载': 831,
#  '徒弟': 832,
#  '职权': 833,
#  '成员': 834,
#  '生活地点': 835,
#  '亚门': 836,
#  '食物': 837,
#  '灭绝原因': 838,
#  '灭绝时间': 839,
#  '背景': 840,
#  '文物等级': 841,
#  '曾用名': 842,
#  '用途': 843,
#  '制作者': 844,
#  '原作者': 845,
#  '投资特长': 846,
#  '公司': 847,
#  '研究领域': 848,
#  '闺蜜': 849,
#  '倾心之人': 850,
#  '方向': 851,
#  '正式成立': 852,
#  '相关典故': 853,
#  '总点击': 854,
#  '总字数': 855,
#  '作品类别': 856,
#  '首发网站': 857,
#  '连载进度': 858,
#  '总推荐': 859,
#  '首演时间': 860,
#  '手下': 861,
#  '能力': 862,
#  '弱点': 863,
#  '发表处': 864,
#  '发表时间': 865,
#  '世代': 866,
#  '师承': 867,
#  '创立时间': 868,
#  '职位': 869,
#  '总策划': 870,
#  '播出电视台': 871,
#  '史载': 872,
#  '现今位置': 873,
#  '所属山脉': 874,
#  '漫画地区': 875,
#  '融资状态': 876,
#  '模式': 877,
#  '深圳老字号': 878,
#  '恋情': 879,
#  '亚种': 880,
#  '宣传': 881,
#  '文案': 882,
#  '英雄定位': 883,
#  '最高等级': 884,
#  '魔法值': 885,
#  '攻击力': 886,
#  '定位': 887,
#  '现已重做': 888,
#  '生命值': 889,
#  '北临': 890,
#  '西临': 891,
#  '全村经济来源': 892,
#  '学生人数': 893,
#  '办学指导思想': 894,
#  '名誉校长': 895,
#  '职工人数': 896,
#  '当前版本': 897,
#  '应用语言': 898,
#  '高音区': 899,
#  '低音区': 900,
#  '命名人及年代': 901,
#  '格式': 902,
#  '症状表现': 903,
#  '进度': 904,
#  '环境': 905,
#  '玩法': 906,
#  '其他亲戚': 907,
#  '假扮样型': 908,
#  '土地面积': 909,
#  '提出人': 910,
#  '所属时代': 911,
#  '人物关系': 912,
#  '应用行业': 913,
#  '术语属性': 914,
#  '应用领域': 915,
#  '其他相关作品': 916,
#  '开始创作时间': 917,
#  '是否完结': 918,
#  '作品标签': 919,
#  '常住人口': 920,
#  '总面积': 921,
#  '五笔': 922,
#  '笔画数': 923,
#  '嗜好': 924,
#  '百度id': 925,
#  '相关文献': 926,
#  '详细解释': 927,
#  '专辑类别': 928,
#  '出版地': 929,
#  '周刊': 930,
#  '适用领域范围': 931,
#  '表达式': 932,
#  '主营': 933,
#  '是否处方药': 934,
#  '包装': 935,
#  '成份': 936,
#  '药品名称': 937,
#  '特产': 938,
#  '画派': 939,
#  '标准': 940,
#  '差异': 941,
#  '山高': 942,
#  '位于': 943,
#  '规划': 944,
#  '半岛数量': 945,
#  '喜欢的音乐': 946,
#  '好感类型': 947,
#  '喜欢的作者': 948,
#  '喜欢的漫画': 949,
#  '速度': 950,
#  '游戏类别': 951,
#  '创立人': 952,
#  '养父': 953,
#  '生父': 954,
#  '生母': 955,
#  '追求者': 956,
#  '养母': 957,
#  '攻击属性': 958,
#  '港口': 959,
#  '颜色': 960,
#  '电影公司': 961,
#  '成名足迹': 962,
#  '雅号': 963,
#  '节目口号': 964,
#  '公测时间': 965,
#  '游戏题材': 966,
#  '口号': 967,
#  '参赛对象': 968,
#  '协办': 969,
#  '举办时间': 970,
#  '活动类型': 971,
#  '发展': 972,
#  '组成': 973,
#  '开始': 974,
#  'dna的复制': 975,
#  '起源年代': 976,
#  '相关作品': 977,
#  '电影': 978,
#  '好处': 979,
#  '游戏分类': 980,
#  '号': 981,
#  '饰演者': 982,
#  '性格': 983,
#  '球衣颜色': 984,
#  '容纳人数': 985,
#  '现任主教练': 986,
#  '主场馆': 987,
#  '分区': 988,
#  '外号': 989,
#  '知名人物': 990,
#  '拥有者': 991,
#  '中文队名': 992,
#  '角逐赛事': 993,
#  '外文队名': 994,
#  '主要荣誉': 995,
#  '在位时间': 996,
#  '年号': 997,
#  '朝代': 998,
#  '庙号': 999,
#  ...}

# %%
kb_data[7:15]
# Out:
# [{'alias': ['滕王阁序'],
#   'subject_id': '10008',
#   'subject': '滕王阁序',
#   'type': ['thing'],
#   'data': [{'predicate': '摘要', 'object': '《滕王阁序》是佚名的音乐作品,收录在《诗词歌赋大集合》专辑中。'},
#    {'predicate': '音乐时长', 'object': '3分50秒'},
#    {'predicate': '所属专辑', 'object': '诗词歌赋大集合'},
#    {'predicate': '义项描述', 'object': '佚名演唱歌曲'}]},
#  {'alias': ['莲宗寺'],
#   'subject_id': '10009',
#   'subject': '莲宗寺',
#   'type': ['place'],
#   'data': [{'predicate': '摘要',
#     'object': '莲宗寺位于天津市和平区保安大街，是1949年后天津仅存的一座尼僧寺院。创建者际然法师在开山时所发的愿言“来僧不赶，去僧不留，自己不亲度徒众”的愿言，使此寺十方丛林的清严道风名闻遐迩。此道风被际然尼师的接班人圣慧法师继承至今，并将作为莲宗寺的传院家风而保留。2014年2月14日(正月十五)莲宗寺落地大修工程正式启动，莲宗寺所有宗教佛事活动均转移至莲宗寺临时活动道场进行(甘肃路32号，在甘肃路上万全道与鞍山道之间)。'},
#    {'predicate': '类型', 'object': '尼僧寺院'},
#    {'predicate': '中文名称', 'object': '莲宗寺'},
#    {'predicate': '占地面积', 'object': '一亩一分'},
#    {'predicate': '地理位置', 'object': '天津市和平区'},
#    {'predicate': '义项描述', 'object': '天津'},
#    {'predicate': '标签', 'object': '地理'},
#    {'predicate': '标签', 'object': '文化'},
#    {'predicate': '标签', 'object': '文物考古'},
#    {'predicate': '标签', 'object': '景观景点'},
#    {'predicate': '标签', 'object': '建筑'},
#    {'predicate': '标签', 'object': '历史'}]},
#  {'alias': ['裙子'],
#   'subject_id': '10010',
#   'subject': '裙子',
#   'type': ['thing'],
#   'data': [{'predicate': '摘要',
#     'object': '《裙子》是一部由[瑞士]杰曼诺·祖罗所著图画书籍，新星出版社出版发行。'},
#    {'predicate': '作者', 'object': '[瑞士]杰曼诺·祖罗'},
#    {'predicate': 'isbn', 'object': '9787513307017'},
#    {'predicate': '书名', 'object': '裙子'},
#    {'predicate': '出版社', 'object': '新星出版社'},
#    {'predicate': '义项描述', 'object': '[瑞士]杰曼诺·祖罗所著书籍'}]},
#  {'alias': ['东泉镇'],
#   'subject_id': '10011',
#   'subject': '东泉镇',
#   'type': ['place'],
#   'data': [{'predicate': '摘要',
#     'object': '巴南区东温泉镇地处巴南区东部，巴南旅游双环线上。2001年7月，乡镇建制调整后由原来东泉、五布镇、天赐镇、清和乡合并而成。东与南川市白沙镇接壤，南与石龙镇、姜家镇为邻，西连二圣镇，北接木洞、丰盛镇。幅员面积122.70平方公里，耕地面积50862亩，其中田25376亩。镇政府所在地距重庆市区50余公里。现辖14个行政村、4个居委会、136个村民小组，总户数11869户，总人口37856人，其中农业人口35188人，非农业人口2668人。'},
#    {'predicate': '行政区类别', 'object': '重庆市'},
#    {'predicate': '所属地区', 'object': '重庆市巴南区'},
#    {'predicate': '下辖地区', 'object': '辖14个行政村、4个居委会'},
#    {'predicate': '电话区号', 'object': '023'},
#    {'predicate': '方言', 'object': '重庆方言'},
#    {'predicate': '邮政区码', 'object': '401320'},
#    {'predicate': '面积', 'object': '122.70平方公里'},
#    {'predicate': '车牌代码', 'object': '渝'},
#    {'predicate': '人口', 'object': '37856人'},
#    {'predicate': '著名景点', 'object': '东温泉'},
#    {'predicate': '中文名称', 'object': '巴南区东温泉镇'},
#    {'predicate': '气候条件', 'object': '亚热带湿润气候'},
#    {'predicate': '义项描述', 'object': '重庆市巴南区东温泉镇'},
#    {'predicate': '标签', 'object': '行政区划'},
#    {'predicate': '标签', 'object': '乡镇'}]},
#  {'alias': ['王峰'],
#   'subject_id': '10012',
#   'subject': '王峰',
#   'type': ['human'],
#   'data': [{'predicate': '摘要',
#     'object': '王峰，男，蒙古族，1958年9月出生，内蒙古鄂托克旗人，中央党校大学学历，1980年1月加入中国共产党，1974年6月参加工作。现任内蒙古自治区鄂尔多斯市人大常委会主任、党组书记。'},
#    {'predicate': '出生地', 'object': '内蒙古鄂托克旗'},
#    {'predicate': '毕业院校', 'object': '中央党校'},
#    {'predicate': '中文名', 'object': '王峰'},
#    {'predicate': '国籍', 'object': '中国'},
#    {'predicate': '出生日期', 'object': '1958年9月'},
#    {'predicate': '民族', 'object': '蒙古族'},
#    {'predicate': '义项描述', 'object': '内蒙古鄂尔多斯市人大常委会主任'},
#    {'predicate': '标签', 'object': '政治人物'},
#    {'predicate': '标签', 'object': '人物'},
#    {'predicate': '标签', 'object': '官员'}]},
#  {'alias': ['男子汉大丈夫'],
#   'subject_id': '10013',
#   'subject': '男子汉大丈夫',
#   'type': ['creativework'],
#   'data': [{'predicate': '摘要', 'object': '《男子汉大丈夫》是李海强填词谱曲并演唱的一首歌曲。'},
#    {'predicate': '歌曲原唱', 'object': '李海强'},
#    {'predicate': '谱曲', 'object': '李海强'},
#    {'predicate': '歌曲语言', 'object': '普通话'},
#    {'predicate': '填词', 'object': '李海强'},
#    {'predicate': '发行时间', 'object': '2015年3月10日'},
#    {'predicate': '中文名称', 'object': '男子汉大丈夫'},
#    {'predicate': '义项描述', 'object': '男子汉大丈夫-李海强歌曲'},
#    {'predicate': '标签', 'object': '人物'}]},
#  {'alias': ['giovanni boccaccio',
#    '乔万尼·薄伽丘',
#    '卜伽丘',
#    '薄伽丘',
#    '乔凡尼·卜迦丘',
#    '乔万尼·卜伽丘',
#    '薄伽丘，g.'],
#   'subject_id': '10014',
#   'subject': '乔万尼·薄伽丘',
#   'type': ['human'],
#   'data': [{'predicate': '摘要',
#     'object': '乔万尼·薄伽丘(giovanni boccaccio，1313年——1375年12月21日)，意大利文艺复兴运动的杰出代表，人文主义杰出作家。与诗人但丁、彼特拉克并称为佛罗伦萨文学“三杰”。其代表作《十日谈》是欧洲文学史上第一部现实主义作品。它批判宗教守旧思想，主张“幸福在人间”，被视为文艺复兴的宣言。'},
#    {'predicate': '出生地', 'object': '巴黎或契塔尔多'},
#    {'predicate': '外文名', 'object': 'giovanni boccaccio'},
#    {'predicate': '逝世日期', 'object': '1375年12月21日'},
#    {'predicate': '星座', 'object': '双子座'},
#    {'predicate': '别名', 'object': '卜伽丘'},
#    {'predicate': '代表作品', 'object': '《十日谈》、《菲洛柯洛》、《苔塞伊达》《但丁传》'},
#    {'predicate': '中文名', 'object': '乔万尼·薄伽丘'},
#    {'predicate': '国籍', 'object': '佛罗伦萨共和国'},
#    {'predicate': '出生日期', 'object': '1313(癸丑年)6月16日'},
#    {'predicate': '职业', 'object': '作家，诗人'},
#    {'predicate': '民族', 'object': '意大利人'},
#    {'predicate': '主要成就', 'object': '意大利文艺复兴先驱，人文主义杰出作家'},
#    {'predicate': '义项描述', 'object': '乔万尼·薄伽丘'},
#    {'predicate': '标签', 'object': '人物'},
#    {'predicate': '标签', 'object': '文学家'},
#    {'predicate': '标签', 'object': '文学'}]},
#  {'alias': ['李青'],
#   'subject_id': '10015',
#   'subject': '李青',
#   'type': ['human'],
#   'data': [{'predicate': '摘要',
#     'object': '李青，汉族，1972年出生，湖北应城人，女子跳水运动员，国际级运动健将，湖北省劳动模范。1988年4月，在中国国际跳水公开赛上获得跳板季军。1988年6月，在韩国汉城国际跳水获得跳板跳水冠军。'},
#    {'predicate': '出生地', 'object': '湖北应城'},
#    {'predicate': '中文名', 'object': '李青'},
#    {'predicate': '主要奖项',
#     'object': '1988年4月，在中国国际跳水公开赛上获得跳板季军,1988年6月，在韩国汉城国际跳水获得跳板跳水冠军。,湖北省劳动模范'},
#    {'predicate': '出生日期', 'object': '1972年'},
#    {'predicate': '国籍', 'object': '中国'},
#    {'predicate': '运动项目', 'object': '跳水'},
#    {'predicate': '性别', 'object': '女'},
#    {'predicate': '民族', 'object': '汉族'},
#    {'predicate': '义项描述', 'object': '女子跳水运动员'},
#    {'predicate': '标签', 'object': '游泳'},
#    {'predicate': '标签', 'object': '体育人物'},
#    {'predicate': '标签', 'object': '人物'},
#    {'predicate': '标签', 'object': '运动员'}]}]

# %%
spo = []
for item in tqdm(kb_data):
    subject_id = subject[item['subject_id']]
    for t_type in item['type']:
        spo.append([subject_id,predicate['type'],type_object[t_type]])
    for p in item['data']:
        if p['predicate'] == '摘要':continue
        spo.append([subject_id,predicate[p['predicate']],type_object[p['object']]])
# Out:
# 100%|██████████| 399252/399252 [00:08<00:00, 47376.97it/s]

# %%
with open('entity_embedding/train2id.txt','w') as f:
    #0 1 0
    f.write(str(len(spo))+'\n')
    for spo_line in spo:
        f.write(str(spo_line[0])+' '+str(spo_line[1])+' '+str(spo_line[2])+'\n')

# %%
# 14951
# /m/027rn	0
with open('entity_embedding/entity2id.txt','w') as f:
    f.write(str(len(type_object))+'\n')
    for key in type_object:
        f.write(str(key)+' '+str(type_object[key])+'\n')

# %%
with open('entity_embedding/relation2id.txt','w') as f:
    f.write(str(len(predicate))+'\n')
    for key in predicate:
        f.write(str(key)+' '+str(predicate[key])+'\n')

# %%
# gensim method

# %%
from gensim.models import word2vec
import jieba

sentence = []
for item in tqdm(kb_data):

    sentence.append([item['subject_id'],item['type'][0]])
    if item['subject_id'] == '172568':
        print('found it',[item['subject_id'],item['type'][0]])
    jieba.add_word(item['subject'],freq=10000)
    for t in item['data']:
        temp = []
        if t['predicate'] == '摘要':
            abstract = jieba.lcut(t['object'])
            for word in abstract:
                if word !=item['subject']:
                    temp.append(word)
                else:
                    temp.append(item['subject_id'])
            sentence.append(temp)
        else:
            temp.append(item['subject_id'])
            temp.append(t['predicate'])
            for w in jieba.lcut(t['object']):
                temp.append(w)
            sentence.append(temp)
# Out:
#   0%|          | 0/399252 [00:00<?, ?it/s]Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 1.183 seconds.
# Prefix dict has been built succesfully.
#  41%|████      | 162725/399252 [03:00<03:16, 1205.75it/s]
# found it ['172568', 'tvplay']
# 100%|██████████| 399252/399252 [06:13<00:00, 1068.38it/s]

# %%
train_data = []
with open('data/raw_data/train.json','r') as f:
    for line in f:
        sentence.append(jieba.lcut(eval(str(json.loads(line)).lower())['text']))
with open('data/raw_data/develop.json','r') as f:
    for line in f:
        sentence.append(jieba.lcut(eval(str(json.loads(line)).lower())['text']))

# %%
model = word2vec.Word2Vec(sentence, size=100, window=5, min_count=1, workers=10, iter=30)
# 打印单词'good'的词向量
print(model.wv.word_vec('good'))
# 打印和'good'相似的前2个单词
print(model.wv.most_similar('good', topn=2))
# 保存模型到文件
model.save('embedding/w2v.model')
# Out:
# [-0.08366165  0.6456421  -0.0053318  -0.17441595  0.10712836  0.21781069
#   0.09438214 -0.40865222  0.5160166  -0.7896486   0.55465025 -0.43442625
#  -0.27489826  0.14783931 -0.17081976  0.37548465  0.17186736 -0.11905498
#   0.8584407   0.42812404  0.06527553  0.84297395 -0.27115908  0.22418188
#   0.08124936  0.01021086 -0.5904909   0.3422028   0.32182467 -0.5895128
#  -0.869983    0.4936087  -0.5036948   0.36903545 -0.4323687  -0.4092008
#   0.00124789 -0.36811572  0.28218976  0.11594447 -0.07792004  0.08003946
#  -0.3795403  -0.07421041 -0.49499682 -0.60084325  0.5517215  -0.43452615
#  -0.08687604  0.28240895  0.07630728 -0.31775263  0.11587354  0.13203569
#  -0.5260034   0.31921571 -0.7562616  -0.53258926  0.05362869  0.05813489
#   0.12120786 -0.03183933  0.9361582   0.16180009  0.07377072  0.3423675
#   0.40612528 -0.16678797  0.3262598  -0.29349467 -0.33626214  0.5669701
#  -0.23239918 -0.02709411 -0.16611421  0.5090579  -0.37861735  0.16692801
#  -0.02533946 -0.35014805  0.07039835  0.22189806  0.01435206 -0.28911108
#  -0.13041176 -0.17987546 -0.17668961 -0.36224782  0.1611178  -0.09180118
#   0.1883241  -0.05588296  0.36027935  0.18995601 -0.17536527  0.42833212
#  -0.09012899 -0.40496397 -0.1182402  -0.21910873]
# [('nothing', 0.7515172958374023), ('unknown', 0.721265435218811)]
# /home/zhukaihua/anaconda3/lib/python3.7/site-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
from gensim.models import Word2Vec

entity_embedding = Word2Vec.load('embedding/w2v.model')
print(entity_embedding.wv.word_vec('搜索'))
# Out:
# /home/zhukaihua/anaconda3/lib/python3.7/site-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# [-1.0737793e+00  5.3504688e-01  1.0700321e+00 -2.6374406e-01
#   6.0185862e+00  2.7448034e+00 -4.9840868e-01  1.6817570e-02
#  -1.2685272e+00  1.6750504e+00 -1.9749253e+00 -1.7095530e+00
#  -5.2341199e+00  9.9409699e-01  8.6485028e-01  7.6562244e-01
#   1.3986145e-01  2.7689950e+00 -4.3328118e+00  1.5562712e+00
#   1.2987630e+00 -6.1722535e-01  2.0230827e+00 -1.7293605e-01
#   1.4320282e+00  1.7313426e+00 -5.8213836e-01  4.0342179e-01
#  -2.0496645e+00 -2.4598682e+00  5.9709676e-02  1.3334175e+00
#  -1.2667675e+00  5.0228090e+00 -1.0579503e+00 -1.2785110e-01
#  -3.1495804e-01  9.5685905e-01 -7.7226305e-01  8.2667005e-01
#  -1.0409649e-01 -5.6299984e-01  3.4439716e-01 -9.6234894e-01
#   8.2685357e-01 -9.0903610e-01 -2.1476011e+00  2.1012766e+00
#   5.6436467e-01  1.4368544e+00 -4.1238542e+00  4.3420631e-01
#   5.4699433e-01  5.7702416e-01 -1.0688744e+00  7.1016723e-01
#   2.0146370e+00  2.7017179e+00 -1.1181473e+00 -3.2932277e+00
#  -2.8647101e+00 -1.6718365e+00 -1.8166791e+00 -2.5158155e-01
#   6.4774728e-01 -1.5589888e-02 -2.9481385e+00 -1.3523998e+00
#   1.4385234e+00  1.9547360e+00  2.1417801e+00  1.0178616e+00
#   5.6833947e-01  3.6124842e+00 -2.0289660e+00 -1.9769433e+00
#   8.6153543e-01  6.5576804e-01 -2.2673481e+00  2.0620699e+00
#  -3.3662289e-02  7.6923555e-01  2.3554456e+00 -3.9067647e+00
#   2.5299019e-01 -2.4230025e+00 -1.0170363e+00 -1.5765316e+00
#  -2.6156003e+00  1.2028567e+00  3.2731895e+00  6.1102517e-02
#  -2.2762339e+00  1.0112528e+00 -3.8643319e-03 -4.0232925e+00
#   7.2335619e-01 -1.5252150e+00 -9.3070388e-01 -7.1498388e-01]

# %%
print(model.wv.most_similar('app', topn=2))
# Out:
# [('ofo', 0.6596300005912781), ('手机软件', 0.6247172951698303)]

# %%
for item in tqdm(kb_data):
    if item['subject_id'] == '172568':
        print('found it')
# Out:
# 100%|██████████| 399252/399252 [00:00<00:00, 1251896.45it/s]
# found it
