# %%
# coding:u8
import pandas as pd
import numpy as np
import copy,gc
import lightgbm as lgb
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import f1_score,classification_report
import matplotlib.pyplot as plt
from tqdm import tqdm as tqdm
import seaborn as sns

# %%
data = pd.read_pickle('features/1_stat_feature.pkl')

# %%
data = data.fillna(-999)

# %%
data.head()
# Out:
#   text_id   kb_id train_mention  label  num_attrs  num_abstract_words  \
# 0       1  130287          南京南站      0          9                 338
# 1       1  311223          南京南站      1         17                 447
# 2       1  341096            高铁      1         10                 239
# 3       1  213561            高铁      0          1                   0
# 4       1  130287          南京南站      0          9                 338
#
#    num_alias  m_id  num_candidates  mention_equal_subject  ...  \
# 0          1     0               2                   True  ...
# 1          5     0               2                   True  ...
# 2         10     1               2                   True  ...
# 3          4     1               2                  False  ...
# 4          1     2               2                   True  ...
#
#    rank_num_abstract_words  rank_num_alias  rank_label_mean  rank_label_count  \
# 0                      2.0             2.0           -999.0            -999.0
# 1                      1.0             1.0           -999.0            -999.0
# 2                      1.0             1.0              1.0               1.5
# 3                      2.0             2.0              2.0               1.5
# 4                      2.0             2.0           -999.0            -999.0
#
#   rank_m_label_mean  rank_m_label_count  rank_num_candidates  \
# 0            -999.0              -999.0                  1.5
# 1            -999.0              -999.0                  1.5
# 2               1.0                 1.5                  1.5
# 3               2.0                 1.5                  1.5
# 4            -999.0              -999.0                  1.5
#
#    rank_mention_equal_subject  rank_shuminghao  rank_entity_common
# 0                         1.5              1.5                 1.5
# 1                         1.5              1.5                 1.5
# 2                         1.0              1.5                 1.0
# 3                         2.0              1.5                 2.0
# 4                         1.5              1.5                 1.5
#
# [5 rows x 78 columns]

# %%
predictor = ['num_attrs', 'num_abstract_words', 'num_alias', 'label_mean', 'label_count', 'm_label_mean', 
             'm_label_count','AcademicDiscipline',
               'Animal', 'AstronomicalObject', 'Athlete', 'AwardEventSeries', 'Brand',
               'Building', 'CollegeOrUniversity', 'CommunicationMedium', 'Country',
               'CreativeWork', 'CulturalHeritage', 'Currency', 'Curriculum',
               'EducationMajor', 'EntertainmentPerson', 'Event', 'FamilyName',
               'FictionalHuman', 'FictionalThing', 'Food', 'Formula', 'Game',
               'HistoricalPeriod', 'HistoricalPerson', 'Human',
               'InternationalOrganization', 'Language', 'Material', 'MedicalCondition',
               'MedicalDepartmentType', 'Movie', 'Nation', 'Organism', 'Organization',
               'Person', 'Place', 'Plant', 'Product', 'ScientificOrganization',
               'Symbol', 'TVPlay', 'TVShow', 'Theorem', 'Thing', 'Tool', 'Vocabulary',
               'ZodiacSign','num_candidates','mention_equal_subject','shuminghao','entity_common',
            'rank_num_attrs', 'rank_num_abstract_words',
       'rank_num_alias', 'rank_label_mean', 'rank_label_count',
       'rank_m_label_mean', 'rank_m_label_count', 'rank_num_candidates',
       'rank_mention_equal_subject', 'rank_shuminghao', 'rank_entity_common','len_mention','mention_start']

# %%
exclude = []
# exclude = []
temp = []
for x in predictor:
    if x not in exclude:temp.append(x)
predictor2 = temp

# %%
param = {
    #'num_leaves':100,
    'objective':'binary',
    #'metric':'acc',
    'metric_freq':20,
    'learning_rate': 0.05,
    'num_threads':8,
    #'min_sum_hessian_in_leaf':10,
    'boosting_type':'gbdt',
    'subsample':0.9,
    'colsample_bytree':0.8,
    'n_estimators':20000,
    'min_child_weight':1,
    'subsample_freq':2,
    'num_leaves':128,
    'n_jobs':-1,
}

# %%
kfold = KFold(n_splits=9,shuffle=False,random_state=2019)
for train_index,test_index in kfold.split(data):
    train_data,val_data = data.loc[train_index,:],data.loc[test_index,:]
    train = lgb.Dataset(train_data[predictor2],label=train_data['label'])
    validation_data = lgb.Dataset(val_data[predictor2],label=val_data['label'])
    
    val_data.reset_index(inplace=True,drop=True)
    val_data.reset_index(inplace=True)
    index_df = val_data.groupby('m_id')['index'].apply(list)
    
    label_package = val_data.groupby('m_id',as_index=False)['label'].agg({'label_id_max':'idxmax'})['label_id_max']
    
    def lgb_f1_score(y_hat, data):
        y_true = data.get_label()
        hit = 0
        for index,pack in enumerate(index_df):
            score = []
            for i in pack:
                score.append(y_hat[i])
            if pack[np.argmax(score)]==label_package[index]:
                hit+=1
        best_score = hit/len(index_df)
        return 'acc', best_score, True
    bst = lgb.train(param, train, valid_sets=[validation_data],early_stopping_rounds=500,
                    verbose_eval=20,feval=lgb_f1_score)
#     break
# 0.8672
# 0.872
# [171]	valid_0's binary_logloss: 0.0988336	valid_0's acc: 0.873219
# valid_0's binary_logloss: 0.0964686	valid_0's acc: 0.87713
# [224]	valid_0's binary_logloss: 0.096617	valid_0's acc: 0.877515
# [308]	valid_0's binary_logloss: 0.09149	valid_0's acc: 0.890507 entity common
# drop ctr 0.877
# [2094]	valid_0's binary_logloss: 0.0791409	valid_0's acc: 0.896452
# [1674]	valid_0's binary_logloss: 0.0784442	valid_0's acc: 0.896347
# Out:
# /home/zhukaihua/anaconda3/lib/python3.7/site-packages/lightgbm/engine.py:118: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 500 rounds.
# [20]	valid_0's binary_logloss: 0.130515	valid_0's acc: 0.950222
# [40]	valid_0's binary_logloss: 0.0702804	valid_0's acc: 0.951103
# [60]	valid_0's binary_logloss: 0.0504813	valid_0's acc: 0.952723
# [80]	valid_0's binary_logloss: 0.0426678	valid_0's acc: 0.954626
# [100]	valid_0's binary_logloss: 0.0394658	valid_0's acc: 0.955718
# [120]	valid_0's binary_logloss: 0.037996	valid_0's acc: 0.956528
# [140]	valid_0's binary_logloss: 0.0371802	valid_0's acc: 0.957479
# [160]	valid_0's binary_logloss: 0.036701	valid_0's acc: 0.957902
# [180]	valid_0's binary_logloss: 0.0363527	valid_0's acc: 0.958395
# [200]	valid_0's binary_logloss: 0.0360944	valid_0's acc: 0.958712
# [220]	valid_0's binary_logloss: 0.035938	valid_0's acc: 0.958782
# [240]	valid_0's binary_logloss: 0.035779	valid_0's acc: 0.959276
# [260]	valid_0's binary_logloss: 0.03568	valid_0's acc: 0.959452
# [280]	valid_0's binary_logloss: 0.0355667	valid_0's acc: 0.959628
# [300]	valid_0's binary_logloss: 0.0354669	valid_0's acc: 0.959558
# [320]	valid_0's binary_logloss: 0.035383	valid_0's acc: 0.959628
# [340]	valid_0's binary_logloss: 0.0353096	valid_0's acc: 0.959945
# [360]	valid_0's binary_logloss: 0.035238	valid_0's acc: 0.960086
# [380]	valid_0's binary_logloss: 0.035164	valid_0's acc: 0.960262
# [400]	valid_0's binary_logloss: 0.0350954	valid_0's acc: 0.960544
# [420]	valid_0's binary_logloss: 0.0350322	valid_0's acc: 0.960509
# /home/zhukaihua/anaconda3/lib/python3.7/site-packages/lightgbm/engine.py:118: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 500 rounds.
# [20]	valid_0's binary_logloss: 0.129302	valid_0's acc: 0.951061
# [40]	valid_0's binary_logloss: 0.069177	valid_0's acc: 0.952947
# [60]	valid_0's binary_logloss: 0.0491053	valid_0's acc: 0.954691
# [80]	valid_0's binary_logloss: 0.0414995	valid_0's acc: 0.956008
# [100]	valid_0's binary_logloss: 0.0383957	valid_0's acc: 0.95704
# [120]	valid_0's binary_logloss: 0.0368494	valid_0's acc: 0.957325
# [140]	valid_0's binary_logloss: 0.0360738	valid_0's acc: 0.957788
# [160]	valid_0's binary_logloss: 0.0356037	valid_0's acc: 0.958499
# [180]	valid_0's binary_logloss: 0.0353019	valid_0's acc: 0.95882
# [200]	valid_0's binary_logloss: 0.0351432	valid_0's acc: 0.959104
# [220]	valid_0's binary_logloss: 0.0349776	valid_0's acc: 0.959247
# [240]	valid_0's binary_logloss: 0.0348387	valid_0's acc: 0.959425
# [260]	valid_0's binary_logloss: 0.0346845	valid_0's acc: 0.959603
# [280]	valid_0's binary_logloss: 0.0345806	valid_0's acc: 0.95971
# [300]	valid_0's binary_logloss: 0.034461	valid_0's acc: 0.960172
# [320]	valid_0's binary_logloss: 0.0343645	valid_0's acc: 0.96003
# [340]	valid_0's binary_logloss: 0.0342992	valid_0's acc: 0.96003
# [360]	valid_0's binary_logloss: 0.0341616	valid_0's acc: 0.960279
# [380]	valid_0's binary_logloss: 0.0340533	valid_0's acc: 0.960279
# [400]	valid_0's binary_logloss: 0.0339857	valid_0's acc: 0.960279
# [420]	valid_0's binary_logloss: 0.0339286	valid_0's acc: 0.960457
# [440]	valid_0's binary_logloss: 0.0338659	valid_0's acc: 0.960599
# [460]	valid_0's binary_logloss: 0.033839	valid_0's acc: 0.960706
# [480]	valid_0's binary_logloss: 0.0337764	valid_0's acc: 0.960849
# [500]	valid_0's binary_logloss: 0.0337153	valid_0's acc: 0.960813
# [520]	valid_0's binary_logloss: 0.0336876	valid_0's acc: 0.960991
# [540]	valid_0's binary_logloss: 0.0336304	valid_0's acc: 0.96092
# [560]	valid_0's binary_logloss: 0.0335652	valid_0's acc: 0.96092
# [580]	valid_0's binary_logloss: 0.0335469	valid_0's acc: 0.960991
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-1a912afa11a7> in <module>
#      23         return 'acc', best_score, True
#      24     bst = lgb.train(param, train, valid_sets=[validation_data],early_stopping_rounds=500,
# ---> 25                     verbose_eval=20,feval=lgb_f1_score)
#      26 #     break
#      27 # 0.8672
#
# ~/anaconda3/lib/python3.7/site-packages/lightgbm/engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     223             if is_valid_contain_train:
#     224                 evaluation_result_list.extend(booster.eval_train(feval))
# --> 225             evaluation_result_list.extend(booster.eval_valid(feval))
#     226         try:
#     227             for cb in callbacks_after_iter:
#
# ~/anaconda3/lib/python3.7/site-packages/lightgbm/basic.py in eval_valid(self, feval)
#    1975             List with evaluation results.
#    1976         """
# -> 1977         return [item for i in range_(1, self.__num_dataset)
#    1978                 for item in self.__inner_eval(self.name_valid_sets[i - 1], i, feval)]
#    1979
#
# ~/anaconda3/lib/python3.7/site-packages/lightgbm/basic.py in <listcomp>(.0)
#    1976         """
#    1977         return [item for i in range_(1, self.__num_dataset)
# -> 1978                 for item in self.__inner_eval(self.name_valid_sets[i - 1], i, feval)]
#    1979
#    1980     def save_model(self, filename, num_iteration=None, start_iteration=0):
#
# ~/anaconda3/lib/python3.7/site-packages/lightgbm/basic.py in __inner_eval(self, data_name, data_idx, feval)
#    2373             else:
#    2374                 cur_data = self.valid_sets[data_idx - 1]
# -> 2375             feval_ret = feval(self.__inner_predict(data_idx), cur_data)
#    2376             if isinstance(feval_ret, list):
#    2377                 for eval_name, val, is_higher_better in feval_ret:
#
# <ipython-input-21-1a912afa11a7> in lgb_f1_score(y_hat, data)
#      18             for i in pack:
#      19                 score.append(y_hat[i])
# ---> 20             if pack[np.argmax(score)]==label_package[index]:
#      21                 hit+=1
#      22         best_score = hit/len(index_df)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4367                     return s[key]
#    4368
# -> 4369         s = com.values_from_object(series)
#    4370         k = com.values_from_object(key)
#    4371
#
# pandas/_libs/lib.pyx in pandas._libs.lib.values_from_object()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in get_values(self)
#     488         return self._data.formatting_values()
#     489
# --> 490     def get_values(self):
#     491         """
#     492         Same as values (but handles sparseness conversions); is a view.
#
# KeyboardInterrupt:

# %%
# submit

train = lgb.Dataset(data[predictor2],label=data['label'])
param = {
    #'num_leaves':100,
    'objective':'binary',
    #'metric':'acc',
    'metric_freq':20,
    'learning_rate': 0.05,
    'num_threads':8,
    #'min_sum_hessian_in_leaf':10,
    'boosting_type':'gbdt',
    'subsample':0.9,
    'colsample_bytree':0.8,
    'n_estimators':1000,
    'min_child_weight':1,
    'subsample_freq':2,
    'num_leaves':128,
    'n_jobs':-1,
}

bst = lgb.train(param, train)
from sklearn.externals import joblib
joblib.dump(bst, 'model_link/lgb.pkl')

# save model
# load model
#gbm_pickle = joblib.load('lgb.pkl')
# break
# Out:
# /home/zhukaihua/anaconda3/lib/python3.7/site-packages/lightgbm/engine.py:118: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-df3e86e52f7a> in <module>
#      23 from sklearn.externals import joblib
#      24 # save model
# ---> 25 joblib.dump(my_model, 'model_link/lgb.pkl')
#      26 # load model
#      27 #gbm_pickle = joblib.load('lgb.pkl')
#
# NameError: name 'my_model' is not defined

# %%
# Out:
# ['model_link/lgb.pkl']

# %%
val_data
# Out:
#          index text_id   kb_id train_mention  label  num_attrs  \
# 0       174507    9965   42532          爱是唯一      0          8
# 1       174508    9965  119164          爱是唯一      0         27
# 2       174509    9965  335631          爱是唯一      0          8
# 3       174510    9965  125048          爱是唯一      0          3
# 4       174511    9965  121240          爱是唯一      0         13
# 5       174512    9965   13127          爱是唯一      0         27
# 6       174513    9965   32955            电影      0          8
# 7       174514    9965  233538            电影      0         11
# 8       174515    9965   62696            电影      0         19
# 9       174516    9965   53384            电影      0         13
# 10      174517    9965  163688            电影      0         14
# 11      174518    9965  336024            电影      0         16
# 12      174519    9965  242124            电影      0         10
# 13      174520    9965  281810            电影      0          6
# 14      174521    9965  388430            电影      0         20
# 15      174522    9965  148097            电影      1         14
# 16      174523    9965  331456            电影      0          5
# 17      174524    9965  185572            电影      0          6
# 18      174525    9965  372092            电影      0         15
# 19      174526    9965   64603            迅雷      0         11
# 20      174527    9965  341954            迅雷      0          6
# 21      174528    9965  241823            迅雷      0          6
# 22      174529    9965   57067            迅雷      1         20
# 23      174530    9965  219667            迅雷      0          2
# 24      174531    9965  105878            迅雷      0         12
# 25      174532    9965  367547            迅雷      0          7
# 26      174533    9966  138590            军旅      1          8
# 27      174534    9966   92065            诗歌      0          7
# 28      174535    9966  373061            诗歌      0          7
# 29      174536    9966  208055            诗歌      1         12
# ...        ...     ...     ...           ...    ...        ...
# 174476  348983   19807  342372            生活      0          8
# 174477  348984   19807  133160            生活      0          3
# 174478  348985   19807  301216            生活      0          5
# 174479  348986   19807  348052            生活      0          5
# 174480  348987   19807   44957            生活      0          4
# 174481  348988   19807   16455            生活      0          9
# 174482  348989   19807  291457            生活      0         14
# 174483  348990   19807  310883            生活      0          5
# 174484  348991   19807  125811            生活      0         30
# 174485  348992   19808   56603            泰剧      0         13
# 174486  348993   19808  367520            泰剧      1          9
# 174487  348994   19809   92028          星光大道      0          5
# 174488  348995   19809   96871          星光大道      0          7
# 174489  348996   19809  224690          星光大道      0          3
# 174490  348997   19809  267137          星光大道      0         10
# 174491  348998   19809   26453          星光大道      0         22
# 174492  348999   19809   69778          星光大道      0          8
# 174493  349000   19809  326973          星光大道      0          1
# 174494  349001   19809  127891          星光大道      1         23
# 174495  349002   19809  223533          星光大道      0         10
# 174496  349003   19809  366757          星光大道      0          5
# 174497  349004   19809  391620          星光大道      0          1
# 174498  349005   19809  403894          星光大道      0          2
# 174499  349006   19809  111103          星光大道      0         15
# 174500  349007   19809  252096          星光大道      0         20
# 174501  349008   19809  246680          星光大道      0         11
# 174502  349009   19809  214108          星光大道      0         11
# 174503  349010   19809   83166          星光大道      0         10
# 174504  349011   19809   64157          星光大道      0          6
# 174505  349012   19809  168731          星光大道      0         13
#
#         num_abstract_words  num_alias   m_id  num_candidates  ...  \
# 0                       33          1  28633               9  ...
# 1                      121          6  28633               9  ...
# 2                       24          1  28633               9  ...
# 3                       29          1  28633               9  ...
# 4                       52          1  28633               9  ...
# 5                       80          4  28633               9  ...
# 6                       86          1  28634              13  ...
# 7                       37          1  28634              13  ...
# 8                      127          1  28634              13  ...
# 9                      116          6  28634              13  ...
# 10                     239          1  28634              13  ...
# 11                     135          2  28634              13  ...
# 12                      47          1  28634              13  ...
# 13                      44          1  28634              13  ...
# 14                       0          3  28634              13  ...
# 15                     289          2  28634              13  ...
# 16                      37          1  28634              13  ...
# 17                      26          1  28634              13  ...
# 18                     249          2  28634              13  ...
# 19                     109          5  28635               7  ...
# 20                      25          1  28635               7  ...
# 21                      50          1  28635               7  ...
# 22                     366          1  28635               7  ...
# 23                      32          1  28635               7  ...
# 24                      35          4  28635               7  ...
# 25                      58          2  28635               7  ...
# 26                      79          1  28636               1  ...
# 27                      58          1  28637               3  ...
# 28                     133          1  28637               3  ...
# 29                     130          1  28637               3  ...
# ...                    ...        ...    ...             ...  ...
# 174476                  19          1  57284              37  ...
# 174477                  45          1  57284              37  ...
# 174478                  36          1  57284              37  ...
# 174479                  26          1  57284              37  ...
# 174480                  27          1  57284              37  ...
# 174481                  40          1  57284              37  ...
# 174482                  59          1  57284              37  ...
# 174483                  26          1  57284              37  ...
# 174484                  78          3  57284              37  ...
# 174485                 334          1  57285               2  ...
# 174486                  61          1  57285               2  ...
# 174487                  29          1  57286              19  ...
# 174488                 126          1  57286              19  ...
# 174489                  26          1  57286              19  ...
# 174490                 225          1  57286              19  ...
# 174491                 100          3  57286              19  ...
# 174492                 104          1  57286              19  ...
# 174493                   0          1  57286              19  ...
# 174494                 191          2  57286              19  ...
# 174495                 110          1  57286              19  ...
# 174496                  30          1  57286              19  ...
# 174497                   0          1  57286              19  ...
# 174498                 101          1  57286              19  ...
# 174499                 225          2  57286              19  ...
# 174500                 167          1  57286              19  ...
# 174501                  54          1  57286              19  ...
# 174502                 155          2  57286              19  ...
# 174503                 173          3  57286              19  ...
# 174504                   0          1  57286              19  ...
# 174505                  75          1  57286              19  ...
#
#         rank_num_abstract_words  rank_num_alias  rank_label_mean  \
# 0                           6.0             7.0           -999.0
# 1                           2.0             2.5           -999.0
# 2                           9.0             7.0           -999.0
# 3                           7.0             7.0           -999.0
# 4                           5.0             7.0           -999.0
# 5                           4.0             4.0           -999.0
# 6                           7.0             9.5              2.0
# 7                          10.5             9.5              8.5
# 8                           5.0             9.5              3.0
# 9                           6.0             1.0              8.5
# 10                          3.0             9.5              8.5
# 11                          4.0             4.0              8.5
# 12                          8.0             9.5              8.5
# 13                          9.0             9.5              8.5
# 14                         13.0             2.0              8.5
# 15                          1.0             4.0              1.0
# 16                         10.5             9.5              8.5
# 17                         12.0             9.5              8.5
# 18                          2.0             4.0              8.5
# 19                          2.0             1.0              4.5
# 20                          7.0             5.5              4.5
# 21                          4.0             5.5              4.5
# 22                          1.0             5.5              1.0
# 23                          6.0             5.5              4.5
# 24                          5.0             2.0              4.5
# 25                          3.0             3.0              4.5
# 26                          1.0             1.0              1.0
# 27                          3.0             2.0              3.0
# 28                          1.0             2.0              2.0
# 29                          2.0             2.0              1.0
# ...                         ...             ...              ...
# 174476                     36.0            22.5             20.5
# 174477                     19.0            22.5             20.5
# 174478                     24.0            22.5             20.5
# 174479                     30.0            22.5             20.5
# 174480                     28.0            22.5             20.5
# 174481                     22.0            22.5             20.5
# 174482                     15.0            22.5             20.5
# 174483                     30.0            22.5             20.5
# 174484                     11.0             2.0             20.5
# 174485                      1.0             1.5              2.0
# 174486                      2.0             1.5              1.0
# 174487                     15.0            12.5             10.5
# 174488                      7.0            12.5             10.5
# 174489                     16.0            12.5             10.5
# 174490                      1.5            12.5             10.5
# 174491                     11.0             1.5             10.5
# 174492                      9.0            12.5             10.5
# 174493                     18.0            12.5             10.5
# 174494                      3.0             4.0              1.0
# 174495                      8.0            12.5             10.5
# 174496                     14.0            12.5             10.5
# 174497                     18.0            12.5             10.5
# 174498                     10.0            12.5             10.5
# 174499                      1.5             4.0             10.5
# 174500                      5.0            12.5             10.5
# 174501                     13.0            12.5             10.5
# 174502                      6.0             4.0             10.5
# 174503                      4.0             1.5             10.5
# 174504                     18.0            12.5             10.5
# 174505                     12.0            12.5             10.5
#
#         rank_label_count  rank_m_label_mean rank_m_label_count  \
# 0                 -999.0             -999.0             -999.0
# 1                 -999.0             -999.0             -999.0
# 2                 -999.0             -999.0             -999.0
# 3                 -999.0             -999.0             -999.0
# 4                 -999.0             -999.0             -999.0
# 5                 -999.0             -999.0             -999.0
# 6                    8.5                2.0                7.0
# 7                    8.5                8.5                7.0
# 8                    8.5                3.0                7.0
# 9                    1.0                8.5                7.0
# 10                   8.5                8.5                7.0
# 11                   8.5                8.5                7.0
# 12                   8.5                8.5                7.0
# 13                   8.5                8.5                7.0
# 14                   8.5                8.5                7.0
# 15                   3.0                1.0                7.0
# 16                   8.5                8.5                7.0
# 17                   8.5                8.5                7.0
# 18                   2.0                8.5                7.0
# 19                   1.5                4.5                4.0
# 20                   5.0                4.5                4.0
# 21                   5.0                4.5                4.0
# 22                   5.0                1.0                4.0
# 23                   5.0                4.5                4.0
# 24                   1.5                4.5                4.0
# 25                   5.0                4.5                4.0
# 26                   1.0                1.0                1.0
# 27                   2.0                3.0                2.0
# 28                   2.0                2.0                2.0
# 29                   2.0                1.0                2.0
# ...                  ...                ...                ...
# 174476              20.0               20.5               19.0
# 174477              20.0               20.5               19.0
# 174478              20.0               20.5               19.0
# 174479              20.0               20.5               19.0
# 174480              20.0               20.5               19.0
# 174481              20.0               20.5               19.0
# 174482              20.0               20.5               19.0
# 174483              20.0               20.5               19.0
# 174484              20.0               20.5               19.0
# 174485               2.0                2.0                1.5
# 174486               1.0                1.0                1.5
# 174487              10.0               10.5               10.0
# 174488              10.0               10.5               10.0
# 174489              10.0               10.5               10.0
# 174490              10.0               10.5               10.0
# 174491              10.0               10.5               10.0
# 174492              10.0               10.5               10.0
# 174493              10.0               10.5               10.0
# 174494              10.0                1.0               10.0
# 174495              10.0               10.5               10.0
# 174496              10.0               10.5               10.0
# 174497              10.0               10.5               10.0
# 174498              10.0               10.5               10.0
# 174499              10.0               10.5               10.0
# 174500              10.0               10.5               10.0
# 174501              10.0               10.5               10.0
# 174502              10.0               10.5               10.0
# 174503              10.0               10.5               10.0
# 174504              10.0               10.5               10.0
# 174505              10.0               10.5               10.0
#
#         rank_num_candidates  rank_mention_equal_subject  rank_shuminghao  \
# 0                       5.0                         3.5              4.5
# 1                       5.0                         8.0              4.5
# 2                       5.0                         3.5              9.0
# 3                       5.0                         3.5              4.5
# 4                       5.0                         3.5              4.5
# 5                       5.0                         3.5              4.5
# 6                       7.0                         5.5             11.0
# 7                       7.0                         5.5              4.5
# 8                       7.0                         5.5              4.5
# 9                       7.0                        12.0              4.5
# 10                      7.0                         5.5              4.5
# 11                      7.0                        12.0             11.0
# 12                      7.0                         5.5              4.5
# 13                      7.0                         5.5              4.5
# 14                      7.0                        12.0             11.0
# 15                      7.0                         5.5             11.0
# 16                      7.0                         5.5              4.5
# 17                      7.0                         5.5              4.5
# 18                      7.0                         5.5             11.0
# 19                      4.0                         6.5              4.0
# 20                      4.0                         3.0              4.0
# 21                      4.0                         3.0              4.0
# 22                      4.0                         3.0              4.0
# 23                      4.0                         3.0              4.0
# 24                      4.0                         6.5              4.0
# 25                      4.0                         3.0              4.0
# 26                      1.0                         1.0              1.0
# 27                      2.0                         2.0              2.0
# 28                      2.0                         2.0              2.0
# 29                      2.0                         2.0              2.0
# ...                     ...                         ...              ...
# 174476                 19.0                        16.5             16.5
# 174477                 19.0                        16.5             16.5
# 174478                 19.0                        16.5             16.5
# 174479                 19.0                        16.5             16.5
# 174480                 19.0                        16.5             16.5
# 174481                 19.0                        16.5             16.5
# 174482                 19.0                        16.5             16.5
# 174483                 19.0                        16.5             16.5
# 174484                 19.0                        16.5             16.5
# 174485                  1.5                         1.0              1.5
# 174486                  1.5                         2.0              1.5
# 174487                 10.0                         9.5              5.5
# 174488                 10.0                         9.5             15.0
# 174489                 10.0                         9.5             15.0
# 174490                 10.0                         9.5              5.5
# 174491                 10.0                         9.5              5.5
# 174492                 10.0                         9.5             15.0
# 174493                 10.0                         9.5             15.0
# 174494                 10.0                         9.5              5.5
# 174495                 10.0                         9.5              5.5
# 174496                 10.0                         9.5              5.5
# 174497                 10.0                         9.5              5.5
# 174498                 10.0                         9.5              5.5
# 174499                 10.0                         9.5             15.0
# 174500                 10.0                         9.5             15.0
# 174501                 10.0                         9.5              5.5
# 174502                 10.0                         9.5             15.0
# 174503                 10.0                        19.0              5.5
# 174504                 10.0                         9.5             15.0
# 174505                 10.0                         9.5             15.0
#
#         rank_entity_common
# 0                      7.5
# 1                      3.0
# 2                      7.5
# 3                      7.5
# 4                      3.0
# 5                      3.0
# 6                      7.0
# 7                      7.0
# 8                      7.0
# 9                      7.0
# 10                     7.0
# 11                     7.0
# 12                     7.0
# 13                     7.0
# 14                     7.0
# 15                     7.0
# 16                     7.0
# 17                     7.0
# 18                     7.0
# 19                     4.0
# 20                     4.0
# 21                     4.0
# 22                     4.0
# 23                     4.0
# 24                     4.0
# 25                     4.0
# 26                     1.0
# 27                     2.0
# 28                     2.0
# 29                     2.0
# ...                    ...
# 174476                19.0
# 174477                19.0
# 174478                19.0
# 174479                19.0
# 174480                19.0
# 174481                19.0
# 174482                19.0
# 174483                19.0
# 174484                19.0
# 174485                 1.5
# 174486                 1.5
# 174487                 8.5
# 174488                 8.5
# 174489                 8.5
# 174490                 8.5
# 174491                 8.5
# 174492                 8.5
# 174493                18.0
# 174494                 8.5
# 174495                 8.5
# 174496                 8.5
# 174497                18.0
# 174498                 8.5
# 174499                 8.5
# 174500                 8.5
# 174501                 8.5
# 174502                 8.5
# 174503                 8.5
# 174504                18.0
# 174505                 8.5
#
# [174506 rows x 79 columns]

# %%
fold_importance_df = pd.DataFrame()
fold_importance_df["feature"] = predictor2
fold_importance_df["importance"] = bst.feature_importance()
cols = (fold_importance_df[["feature", "importance"]]
        .groupby("feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)

best_features = fold_importance_df.loc[fold_importance_df.feature.isin(cols)]

plt.figure(figsize=(14,25))
sns.barplot(x="importance",
            y="feature",
            data=best_features.sort_values(by="importance",
                                           ascending=False))
plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()
plt.savefig('lgbm_importances.png')

# %%
fold_importance_df = pd.DataFrame()
fold_importance_df["feature"] = predictor2
fold_importance_df["importance"] = bst.feature_importance()
cols = (fold_importance_df[["feature", "importance"]]
        .groupby("feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)

best_features = fold_importance_df.loc[fold_importance_df.feature.isin(cols)]

plt.figure(figsize=(14,25))
sns.barplot(x="importance",
            y="feature",
            data=best_features.sort_values(by="importance",
                                           ascending=False))
plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()
plt.savefig('lgbm_importances.png')
