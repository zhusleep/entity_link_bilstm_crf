# %%
# coding:u8
import pandas as pd
import numpy as np
import copy,gc
import lightgbm as lgb
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import f1_score,classification_report
import matplotlib.pyplot as plt
from tqdm import tqdm as tqdm
import seaborn as sns

# %%
data = pd.read_pickle('features/1_stat_feature.pkl')

# %%
# data = data.fillna(-999)

# %%
data.head()
# Out:
#   text_id   kb_id train_mention  label  num_attrs  num_abstract_words  \
# 0       1  130287          南京南站      0          9                 338
# 1       1  311223          南京南站      1         17                 447
# 2       1  341096            高铁      1         10                 239
# 3       1  213561            高铁      0          1                   0
# 4       1  130287          南京南站      0          9                 338
#
#    num_alias  m_id  num_candidates  mention_equal_subject  ...  \
# 0          2     0               2                   True  ...
# 1          3     0               2                   True  ...
# 2          1     1               2                   True  ...
# 3          2     1               2                  False  ...
# 4          2     2               2                   True  ...
#
#    rank_label_mean  rank_label_count  rank_m_label_mean  rank_m_label_count  \
# 0              NaN               NaN                NaN                 NaN
# 1              NaN               NaN                NaN                 NaN
# 2              1.0               1.5                1.0                 1.5
# 3              2.0               1.5                2.0                 1.5
# 4              NaN               NaN                NaN                 NaN
#
#    rank_num_candidates  rank_mention_equal_subject rank_shuminghao  \
# 0                  1.5                         1.5             1.5
# 1                  1.5                         1.5             1.5
# 2                  1.5                         1.0             1.5
# 3                  1.5                         2.0             1.5
# 4                  1.5                         1.5             1.5
#
#    rank_entity_common  rank_cos_distance  rank_mse_distance
# 0                 1.5                2.0                1.0
# 1                 1.5                1.0                2.0
# 2                 1.0                1.0                2.0
# 3                 2.0                2.0                1.0
# 4                 1.5                2.0                1.0
#
# [5 rows x 82 columns]

# %%
predictor = ['num_attrs',
       'num_abstract_words', 'num_alias', 'num_candidates',
       'mention_equal_subject', 'shuminghao', 'len_mention', 'mention_start',
       'academicdiscipline', 'animal', 'astronomicalobject', 'athlete',
       'awardeventseries', 'brand', 'building', 'collegeoruniversity',
       'communicationmedium', 'country', 'creativework', 'culturalheritage',
       'currency', 'curriculum', 'educationmajor', 'entertainmentperson',
       'event', 'familyname', 'fictionalhuman', 'fictionalthing', 'food',
       'formula', 'game', 'historicalperiod', 'historicalperson', 'human',
       'internationalorganization', 'language', 'material', 'medicalcondition',
       'medicaldepartmenttype', 'movie', 'nation', 'organism', 'organization',
       'person', 'place', 'plant', 'product', 'scientificorganization',
       'symbol', 'theorem', 'thing', 'tool', 'tvplay', 'tvshow', 'vocabulary',
       'zodiacsign', 'label_mean', 'label_count', 'm_label_mean',
       'm_label_count', 'rank_num_attrs', 'rank_num_abstract_words',
       'rank_num_alias', 'rank_label_mean', 'rank_label_count',
       'rank_m_label_mean', 'rank_m_label_count', 'rank_num_candidates',
       'rank_mention_equal_subject', 'rank_shuminghao', 'rank_entity_common','entity_common',
        'rank_cos_distance', 'rank_mse_distance','cos_distance','mse_distance']

# %%
exclude = ['num_abstract_words','rank_num_abstract_words']
# exclude = []
temp = []
for x in predictor:
    if x not in exclude:temp.append(x)
predictor2 = temp

# %%
param = {
    #'num_leaves':100,
    'objective':'binary',
    'metric':'binary_logloss',
    'metric_freq':20,
    'learning_rate': 0.05,
    'num_threads':8,
    #'min_sum_hessian_in_leaf':10,
    'boosting_type':'gbdt',
    'subsample':0.9,
    'colsample_bytree':0.8,
    'n_estimators':20000,
    'min_child_weight':1,
    'subsample_freq':2,
    'num_leaves':64,
    'n_jobs':-1,
}

# %%
kfold = KFold(n_splits=9,shuffle=False,random_state=2019)
for train_index,test_index in kfold.split(data):
    train_data,val_data = data.loc[train_index,:],data.loc[test_index,:]
    print(train_data.shape,val_data.shape)
    train = lgb.Dataset(train_data[predictor2],label=train_data['label'])
    
    validation_data = lgb.Dataset(val_data[predictor2],label=val_data['label'])
    
#     val_data.reset_index(inplace=True,drop=True)
#     val_data.reset_index(inplace=True)
#     index_df = val_data.groupby('m_id')['index'].apply(list)
    
#     label_package = val_data.groupby('m_id',as_index=False)['label'].agg({'label_id_max':'idxmax'})['label_id_max']

    bst = lgb.train(param, train, valid_sets=[validation_data],early_stopping_rounds=200,
                    verbose_eval=100)
    break
#     span = list(np.linspace(0,1, 100))
#     scores = []
#     for i in span:
#         predict_y =  np.where(pred >= i, 1,0)
#         score = f1_score(val_data['label'], predict_y)
#         #print(i,score)
#         scores.append(score)
#     best_score = max(scores)
#     n = scores.index(best_score)/100
#     print(n)
#     val_data['pred'] = pred
#     valid_data = val_data[val_data.pred>n]
#     submit = valid_data.groupby('m_id',as_index=False)['pred'].agg({'label_id_max':'idxmax'})
#     m = submit.shape[0]
#     n = sum(val_data.groupby('m_id')['label'].sum())
#     hit = valid_data.loc[submit['label_id_max'],:]['label'].sum()
#     print(m,n)
#     print(hit/m,hit/n)
#     break
    # 观察阈值
#     val_data['link_grade'] = bst.predict(val_data[predictor2])
#     max_id = val_data.groupby('m_id',as_index=False)['link_grade'].agg({'max_id':'idxmax'})['max_id']
#     val_data_temp = val_data.loc[max_id,:]
#     # 假设label为１的数据有0.84的概率为真
#     m = 0
#     n = 0
#     hit = 0
#     for i in range(100):
#         i = i/100
#         filter_val = val_data_temp[val_data_temp['link_grade']>i]
#         m = filter_val.shape[0]
#         n = 28000
#         hit = filter_val['label'].mean()*m*0.83
#         acc = hit/m
#         recall = hit/n
#         f1 = 2*acc*recall/(acc+recall)
#         print(f1,acc,recall,i)
        
# 0.8672
# 0.872
# [171]	valid_0's binary_logloss: 0.0988336	valid_0's acc: 0.873219
# valid_0's binary_logloss: 0.0964686	valid_0's acc: 0.87713
# [224]	valid_0's binary_logloss: 0.096617	valid_0's acc: 0.877515
# [308]	valid_0's binary_logloss: 0.09149	valid_0's acc: 0.890507 entity common
# drop ctr 0.877
# [2094]	valid_0's binary_logloss: 0.0791409	valid_0's acc: 0.896452
# [1674]	valid_0's binary_logloss: 0.0784442	valid_0's acc: 0.896347
#０．９１５
# [1344]	valid_0's binary_logloss: 0.0767459	valid_0's acc: 0.897395
# [405]	valid_0's binary_logloss: 0.0681472	valid_0's acc: 0.913129
# [1600]	valid_0's binary_logloss: 0.0672695	valid_0's acc: 0.91415
# [2898]	valid_0's binary_logloss: 0.0717056
# Out:
# (1631082, 82) (203886, 82)
# /home/zhukaihua/anaconda3/lib/python3.7/site-packages/lightgbm/engine.py:118: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 200 rounds.
# [100]	valid_0's binary_logloss: 0.0775625
# [200]	valid_0's binary_logloss: 0.074607
# [300]	valid_0's binary_logloss: 0.0739945
# [400]	valid_0's binary_logloss: 0.0737195
# [500]	valid_0's binary_logloss: 0.0734827
# [600]	valid_0's binary_logloss: 0.0733322
# [700]	valid_0's binary_logloss: 0.0731638
# [800]	valid_0's binary_logloss: 0.073075
# [900]	valid_0's binary_logloss: 0.0729923
# [1000]	valid_0's binary_logloss: 0.072954
# [1100]	valid_0's binary_logloss: 0.0728836
# [1200]	valid_0's binary_logloss: 0.0728285
# [1300]	valid_0's binary_logloss: 0.0727956
# [1400]	valid_0's binary_logloss: 0.0728046
# [1500]	valid_0's binary_logloss: 0.0727466
# [1600]	valid_0's binary_logloss: 0.0727218
# [1700]	valid_0's binary_logloss: 0.0726912
# [1800]	valid_0's binary_logloss: 0.0726897
# [1900]	valid_0's binary_logloss: 0.0726411
# [2000]	valid_0's binary_logloss: 0.0726232
# [2100]	valid_0's binary_logloss: 0.0725996
# [2200]	valid_0's binary_logloss: 0.072578
# [2300]	valid_0's binary_logloss: 0.0725784
# [2400]	valid_0's binary_logloss: 0.0726097
# Early stopping, best iteration is:
# [2271]	valid_0's binary_logloss: 0.0725622

# %%
val_data
# Out:
#        text_id   kb_id train_mention  label  num_attrs  num_abstract_words  \
# 0            1  130287          南京南站      0          9                 338
# 1            1  311223          南京南站      1         17                 447
# 2            1  213561            高铁      0          1                   0
# 3            1  341096            高铁      1         10                 239
# 4            1  130287          南京南站      0          9                 338
# 5            1  311223          南京南站      1         17                 447
# 6            1  130287          南京南站      0          9                 338
# 7            1  311223          南京南站      1         17                 447
# 8            2  278410           比特币      1         12                 610
# 9            2   46540           比特币      0          1                   0
# 10           2   91051           比特币      0          9                  49
# 11           2   52784           比特币      0         10                  98
# 12           2  199602            央行      1         12                 346
# 13           2   86638            央行      0         10                 105
# 14           2  215472          界面新闻      1          9                 171
# 15           3  131751         万历十五年      1         16                 185
# 16           3  148733         万历十五年      0          8                  51
# 17           4  219667            迅雷      0          2                  32
# 18           4  105878            迅雷      0         12                  35
# 19           4  367547            迅雷      0          7                  58
# 20           4   57067            迅雷      1         20                 366
# 21           4  281480            迅雷      0          8                  69
# 22           4  241823            迅雷      0          6                  50
# 23           4  341954            迅雷      0          6                  25
# 24           4  202048            迅雷      0         14                 426
# 25           4   64603            迅雷      0         11                 109
# 26           4  394479            美剧      1          8                 176
# 27           5  276126           毛泽东      0         16                  37
# 28           5  348459           毛泽东      0         16                   0
# 29           5   43905           毛泽东      0         11                  62
# ...        ...     ...           ...    ...        ...                 ...
# 203856    9996  124352            医道      0          2                   0
# 203857    9996  251665            医道      0         17                 194
# 203858    9996  309053            医道      1         25                 128
# 203859    9996   54019        一代神医许浚      0         19                 110
# 203860    9996  309053        一代神医许浚      1         25                 128
# 203861    9997  319731             女      0          8                  70
# 203862    9997  114838             女      0         21                  85
# 203863    9997  285726             女      0          9                  77
# 203864    9997  192164             女      0          8                 134
# 203865    9997  275527             女      1         20                 241
# 203866    9997  280401             女      0          8                  65
# 203867    9997  192377             女      0         22                 141
# 203868    9997  232603             女      0          7                 121
# 203869    9997  213245             女      0          6                  87
# 203870    9997  155967            影视      0          9                 282
# 203871    9997  232027            影视      0          8                  42
# 203872    9997  154227            影视      1          9                  82
# 203873    9997  155967            影视      0          9                 282
# 203874    9997  232027            影视      0          8                  42
# 203875    9997  154227            影视      1          9                  82
# 203876    9998  185227            杀青      0         10                 114
# 203877    9998  191617            杀青      0          7                  67
# 203878    9998   22799            杀青      0         11                 120
# 203879    9998  282729            杀青      0         16                 325
# 203880    9998  375794            杀青      0          8                  61
# 203881    9998  122269            杀青      0          7                  53
# 203882    9998  277481            杀青      0          5                  69
# 203883    9999  356388           方莘莘      1          9                 125
# 203884    9999   99597           林中华      1         10                 176
# 203885    9999  196725           林中华      0          7                  68
#
#         num_alias   m_id  num_candidates  mention_equal_subject  ...  \
# 0               2      0               2                   True  ...
# 1               3      0               2                   True  ...
# 2               2      1               2                  False  ...
# 3               1      1               2                   True  ...
# 4               2      2               2                   True  ...
# 5               3      2               2                   True  ...
# 6               2      3               2                   True  ...
# 7               3      3               2                   True  ...
# 8               4      4               4                   True  ...
# 9               1      4               4                   True  ...
# 10              3      4               4                  False  ...
# 11              1      4               4                   True  ...
# 12              9      5               2                  False  ...
# 13              3      5               2                  False  ...
# 14              2      6               1                   True  ...
# 15              2      7               2                   True  ...
# 16              1      7               2                   True  ...
# 17              1      8               9                   True  ...
# 18              5      8               9                  False  ...
# 19              2      8               9                   True  ...
# 20              5      8               9                   True  ...
# 21              6      8               9                  False  ...
# 22              1      8               9                   True  ...
# 23              1      8               9                   True  ...
# 24             18      8               9                  False  ...
# 25              4      8               9                  False  ...
# 26              2      9               1                   True  ...
# 27              1     10              23                   True  ...
# 28              5     10              23                  False  ...
# 29              2     10              23                  False  ...
# ...           ...    ...             ...                    ...  ...
# 203856          1  29860               4                   True  ...
# 203857          1  29860               4                   True  ...
# 203858          5  29860               4                   True  ...
# 203859          1  29861               2                   True  ...
# 203860          5  29861               2                  False  ...
# 203861          2  29862               9                  False  ...
# 203862          3  29862               9                  False  ...
# 203863          4  29862               9                  False  ...
# 203864          1  29862               9                   True  ...
# 203865          1  29862               9                   True  ...
# 203866          2  29862               9                  False  ...
# 203867          3  29862               9                  False  ...
# 203868          2  29862               9                  False  ...
# 203869          3  29862               9                  False  ...
# 203870          2  29863               3                  False  ...
# 203871          3  29863               3                  False  ...
# 203872          2  29863               3                   True  ...
# 203873          2  29864               3                  False  ...
# 203874          3  29864               3                  False  ...
# 203875          2  29864               3                   True  ...
# 203876          1  29865               7                   True  ...
# 203877          1  29865               7                   True  ...
# 203878          1  29865               7                   True  ...
# 203879          2  29865               7                   True  ...
# 203880          1  29865               7                   True  ...
# 203881          1  29865               7                   True  ...
# 203882          1  29865               7                   True  ...
# 203883          1  29866               1                   True  ...
# 203884          1  29867               2                   True  ...
# 203885          1  29867               2                   True  ...
#
#         rank_num_abstract_words  rank_num_alias  rank_label_mean  \
# 0                           2.0             2.0              NaN
# 1                           1.0             1.0              NaN
# 2                           2.0             1.0              2.0
# 3                           1.0             2.0              1.0
# 4                           2.0             2.0              NaN
# 5                           1.0             1.0              NaN
# 6                           2.0             2.0              NaN
# 7                           1.0             1.0              NaN
# 8                           1.0             1.0              1.0
# 9                           4.0             3.5              3.0
# 10                          3.0             2.0              3.0
# 11                          2.0             3.5              3.0
# 12                          1.0             1.0              2.0
# 13                          2.0             2.0              1.0
# 14                          1.0             1.0              1.0
# 15                          1.0             1.0              1.0
# 16                          2.0             2.0              2.0
# 17                          8.0             8.0              6.5
# 18                          7.0             3.5              6.5
# 19                          5.0             6.0              6.5
# 20                          2.0             3.5              1.0
# 21                          4.0             2.0              3.0
# 22                          6.0             8.0              6.5
# 23                          9.0             8.0              6.5
# 24                          1.0             1.0              2.0
# 25                          3.0             5.0              6.5
# 26                          1.0             1.0              1.0
# 27                         20.0            16.5             12.5
# 28                         23.0             2.0             12.5
# 29                         14.0             8.5             12.5
# ...                         ...             ...              ...
# 203856                      4.0             3.0              3.0
# 203857                      1.0             3.0              3.0
# 203858                      2.0             1.0              1.0
# 203859                      2.0             2.0              NaN
# 203860                      1.0             1.0              1.0
# 203861                      8.0             6.0              5.0
# 203862                      6.0             3.0              7.5
# 203863                      7.0             1.0              2.0
# 203864                      3.0             8.5              7.5
# 203865                      1.0             8.5              1.0
# 203866                      9.0             6.0              3.0
# 203867                      2.0             3.0              7.5
# 203868                      4.0             6.0              4.0
# 203869                      5.0             3.0              7.5
# 203870                      1.0             2.5              2.5
# 203871                      3.0             1.0              2.5
# 203872                      2.0             2.5              1.0
# 203873                      1.0             2.5              2.5
# 203874                      3.0             1.0              2.5
# 203875                      2.0             2.5              1.0
# 203876                      3.0             4.5              5.0
# 203877                      5.0             4.5              5.0
# 203878                      2.0             4.5              1.0
# 203879                      1.0             1.0              2.0
# 203880                      6.0             4.5              5.0
# 203881                      7.0             4.5              5.0
# 203882                      4.0             4.5              5.0
# 203883                      1.0             1.0              NaN
# 203884                      1.0             1.5              NaN
# 203885                      2.0             1.5              NaN
#
#         rank_label_count rank_m_label_mean  rank_m_label_count  \
# 0                    NaN               NaN                 NaN
# 1                    NaN               NaN                 NaN
# 2                    1.5               2.0                 1.5
# 3                    1.5               1.0                 1.5
# 4                    NaN               NaN                 NaN
# 5                    NaN               NaN                 NaN
# 6                    NaN               NaN                 NaN
# 7                    NaN               NaN                 NaN
# 8                    1.0               1.0                 2.5
# 9                    3.0               3.0                 2.5
# 10                   3.0               3.0                 2.5
# 11                   3.0               3.0                 2.5
# 12                   1.0               2.0                 1.5
# 13                   2.0               1.0                 1.5
# 14                   1.0               1.0                 1.0
# 15                   1.5               1.0                 1.5
# 16                   1.5               2.0                 1.5
# 17                   7.5               6.5                 5.0
# 18                   5.0               6.5                 5.0
# 19                   7.5               6.5                 5.0
# 20                   3.0               1.0                 5.0
# 21                   2.0               2.5                 5.0
# 22                   7.5               6.5                 5.0
# 23                   7.5               6.5                 5.0
# 24                   1.0               2.5                 5.0
# 25                   4.0               6.5                 5.0
# 26                   1.0               1.0                 1.0
# 27                  14.0              12.5                12.0
# 28                   3.5              12.5                12.0
# 29                  14.0              12.5                12.0
# ...                  ...               ...                 ...
# 203856               2.5               3.0                 2.5
# 203857               2.5               3.0                 2.5
# 203858               2.5               1.0                 2.5
# 203859               NaN               NaN                 NaN
# 203860               1.0               NaN                 NaN
# 203861               4.0               2.5                 5.0
# 203862               7.5               7.0                 5.0
# 203863               1.0               7.0                 5.0
# 203864               7.5               7.0                 5.0
# 203865               7.5               1.0                 5.0
# 203866               3.0               4.0                 5.0
# 203867               5.0               7.0                 5.0
# 203868               2.0               2.5                 5.0
# 203869               7.5               7.0                 5.0
# 203870               2.0               2.5                 2.0
# 203871               2.0               2.5                 2.0
# 203872               2.0               1.0                 2.0
# 203873               2.0               2.5                 2.0
# 203874               2.0               2.5                 2.0
# 203875               2.0               1.0                 2.0
# 203876               4.5               5.0                 4.0
# 203877               4.5               5.0                 4.0
# 203878               4.5               1.0                 4.0
# 203879               1.0               2.0                 4.0
# 203880               4.5               5.0                 4.0
# 203881               4.5               5.0                 4.0
# 203882               4.5               5.0                 4.0
# 203883               NaN               NaN                 NaN
# 203884               NaN               NaN                 NaN
# 203885               NaN               NaN                 NaN
#
#         rank_num_candidates  rank_mention_equal_subject  rank_shuminghao  \
# 0                       1.5                         1.5              1.5
# 1                       1.5                         1.5              1.5
# 2                       1.5                         2.0              1.5
# 3                       1.5                         1.0              1.5
# 4                       1.5                         1.5              1.5
# 5                       1.5                         1.5              1.5
# 6                       1.5                         1.5              1.5
# 7                       1.5                         1.5              1.5
# 8                       2.5                         2.0              3.5
# 9                       2.5                         2.0              3.5
# 10                      2.5                         4.0              1.5
# 11                      2.5                         2.0              1.5
# 12                      1.5                         1.5              1.5
# 13                      1.5                         1.5              1.5
# 14                      1.0                         1.0              1.0
# 15                      1.5                         1.5              1.0
# 16                      1.5                         1.5              2.0
# 17                      5.0                         3.0              5.0
# 18                      5.0                         7.5              5.0
# 19                      5.0                         3.0              5.0
# 20                      5.0                         3.0              5.0
# 21                      5.0                         7.5              5.0
# 22                      5.0                         3.0              5.0
# 23                      5.0                         3.0              5.0
# 24                      5.0                         7.5              5.0
# 25                      5.0                         7.5              5.0
# 26                      1.0                         1.0              1.0
# 27                     12.0                         8.5              8.5
# 28                     12.0                        20.0             20.0
# 29                     12.0                        20.0             20.0
# ...                     ...                         ...              ...
# 203856                  2.5                         2.5              3.5
# 203857                  2.5                         2.5              1.5
# 203858                  2.5                         2.5              1.5
# 203859                  1.5                         1.0              2.0
# 203860                  1.5                         2.0              1.0
# 203861                  5.0                         6.0              5.0
# 203862                  5.0                         6.0              5.0
# 203863                  5.0                         6.0              5.0
# 203864                  5.0                         1.5              5.0
# 203865                  5.0                         1.5              5.0
# 203866                  5.0                         6.0              5.0
# 203867                  5.0                         6.0              5.0
# 203868                  5.0                         6.0              5.0
# 203869                  5.0                         6.0              5.0
# 203870                  2.0                         2.5              2.0
# 203871                  2.0                         2.5              2.0
# 203872                  2.0                         1.0              2.0
# 203873                  2.0                         2.5              2.0
# 203874                  2.0                         2.5              2.0
# 203875                  2.0                         1.0              2.0
# 203876                  4.0                         4.0              4.0
# 203877                  4.0                         4.0              4.0
# 203878                  4.0                         4.0              4.0
# 203879                  4.0                         4.0              4.0
# 203880                  4.0                         4.0              4.0
# 203881                  4.0                         4.0              4.0
# 203882                  4.0                         4.0              4.0
# 203883                  1.0                         1.0              1.0
# 203884                  1.5                         1.5              1.5
# 203885                  1.5                         1.5              1.5
#
#         rank_entity_common
# 0                      1.5
# 1                      1.5
# 2                      2.0
# 3                      1.0
# 4                      1.5
# 5                      1.5
# 6                      1.5
# 7                      1.5
# 8                      2.0
# 9                      4.0
# 10                     2.0
# 11                     2.0
# 12                     1.5
# 13                     1.5
# 14                     1.0
# 15                     1.5
# 16                     1.5
# 17                     4.0
# 18                     4.0
# 19                     4.0
# 20                     4.0
# 21                     8.5
# 22                     4.0
# 23                     4.0
# 24                     8.5
# 25                     4.0
# 26                     1.0
# 27                    12.0
# 28                    12.0
# 29                    12.0
# ...                    ...
# 203856                 4.0
# 203857                 2.0
# 203858                 1.0
# 203859                 1.5
# 203860                 1.5
# 203861                 5.5
# 203862                 1.0
# 203863                 5.5
# 203864                 5.5
# 203865                 5.5
# 203866                 5.5
# 203867                 5.5
# 203868                 5.5
# 203869                 5.5
# 203870                 2.0
# 203871                 2.0
# 203872                 2.0
# 203873                 2.0
# 203874                 2.0
# 203875                 2.0
# 203876                 4.0
# 203877                 4.0
# 203878                 4.0
# 203879                 4.0
# 203880                 4.0
# 203881                 4.0
# 203882                 4.0
# 203883                 1.0
# 203884                 1.0
# 203885                 2.0
#
# [203886 rows x 78 columns]

# %%
def lgb_f1_score(y_hat, data):
        y_true = data.get_label()
        span = list(np.linspace(0,1, 100))
        scores = []
        for i in span:
            predict_y =  np.where(y_hat >= i, 1,0)
            score = f1_score(y_true, predict_y)
            scores.append(score)
        #print(scores)
        best_score = max(scores)

# %%
pred = bst.predict(val_data[predictor2])
val_data['pred'] = pred

# %%
span = list(np.linspace(0,1, 100))
scores = []
for i in span:
#     predict_y =  np.where(pred >= i, 1,0)
#     score = f1_score(val_data['label'], predict_y)
#     #print(i,score)
#     scores.append(score)
#     best_score = max(scores)
    n = i
    valid_data = val_data[val_data.pred>n]
    submit = valid_data.groupby('m_id',as_index=False)['pred'].agg({'label_id_max':'idxmax'})
    m = submit.shape[0]
    n = sum(val_data.groupby('m_id')['label'].sum())
    hit = valid_data.loc[submit['label_id_max'],:]['label'].sum()
    print(m,n,hit)
    acc = hit/m
    recall = hit/n
    print(i,acc,recall,2*acc*recall/(acc+recall))
# Out:
# 29868 28525 26100
# 0.0 0.8738449176376054 0.9149868536371604 0.8939427671124962
# 29824 28525 26100
# 0.010101010101010102 0.8751341201716738 0.9149868536371604 0.8946168743251811
# 29777 28525 26098
# 0.020202020202020204 0.876448265439769 0.9149167397020158 0.8952694590237043
# 29744 28525 26096
# 0.030303030303030304 0.8773534158149543 0.9148466257668711 0.8957078377868164
# 29716 28525 26095
# 0.04040404040404041 0.8781464530892449 0.9148115687992988 0.8961041190913618
# 29691 28525 26091
# 0.05050505050505051 0.8787511367080933 0.9146713409290096 0.8963515184828913
# 29669 28525 26087
# 0.06060606060606061 0.8792679227476491 0.9145311130587204 0.896552909234629
# 202072          9.0      1.000000            2.0     -0.008617  0.869008
# 202678          3.0      1.000000            3.0      0.472021  0.939849
# 202869         45.0      0.800000           45.0      0.345530  0.903827
# 202989         25.0           NaN            NaN      0.427399  0.851650
# 202991         25.0           NaN            NaN      0.603126  0.816052
# 203543          1.0      1.000000            1.0      0.425766  0.860280
# 203759          3.0      0.666667            3.0      0.288045  0.848317
#
# [774 rows x 11 columns]

# %%
val_data[['text_id','kb_id','train_mention','label','label_mean','label_count','m_label_mean','m_label_count',
          'cos_distance','rank_cos_distance','pred']]
# Out:
#        text_id   kb_id train_mention  label  label_mean  label_count  \
# 0            1  130287          南京南站      0         NaN          NaN
# 1            1  311223          南京南站      1         NaN          NaN
# 2            1  341096            高铁      1    0.777778          9.0
# 3            1  213561            高铁      0    0.222222          9.0
# 4            1  130287          南京南站      0         NaN          NaN
# 5            1  311223          南京南站      1         NaN          NaN
# 6            1  130287          南京南站      0         NaN          NaN
# 7            1  311223          南京南站      1         NaN          NaN
# 8            2   52784           比特币      0    0.000000         19.0
# 9            2   46540           比特币      0    0.000000         19.0
# 10           2  278410           比特币      1    1.000000         20.0
# 11           2   91051           比特币      0    0.000000         19.0
# 12           2  199602            央行      1    0.500000          2.0
# 13           2   86638            央行      0    1.000000          1.0
# 14           2  215472          界面新闻      1    0.538462         65.0
# 15           3  148733         万历十五年      0    0.000000          8.0
# 16           3  131751         万历十五年      1    1.000000          8.0
# 17           4  105878            迅雷      0    0.000000        796.0
# 18           4  341954            迅雷      0    0.000000        794.0
# 19           4  367547            迅雷      0    0.000000        794.0
# 20           4  219667            迅雷      0    0.000000        794.0
# 21           4  281480            迅雷      0    0.188632       5630.0
# 22           4   57067            迅雷      1    0.949825        857.0
# 23           4  202048            迅雷      0    0.281728       9424.0
# 24           4   64603            迅雷      0    0.000000        797.0
# 25           4  241823            迅雷      0    0.000000        794.0
# 26           4  394479            美剧      1    0.991228        114.0
# 27           5  305163           毛泽东      0    0.000000         46.0
# 28           5  289026           毛泽东      1    1.000000         56.0
# 29           5  348459           毛泽东      0    0.000000         47.0
# ...        ...     ...           ...    ...         ...          ...
# 203856    9996  251665            医道      0    0.000000          1.0
# 203857    9996  309053            医道      1    1.000000          1.0
# 203858    9996  124352            医道      0    0.000000          1.0
# 203859    9996  309053        一代神医许浚      1    1.000000          1.0
# 203860    9996   54019        一代神医许浚      0         NaN          NaN
# 203861    9997  232603             女      0    0.500000         96.0
# 203862    9997  192377             女      0    0.000000         48.0
# 203863    9997  192164             女      0    0.000000         44.0
# 203864    9997  285726             女      0    0.554545        110.0
# 203865    9997  319731             女      0    0.408451         71.0
# 203866    9997  275527             女      1    0.886364         44.0
# 203867    9997  114838             女      0    0.000000         44.0
# 203868    9997  280401             女      0    0.537634         93.0
# 203869    9997  213245             女      0    0.000000         44.0
# 203870    9997  155967            影视      0    0.000000        143.0
# 203871    9997  154227            影视      1    1.000000        143.0
# 203872    9997  232027            影视      0    0.000000        143.0
# 203873    9997  155967            影视      0    0.000000        143.0
# 203867      0.000000           44.0     -0.056550                5.0  0.011016
# 203868      0.022727           44.0     -0.111453                9.0  0.008655
# 203869      0.000000           44.0     -0.084599                7.0  0.000315
# 203870      0.000000          143.0     -0.007662                2.0  0.002656
# 203871      1.000000          143.0      0.723169                1.0  0.994227
# 203872      0.000000          143.0     -0.021371                3.0  0.000874
# 203873      0.000000          143.0     -0.026323                3.0  0.002398
# 203874      1.000000          143.0      0.719450                1.0  0.993374
# 203875      0.000000          143.0     -0.023863                2.0  0.000741
# 203876      0.000000           37.0      0.032675                2.0  0.001608
# 203877      0.972973           37.0      0.028915                3.0  0.265581
# 203878      0.027027           37.0     -0.113284                5.0  0.016341
# 203879      0.000000           37.0     -0.149356                6.0  0.002646
# 203880      0.000000           37.0      0.087674                1.0  0.004403
# 203881      0.000000           37.0     -0.102172                4.0  0.000679
# 203882      0.000000           37.0     -0.172304                7.0  0.000425
# 203883           NaN            NaN      0.786317                1.0  0.993019
# 203884           NaN            NaN      0.017506                1.0  0.043175
# 203885           NaN            NaN     -0.047624                2.0  0.967680
#
# [203886 rows x 11 columns]

# %%
# span = list(np.linspace(0,1, 100))
# scores = []
# for i in span:
#     predict_y =  np.where(pred >= i, 1,0)
#     score = f1_score(val_data['label'], predict_y)
#     #print(i,score)
#     scores.append(score)
# best_score = max(scores)
# n = scores.index(best_score)/100
# print(n)

# %%
data
# Out:
#         text_id   kb_id train_mention  label  num_attrs  num_abstract_words  \
# 0             1  130287          南京南站      0          9                 338
# 1             1  311223          南京南站      1         17                 447
# 2             1  213561            高铁      0          1                   0
# 3             1  341096            高铁      1         10                 239
# 4             1  130287          南京南站      0          9                 338
# 5             1  311223          南京南站      1         17                 447
# 6             1  130287          南京南站      0          9                 338
# 7             1  311223          南京南站      1         17                 447
# 8             2  278410           比特币      1         12                 610
# 9             2   46540           比特币      0          1                   0
# 10            2   91051           比特币      0          9                  49
# 11            2   52784           比特币      0         10                  98
# 12            2  199602            央行      1         12                 346
# 13            2   86638            央行      0         10                 105
# 14            2  215472          界面新闻      1          9                 171
# 15            3  131751         万历十五年      1         16                 185
# 16            3  148733         万历十五年      0          8                  51
# 17            4  219667            迅雷      0          2                  32
# 18            4  105878            迅雷      0         12                  35
# 19            4  367547            迅雷      0          7                  58
# 20            4   57067            迅雷      1         20                 366
# 21            4  281480            迅雷      0          8                  69
# 22            4  241823            迅雷      0          6                  50
# 23            4  341954            迅雷      0          6                  25
# 24            4  202048            迅雷      0         14                 426
# 25            4   64603            迅雷      0         11                 109
# 26            4  394479            美剧      1          8                 176
# 27            5  276126           毛泽东      0         16                  37
# 28            5  348459           毛泽东      0         16                   0
# 29            5   43905           毛泽东      0         11                  62
# ...         ...     ...           ...    ...        ...                 ...
# 1834938   89999  259119            主演      0          4                  27
# 1834939   90000  163688            电影      0         14                 239
# 1834940   90000  346274            电影      0         15                  40
# 1834941   90000   62696            电影      0         19                 127
# 1834942   90000  336024            电影      0         16                 135
# 1834943   90000  148097            电影      1         14                 289
# 1834944   90000  372092            电影      0         15                 249
# 1834945   90000  185572            电影      0          6                  26
# 1834946   90000  396669            电影      0         23                 104
# 1834947   90000  143006            电影      0          7                  47
# 1834948   90000  233538            电影      0         11                  37
# 1834949   90000  213260            电影      0         10                 211
# 1834950   90000  388430            电影      0         20                   0
# 1834951   90000   32955            电影      0          8                  86
# 1834952   90000  242124            电影      0         10                  47
# 1834953   90000  202048            电影      0         14                 426
# 1834954   90000   31389            电影      0         30                 134
# 1834955   90000  331456            电影      0          5                  37
# 1834956   90000  129281            电影      0         40                 644
# 1834957   90000   53384            电影      0         13                 116
# 1834958   90000  281810            电影      0          6                  44
# 1834959   90000  152301            电影      0         15                 124
# 1834960   90000  192858            电影      0         14                  72
# 1834961   90000  309616            电影      0         22                 310
# 1834962   90000  182919            电影      0         11                 175
# 1834963   90000  257369            电影      0          7                  25
# 1834964   90000  121519            电影      0         22                 104
# 1834965   90000  146813           尹灵芝      0         11                  78
# 1834966   90000  228837           尹灵芝      0         20                 335
# 1834967   90000  226769           尹灵芝      1          4                  82
#
#          num_alias    m_id  num_candidates  mention_equal_subject  ...  \
# 0                2       0               2                   True  ...
# 1                3       0               2                   True  ...
# 2                2       1               2                  False  ...
# 3                1       1               2                   True  ...
# 4                2       2               2                   True  ...
# 5                3       2               2                   True  ...
# 6                2       3               2                   True  ...
# 7                3       3               2                   True  ...
# 8                4       4               4                   True  ...
# 9                1       4               4                   True  ...
# 10               3       4               4                  False  ...
# 11               1       4               4                   True  ...
# 12               9       5               2                  False  ...
# 13               3       5               2                  False  ...
# 14               2       6               1                   True  ...
# 15               2       7               2                   True  ...
# 16               1       7               2                   True  ...
# 17               1       8               9                   True  ...
# 18               5       8               9                  False  ...
# 19               2       8               9                   True  ...
# 20               5       8               9                   True  ...
# 21               6       8               9                  False  ...
# 22               1       8               9                   True  ...
# 23               1       8               9                   True  ...
# 24              18       8               9                  False  ...
# 25               4       8               9                  False  ...
# 26               2       9               1                   True  ...
# 27               1      10              23                   True  ...
# 28               5      10              23                  False  ...
# 29               2      10              23                  False  ...
# ...            ...     ...             ...                    ...  ...
# 1834938          1  269358               2                   True  ...
# 1834939          1  269359              26                   True  ...
# 1834940          2  269359              26                  False  ...
# 1834941          1  269359              26                   True  ...
# 1834942          3  269359              26                  False  ...
# 1834943         17  269359              26                   True  ...
# 1834944          3  269359              26                   True  ...
# 1834945          1  269359              26                   True  ...
# 1834946          5  269359              26                  False  ...
# 1834947          2  269359              26                  False  ...
# 1834948          1  269359              26                   True  ...
# 1834949          2  269359              26                  False  ...
# 1834950          4  269359              26                  False  ...
# 1834951          1  269359              26                   True  ...
# 1834952          1  269359              26                   True  ...
# 1834953         18  269359              26                  False  ...
# 1834954          3  269359              26                  False  ...
# 1834955          1  269359              26                   True  ...
# 1834956          9  269359              26                  False  ...
# 1834957          7  269359              26                  False  ...
# 1834958          1  269359              26                   True  ...
# 1834959          4  269359              26                  False  ...
# 1834960          2  269359              26                  False  ...
# 1834961          3  269359              26                  False  ...
# 1834962          2  269359              26                  False  ...
# 1834963          3  269359              26                  False  ...
# 1834964          3  269359              26                  False  ...
# 1834965          1  269360               3                   True  ...
# 1834966          3  269360               3                  False  ...
# 1834967          1  269360               3                   True  ...
#
#          rank_num_abstract_words  rank_num_alias  rank_label_mean  \
# 0                            2.0             2.0              NaN
# 1                            1.0             1.0              NaN
# 2                            2.0             1.0              2.0
# 3                            1.0             2.0              1.0
# 4                            2.0             2.0              NaN
# 5                            1.0             1.0              NaN
# 6                            2.0             2.0              NaN
# 7                            1.0             1.0              NaN
# 8                            1.0             1.0              1.0
# 9                            4.0             3.5              3.0
# 10                           3.0             2.0              3.0
# 11                           2.0             3.5              3.0
# 12                           1.0             1.0              2.0
# 13                           2.0             2.0              1.0
# 14                           1.0             1.0              1.0
# 15                           1.0             1.0              1.0
# 16                           2.0             2.0              2.0
# 17                           8.0             8.0              6.5
# 18                           7.0             3.5              6.5
# 19                           5.0             6.0              6.5
# 20                           2.0             3.5              1.0
# 21                           4.0             2.0              3.0
# 22                           6.0             8.0              6.5
# 23                           9.0             8.0              6.5
# 24                           1.0             1.0              2.0
# 25                           3.0             5.0              6.5
# 26                           1.0             1.0              1.0
# 27                          20.0            16.5             12.5
# 28                          23.0             2.0             12.5
# 29                          14.0             8.5             12.5
# ...                          ...             ...              ...
# 1834938                      2.0             2.0              2.0
# 1834939                      6.0            22.5             21.5
# 1834940                     21.0            16.0              8.0
# 1834941                     11.0            22.5             14.0
# 1834942                      9.0            10.5             21.5
# 1834943                      4.0             2.0              1.0
# 1834944                      5.0            10.5             21.5
# 1834945                     24.0            22.5             21.5
# 1834946                     14.5             5.0              9.0
# 1834947                     18.5            16.0              6.5
# 1834948                     22.5            22.5             21.5
# 1834949                      7.0            16.0             15.0
# 1834950                     26.0             6.5             21.5
# 1834951                     16.0            22.5              4.0
# 1834952                     18.5            22.5             21.5
# 1834953                      2.0             1.0              2.0
# 1834954                     10.0            10.5             10.5
# 1834955                     22.5            22.5             21.5
# 1834956                      1.0             3.0              3.0
# 1834957                     13.0             4.0             21.5
# 1834958                     20.0            22.5             21.5
# 1834959                     12.0             6.5             16.0
# 1834960                     17.0            16.0              5.0
# 1834961                      3.0            10.5             12.5
# 1834962                      8.0            16.0             10.5
# 1834963                     25.0            10.5             12.5
# 1834964                     14.5            10.5              6.5
# 1834965                      3.0             2.5              NaN
# 1834966                      1.0             1.0              1.0
# 1834967                      2.0             2.5              NaN
#
#          rank_label_count rank_m_label_mean  rank_m_label_count  \
# 0                     NaN               NaN                 NaN
# 1                     NaN               NaN                 NaN
# 2                     1.5               2.0                 1.5
# 3                     1.5               1.0                 1.5
# 4                     NaN               NaN                 NaN
# 5                     NaN               NaN                 NaN
# 6                     NaN               NaN                 NaN
# 7                     NaN               NaN                 NaN
# 8                     1.0               1.0                 2.5
# 9                     3.0               3.0                 2.5
# 10                    3.0               3.0                 2.5
# 11                    3.0               3.0                 2.5
# 12                    1.0               2.0                 1.5
# 13                    2.0               1.0                 1.5
# 14                    1.0               1.0                 1.0
# 15                    1.5               1.0                 1.5
# 16                    1.5               2.0                 1.5
# 17                    7.5               6.5                 5.0
# 18                    5.0               6.5                 5.0
# 19                    7.5               6.5                 5.0
# 20                    3.0               1.0                 5.0
# 21                    2.0               2.5                 5.0
# 22                    7.5               6.5                 5.0
# 23                    7.5               6.5                 5.0
# 24                    1.0               2.5                 5.0
# 25                    4.0               6.5                 5.0
# 26                    1.0               1.0                 1.0
# 27                   14.0              12.5                12.0
# 28                    3.5              12.5                12.0
# 29                   14.0              12.5                12.0
# ...                   ...               ...                 ...
# 1834938               2.0               2.0                 1.5
# 1834939              21.5              20.5                13.5
# 1834940               8.0               8.5                13.5
# 1834941              21.5               8.5                13.5
# 1834942              21.5              20.5                13.5
# 1834943               1.0               1.0                13.5
# 1834944               6.5              20.5                13.5
# 1834945              21.5              20.5                13.5
# 1834946               3.0               8.5                13.5
# 1834947              10.5               8.5                13.5
# 1834948              21.5              20.5                13.5
# 1834949              15.0              20.5                13.5
# 1834950              21.5              20.5                13.5
# 1834951              21.5               2.0                13.5
# 1834952              21.5              20.5                13.5
# 1834953               2.0               8.5                13.5
# 1834954              15.0               8.5                13.5
# 1834955              21.5              20.5                13.5
# 1834956               4.0               8.5                13.5
# 1834957               5.0              20.5                13.5
# 1834958              21.5              20.5                13.5
# 1834959              13.0              20.5                13.5
# 1834960               6.5               8.5                13.5
# 1834961              10.5               8.5                13.5
# 1834962              15.0               8.5                13.5
# 1834963              10.5               8.5                13.5
# 1834964              10.5               8.5                13.5
# 1834965               NaN               NaN                 NaN
# 1834966               1.0               NaN                 NaN
# 1834967               NaN               NaN                 NaN
#
#          rank_num_candidates  rank_mention_equal_subject  rank_shuminghao  \
# 0                        1.5                         1.5              1.5
# 1                        1.5                         1.5              1.5
# 2                        1.5                         2.0              1.5
# 3                        1.5                         1.0              1.5
# 4                        1.5                         1.5              1.5
# 5                        1.5                         1.5              1.5
# 6                        1.5                         1.5              1.5
# 7                        1.5                         1.5              1.5
# 8                        2.5                         2.0              3.5
# 9                        2.5                         2.0              3.5
# 10                       2.5                         4.0              1.5
# 11                       2.5                         2.0              1.5
# 12                       1.5                         1.5              1.5
# 13                       1.5                         1.5              1.5
# 14                       1.0                         1.0              1.0
# 15                       1.5                         1.5              1.0
# 16                       1.5                         1.5              2.0
# 17                       5.0                         3.0              5.0
# 18                       5.0                         7.5              5.0
# 19                       5.0                         3.0              5.0
# 20                       5.0                         3.0              5.0
# 21                       5.0                         7.5              5.0
# 22                       5.0                         3.0              5.0
# 23                       5.0                         3.0              5.0
# 24                       5.0                         7.5              5.0
# 25                       5.0                         7.5              5.0
# 26                       1.0                         1.0              1.0
# 27                      12.0                         8.5              8.5
# 28                      12.0                        20.0             20.0
# 29                      12.0                        20.0             20.0
# ...                      ...                         ...              ...
# 1834938                  1.5                         1.5              1.0
# 1834939                 13.5                         5.5              7.5
# 1834940                 13.5                        18.5              7.5
# 1834941                 13.5                         5.5              7.5
# 1834942                 13.5                        18.5             20.5
# 1834943                 13.5                         5.5             20.5
# 1834944                 13.5                         5.5             20.5
# 1834945                 13.5                         5.5              7.5
# 1834946                 13.5                        18.5              7.5
# 1834947                 13.5                        18.5             20.5
# 1834948                 13.5                         5.5              7.5
# 1834949                 13.5                        18.5             20.5
# 1834950                 13.5                        18.5             20.5
# 1834951                 13.5                         5.5             20.5
# 1834952                 13.5                         5.5              7.5
# 1834953                 13.5                        18.5             20.5
# 1834954                 13.5                        18.5              7.5
# 1834955                 13.5                         5.5              7.5
# 1834956                 13.5                        18.5             20.5
# 1834957                 13.5                        18.5              7.5
# 1834958                 13.5                         5.5              7.5
# 1834959                 13.5                        18.5             20.5
# 1834960                 13.5                        18.5              7.5
# 1834961                 13.5                        18.5              7.5
# 1834962                 13.5                        18.5             20.5
# 1834963                 13.5                        18.5             20.5
# 1834964                 13.5                        18.5              7.5
# 1834965                  2.0                         1.5              2.5
# 1834966                  2.0                         3.0              1.0
# 1834967                  2.0                         1.5              2.5
#
#          rank_entity_common
# 0                       1.5
# 1                       1.5
# 2                       2.0
# 3                       1.0
# 4                       1.5
# 5                       1.5
# 6                       1.5
# 7                       1.5
# 8                       2.0
# 9                       4.0
# 10                      2.0
# 11                      2.0
# 12                      1.5
# 13                      1.5
# 14                      1.0
# 15                      1.5
# 16                      1.5
# 17                      4.0
# 18                      4.0
# 19                      4.0
# 20                      4.0
# 21                      8.5
# 22                      4.0
# 23                      4.0
# 24                      8.5
# 25                      4.0
# 26                      1.0
# 27                     12.0
# 28                     12.0
# 29                     12.0
# ...                     ...
# 1834938                 1.5
# 1834939                10.5
# 1834940                10.5
# 1834941                10.5
# 1834942                10.5
# 1834943                10.5
# 1834944                10.5
# 1834945                10.5
# 1834946                10.5
# 1834947                10.5
# 1834948                10.5
# 1834949                23.5
# 1834950                10.5
# 1834951                10.5
# 1834952                10.5
# 1834953                10.5
# 1834954                10.5
# 1834955                10.5
# 1834956                23.5
# 1834957                10.5
# 1834958                10.5
# 1834959                23.5
# 1834960                23.5
# 1834961                10.5
# 1834962                23.5
# 1834963                23.5
# 1834964                10.5
# 1834965                 3.0
# 1834966                 1.5
# 1834967                 1.5
#
# [1834968 rows x 78 columns]

# %%
############################## for submit  #####################################

train = lgb.Dataset(data[predictor2],label=data['label'])
param = {
    #'num_leaves':100,
    'objective':'binary',
    #'metric':'acc',
    'metric_freq':20,
    'learning_rate': 0.05,
    'num_threads':8,
    #'min_sum_hessian_in_leaf':10,
    'boosting_type':'gbdt',
    'subsample':0.9,
    'colsample_bytree':0.8,
    'n_estimators':2000,
    'min_child_weight':1,
    'subsample_freq':2,
    'num_leaves':64,
    'n_jobs':-1,
}

bst = lgb.train(param, train)
from sklearn.externals import joblib
joblib.dump(bst, 'model_link/lgb.pkl')

# save model
# load model
#gbm_pickle = joblib.load('lgb.pkl')
# break
# Out:
# /home/zhukaihua/anaconda3/lib/python3.7/site-packages/lightgbm/engine.py:118: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# ['model_link/lgb.pkl']

# %%
predictor2
# Out:
# ['label_mean', 'label_count', 'm_label_mean', 'm_label_count']

# %%
# val_data

# %%
fold_importance_df = pd.DataFrame()
fold_importance_df["feature"] = predictor2
fold_importance_df["importance"] = bst.feature_importance()
cols = (fold_importance_df[["feature", "importance"]]
        .groupby("feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)

best_features = fold_importance_df.loc[fold_importance_df.feature.isin(cols)]

plt.figure(figsize=(14,25))
sns.barplot(x="importance",
            y="feature",
            data=best_features.sort_values(by="importance",
                                           ascending=False))
plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()
plt.savefig('lgbm_importances.png')

# %%
fold_importance_df = pd.DataFrame()
fold_importance_df["feature"] = predictor2
fold_importance_df["importance"] = bst.feature_importance()
cols = (fold_importance_df[["feature", "importance"]]
        .groupby("feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)

best_features = fold_importance_df.loc[fold_importance_df.feature.isin(cols)]

plt.figure(figsize=(14,25))
sns.barplot(x="importance",
            y="feature",
            data=best_features.sort_values(by="importance",
                                           ascending=False))
plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()
plt.savefig('lgbm_importances.png')
