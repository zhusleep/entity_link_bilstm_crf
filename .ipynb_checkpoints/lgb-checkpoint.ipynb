# %%
# coding:u8
import pandas as pd
import numpy as np
import copy,gc
import lightgbm as lgb
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import f1_score,classification_report
import matplotlib.pyplot as plt
from tqdm import tqdm as tqdm
import seaborn as sns
from sklearn.externals import joblib
# Out:
# /home/zhukaihua/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
data = pd.read_pickle('data/step1_5.pkl')

# %%
data2 = pd.read_pickle('data/step2.pkl')

# %%
data3 = pd.read_pickle('data/step5.pkl')

# %%
data4 = pd.read_pickle('data/bert_dis.pkl')

# %%
# data4['type_equal'] = data4['type_equal'].apply(lambda x: 1 if x==True else 0)

# %%
# data4['type_equal'].value_counts()

# %%
data[['text_id','train_mention','kb_id','label','num_candidates']].head(20)
# Out:
#    text_id train_mention   kb_id  label  num_candidates
# 0        1          南京南站  130287      0               2
# 1        1          南京南站  311223      1               2
# 2        1            高铁  341096      1               1
# 3        1          南京南站  130287      0               2
# 4        1          南京南站  311223      1               2
# 5        1          南京南站  130287      0               2
# 6        1          南京南站  311223      1               2
# 7        2           比特币  278410      1               4
# 8        2           比特币   46540      0               4
# 9        2           比特币   52784      0               4
# 10       2           比特币   91051      0               4
# 11       2          界面新闻  215472      1               1
# 12       3         万历十五年  131751      1               2
# 13       3         万历十五年  148733      0               2
# 14       4            迅雷  105878      0               7
# 15       4            迅雷  219667      0               7
# 16       4            迅雷  241823      0               7
# 17       4            迅雷  341954      0               7
# 18       4            迅雷  367547      0               7
# 19       4            迅雷   57067      1               7

# %%
for c in data2.columns:
    if c not in data.columns:
        data[c] = data2[c]
for c in data3.columns:
    if c not in data.columns:
        data[c] = data3[c]
for c in data4.columns:
    if c not in data.columns:
        data[c] = data4[c]

# %%
predictor=data.columns

# %%
exclude = ['text_id',
 'kb_id',
 'train_mention',
 'label',
 'm_id','type']
# exclude = []
temp = []
for x in predictor:
    if x not in exclude :temp.append(x)
predictor2 = temp

# %%
param = {
    #'num_leaves':100,
    'objective':'binary',
    'metric':'binary_logloss',
    'metric_freq':20,
    'learning_rate': 0.05,
    'num_threads':6,
    #'min_sum_hessian_in_leaf':10,
    'boosting_type':'gbdt',
    'subsample':0.9,
    #'xgboost_dart_mode':True,
    'colsample_bytree':0.8,
    'n_estimators':10000,
    'min_child_weight':2,
    'subsample_freq':2,
    'num_leaves':32,
    'n_jobs':-1,
}

# %%
data.shape
# Out:
# (1566680, 611)

# %%
kfold = KFold(n_splits=5,shuffle=False,random_state=2019)
c = 0
for train_index,test_index in kfold.split(data):
    #train_data,val_data = data.loc[train_index,:],data.loc[test_index,:]
    train_data,val_data = data.loc[train_index,:],data.loc[test_index,:]
    print(train_data.shape,val_data.shape)
    train = lgb.Dataset(train_data[predictor2],label=train_data['label'])
    
    validation_data = lgb.Dataset(val_data[predictor2],label=val_data['label'])
    #break
#     val_data.reset_index(inplace=True,drop=True)
#     val_data.reset_index(inplace=True)
#     index_df = val_data.groupby('m_id')['index'].apply(list)
    
#     label_package = val_data.groupby('m_id',as_index=False)['label'].agg({'label_id_max':'idxmax'})['label_id_max']

    bst = lgb.train(param, train, valid_sets=[validation_data],early_stopping_rounds=200,
                    verbose_eval=100)
    #joblib.dump(bst, 'model_link/lgb_gbdt_%d.pkl'%c)
    c+=1
    break

    # 观察阈值
#     val_data['link_grade'] = bst.predict(val_data[predictor2])
#     max_id = val_data.groupby('m_id',as_index=False)['link_grade'].agg({'max_id':'idxmax'})['max_id']
#     val_data_temp = val_data.loc[max_id,:]
#     # 假设label为１的数据有0.84的概率为真
#     m = 0
#     n = 0
#     hit = 0
#     for i in range(100):
#         i = i/100
#         filter_val = val_data_temp[val_data_temp['link_grade']>i]
#         m = filter_val.shape[0]
#         n = 28000
#         hit = filter_val['label'].mean()*m*0.83
#         acc = hit/m
#         recall = hit/n
#         f1 = 2*acc*recall/(acc+recall)
#         print(f1,acc,recall,i)
        
#０．９１５
# [1344]	valid_0's binary_logloss: 0.0767459	valid_0's acc: 0.897395
# [405]	valid_0's binary_logloss: 0.0681472	valid_0's acc: 0.913129
# [1600]	valid_0's binary_logloss: 0.0672695	valid_0's acc: 0.91415
# [2898]	valid_0's binary_logloss: 0.0717056
# [100]	valid_0's binary_logloss: 0.0787558 0.071
# [12100]	valid_0's binary_logloss: 0.068946 dart
# [3476]	valid_0's binary_logloss: 0.0705663
# [1879]	valid_0's binary_logloss: 0.0697744 gbdt
# [8200]	valid_0's binary_logloss: 0.068178 dart
# pure hello [2162]	valid_0's binary_logloss: 0.0516024
# hello train,data test 
# [3100]	valid_0's binary_logloss: 0.0671858 gbdt
# 2737 0.0676
# 0.035
# 0.0343
# 0.0349
# [2499]	valid_0's binary_logloss: 0.0697551
# [2298]	valid_0's binary_logloss: 0.0684312
# [100]	valid_0's binary_logloss: 0.146277
# [1945]	valid_0's binary_logloss: 0.0693056
# [28]	valid_0's binary_logloss: 0.314403
# [87]	valid_0's binary_logloss: 0.0789237
# Out:
# (1253344, 611) (313336, 611)
# /home/zhukaihua/anaconda3/lib/python3.7/site-packages/lightgbm/engine.py:118: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 200 rounds.
# [100]	valid_0's binary_logloss: 0.075955
# [200]	valid_0's binary_logloss: 0.071715
# [300]	valid_0's binary_logloss: 0.0707703
# [400]	valid_0's binary_logloss: 0.0703232
# [500]	valid_0's binary_logloss: 0.0700026

# %%
data['m_id'].max()

# %%
bst.current_iteration()

# %%
# 
# joblib.dump(bst, 'model_link/lgb_dart.pkl')
#import copy
bst = joblib.load('model_link/lgb_gbdt_0.pkl')
#pred2 = bst2.predict(val_data_dart[predictor2])

# %%
def lgb_f1_score(y_hat, data):
        y_true = data.get_label()
        span = list(np.linspace(0,1, 100))
        scores = []
        for i in span:
            predict_y =  np.where(y_hat >= i, 1,0)
            score = f1_score(y_true, predict_y)
            scores.append(score)
        #print(scores)
        best_score = max(scores)

# %%
valid_data = val_data[val_data.pred>0.4]
submit = valid_data.groupby('m_id',as_index=False)['pred'].agg({'label_id_max':'idxmax'})
m = submit.shape[0]
n = sum(val_data.groupby('m_id')['label'].sum())

# %%
m

# %%
# 标注错误总结
1 非nil标注为nil
2 kb_id链接到其他词汇
3 可标可不标
4 纯粹标注错误
label=0 预测偏大 纠正
label=1 预测偏小 纠正

# %%
val_data.to_pickle('data/old.pkl')

# %%
val_data = pd.read_pickle('data/t_val.pkl')

# %%
pred = bst.predict(val_data[predictor2])
val_data['pred'] = pred

# %%
span = list(np.linspace(0,1, 40))
scores = []
for i in span:
#     predict_y =  np.where(pred >= i, 1,0)
#     score = f1_score(val_data['label'], predict_y)
#     #print(i,score)
#     scores.append(score)
#     best_score = max(scores)
    n = i
    #val_data.loc[(val_data.label_mean>0.99)&(val_data.label_count>10),'pred']=1
    valid_data = val_data[(val_data.pred>n)]
    v_index = valid_data.loc[valid_data.pred>0.99,'pred'].index

    #valid_data.loc[(valid_data.label_mean==0)&(valid_data.label_count>15),'pred']=0

    submit = valid_data.groupby('m_id',as_index=False)['pred'].agg({'label_id_max':'idxmax'})
    submit_index = np.array(list(set(list(submit['label_id_max'])+list(v_index))))
    m = submit.shape[0]
    n = sum(val_data.groupby('m_id')['label'].sum())
    #hit = valid_data.loc[submit['label_id_max']|valid_data.pred>0.9,:]['label'].sum()
    hit = valid_data.loc[submit_index,:]['label'].sum()
    print(m,n,hit)
    acc = hit/m
    recall = hit/n
    print(i,acc,recall,2*acc*recall/(acc+recall))
# 0.358974358974359 0.9064828744358535 0.9083260297984225 0.9074035161448484
# 0.41025641025641024 0.9134305067915026 0.9029272567922875 0.9081485138041677
# 0.4358974358974359 0.9561564043528741 0.9456976585764612 0.9508982739050452
# 0.1794871794871795 0.8884175317656177 0.8817278302937068 0.8850600402300017
# 0.4358974358974359 0.9231731834406925 0.9112650102261912 0.9171804461474181
# 0.358974358974359 0.9152727272727272 0.9174412247129579 0.9163556930918358
# Out:
# 51421 49383 45861
# 0.0 0.8918729701872776 0.928679910090517 0.9099043688742511
# 51329 49383 45860
# 0.02564102564102564 0.8934520446531201 0.9286596602069538 0.9107157041861943
# 51257 49383 45857
# 0.05128205128205128 0.894648535809743 0.9285989105562643 0.9113076311605723
# 51177 49383 45851
# 0.07692307692307693 0.8959298122203333 0.9284774112548853 0.9119132856006363
# 51064 49383 45832
# 0.10256410256410256 0.8975403415321949 0.9280926634671851 0.9125608529871475
# 50947 49383 45818
# 0.1282051282051282 0.8993267513298133 0.9278091650973007 0.9133459583374863
# 50814 49383 45790
# 0.15384615384615385 0.9011296099500138 0.9272421683575319 0.9139994211403535
# 50680 49383 45756
# 0.1794871794871795 0.9028413575374902 0.9265536723163842 0.9145438373824492
# 50536 49383 45718
# 0.20512820512820512 0.9046620231122369 0.9257841767409838 0.9151012319979184
# 50361 49383 45667
# 0.23076923076923075 0.9067929548658684 0.9247514326792621 0.9156841514276548
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-6cc140da1ae0> in <module>
#      14     #valid_data.loc[(valid_data.label_mean==0)&(valid_data.label_count>15),'pred']=0
#      15
# ---> 16     submit = valid_data.groupby('m_id',as_index=False)['pred'].agg({'label_id_max':'idxmax'})
#      17     submit_index = np.array(list(set(list(submit['label_id_max'])+list(v_index))))
#      18     m = submit.shape[0]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, arg, *args, **kwargs)
#    1313     @Appender(_shared_docs['aggregate'])
#    1314     def aggregate(self, arg, *args, **kwargs):
# -> 1315         return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#    1316
#    1317     agg = aggregate
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, arg, *args, **kwargs)
#     184
#     185         _level = kwargs.pop('_level', None)
# --> 186         result, how = self._aggregate(arg, _level=_level, *args, **kwargs)
#     187         if how is None:
#     188             return result
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/base.py in _aggregate(self, arg, *args, **kwargs)
#     479                 if len(sl) == 1:
#     480
# --> 481                     result = _agg(arg, lambda fname,
#     482                                   agg_how: _agg_1dim(self._selection, agg_how))
#     483
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/base.py in _agg(arg, func)
#     447                 result = compat.OrderedDict()
#     448                 for fname, agg_how in compat.iteritems(arg):
# --> 449                     result[fname] = func(fname, agg_how)
#     450                 return result
#     451
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/base.py in <lambda>(fname, agg_how)
#     480
#     481                     result = _agg(arg, lambda fname,
# --> 482                                   agg_how: _agg_1dim(self._selection, agg_how))
#     483
#     484                 # we are selecting the same set as we are aggregating
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/base.py in _agg_1dim(name, how, subset)
#     430                     raise SpecificationError("nested dictionary is ambiguous "
#     431                                              "in aggregation")
# --> 432                 return colg.aggregate(how, _level=(_level or 0) + 1)
#     433
#     434             def _agg_2dim(name, how):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     758         _level = kwargs.pop('_level', None)
#     759         if isinstance(func_or_funcs, compat.string_types):
# --> 760             return getattr(self, func_or_funcs)(*args, **kwargs)
#     761
#     762         if isinstance(func_or_funcs, compat.Iterable):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in wrapper(*args, **kwargs)
#     604
#     605             try:
# --> 606                 return self.apply(curried_with_axis)
#     607             except Exception:
#     608                 try:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in apply(self, func, *args, **kwargs)
#     747                       examples=_apply_docs['series_examples']))
#     748     def apply(self, func, *args, **kwargs):
# --> 749         return super(SeriesGroupBy, self).apply(func, *args, **kwargs)
#     750
#     751     @Substitution(see_also=_agg_see_also_doc,
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     687         with option_context('mode.chained_assignment', None):
#     688             try:
# --> 689                 result = self._python_apply_general(f)
#     690             except Exception:
#     691
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f)
#     705     def _python_apply_general(self, f):
#     706         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 707                                                    self.axis)
#     708
#     709         return self._wrap_applied_output(
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/ops.py in apply(self, f, data, axis)
#     183
#     184         result_values = []
# --> 185         for key, (i, group) in zip(group_keys, splitter):
#     186             object.__setattr__(group, 'name', key)
#     187
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/ops.py in __iter__(self)
#     826             #     raise AssertionError('Start %s must be less than end %s'
#     827             #                          % (str(start), str(end)))
# --> 828             yield i, self._chop(sdata, slice(start, end))
#     829
#     830     def _get_sorted_data(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/ops.py in _chop(self, sdata, slice_obj)
#     841
#     842     def _chop(self, sdata, slice_obj):
# --> 843         return sdata._get_values(slice_obj).to_dense()
#     844
#     845
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in _get_values(self, indexer)
#     975     def _get_values(self, indexer):
#     976         try:
# --> 977             return self._constructor(self._data.get_slice(indexer),
#     978                                      fastpath=True).__finalize__(self)
#     979         except Exception:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in get_slice(self, slobj, axis)
#    1505
#    1506     def get_slice(self, slobj, axis=0):
# -> 1507         if axis >= self.ndim:
#    1508             raise IndexError("Requested axis not found in manager")
#    1509
#
# KeyboardInterrupt:

# %%
valid_data = val_data[val_data.pred>0.4]

submit = valid_data.groupby('m_id',as_index=False)['pred'].agg({'label_id_max':'idxmax'})
val_data['positive'] = 0
val_data.loc[submit['label_id_max'],'positive'] = 1

# %%
a = val_data[val_data.positive!=val_data.label][['text_id','kb_id','train_mention','num_candidates','label','label_mean','label_count','m_label_mean','m_label_count',
          'cos_distance','pred']]
a[a.pred>0.8]
# Out:
#        text_id   kb_id train_mention  num_candidates  label  label_mean  \
# 81          10  371620          少女时代               8      0    1.000000
# 83          10  232160    lion heart               4      0    1.000000
# 693         46  395754            高潮              18      0    1.000000
# 849         52  158891            译文               1      0    1.000000
# 872         54   55422          足球之恋               2      0         NaN
# 1188        65  187123           赛尔号               8      0    0.909091
# 1452        77   43711            人间              27      0    0.692308
# 1678        90  262605      机械战警2014               1      0         NaN
# 1778        94  214171           制片人               6      0    0.909091
# 2003       109  232084       第一次的gal               4      0    0.666667
# 2575       136   14673          南极绝恋               4      0    1.000000
# 2883       149   47777           徐文远               4      0         NaN
# 3094       174  314340            歌手              11      0    0.409722
# 4203       237  226934            董磊               1      0         NaN
# 4324       242  331079            大班               5      0    0.764706
# 5083       279  126309         快速问医生               1      0    1.000000
# 5160       283  276089            压力               9      0    0.750000
# 5211       288  339909            大学               9      0    0.266667
# 5373       304  375989            戴涛               7      0    1.000000
# 5471       310  193957         最美的情缘               2      0    1.000000
# 5481       311   37723            东华               5      0    1.000000
# 5484       311  373933            凤九               4      0    0.416667
# 5496       312  232297        班超重开丝路               2      1         NaN
# 5497       312  394554        班超重开丝路               2      0         NaN
# 5560       315   64725         守护者联盟               8      0    0.750000
# 5940       342   12259            膜拜               4      0    1.000000
# 6173       363   40007           钢琴家               3      0    1.000000
# 6193       365   13546           琉璃碎               2      0         NaN
# 6526       390  127070         让我帮助你               1      0         NaN
# 7032       421  381261            全集               2      0    0.914044
# ...        ...     ...           ...             ...    ...         ...
# 307584   17530  300420            国剧               4      0    0.948718
# 307644   17540  194245       重生之嫡女有毒               2      0         NaN
# 307833   17541   41242             爱             173      0    0.866667
# 308423   17571   77345            大戏               2      0    1.000000
# 308457   17574   38345            频道               2      0    0.850220
# 308793   17594  338078           巽寮湾               2      0         NaN
# 308810   17597  396099           王子瑜               3      0         NaN
# 308849   17601  195400            补丁               2      0    1.000000
# 308925   17607  391114     欢天喜地七仙女续集               2      0         NaN
# 309072   17622  140176            猜测               6      0    1.000000
# 309549   17641  119148           乐酷网               1      0    0.928994
# 310025   17668  215229          经济频道               3      0    1.000000
# 310379   17690  387662          人力资源               1      0    1.000000
# 310447   17696  341070             夏              20      0    1.000000
# 310456   17697  281979            积分               3      0    1.000000
# 310611   17704  219259            替身              43      0    1.000000
# 310809   17719  228790            网友               1      0    1.000000
# 311060   17740  238678            宾虚               6      0    1.000000
# 311163   17746  256819          基础化学               9      0         NaN
# 311305   17749   77320            英雄              95      0    0.827957
# 311405   17763  365019            故宫               8      0    0.888889
# 311856   17782  108912            高炮               2      0         NaN
# 312251   17804   44309           爱呀呀               2      0    1.000000
# 312336   17810   64467       美丽中国走起来               2      0    1.000000
# 312648   17822  345800           作曲家               3      0    1.000000
# 312779   17835  123870         若你碰到他               3      0    0.000000
# 313021   17847  398618           詹伯a               3      0         NaN
# 313156   17856  205441            王子              71      0    0.750000
# 313245   17858  100187             值               1      0         NaN
# 313269   17861  408317            作文               2      0    0.987220
#
#         label_count  m_label_mean  m_label_count  cos_distance      pred
# 81             24.0      1.000000           23.0      1.345151  0.996715
# 83              2.0      1.000000            2.0      2.851580  0.897865
# 693             3.0      1.000000            3.0      0.901810  0.975391
# 849            51.0      1.000000           51.0      2.304226  0.996709
# 872             NaN           NaN            NaN      6.499876  0.964783
# 1188           11.0      0.900000           10.0      1.122191  0.917924
# 1452           13.0      0.692308           13.0      1.046929  0.901603
# 1678            NaN           NaN            NaN      3.024190  0.990927
# 1778           22.0      0.909091           22.0      1.941147  0.946392
# 2003            3.0      1.000000            2.0      7.940361  0.817194
# 2575            3.0      1.000000            3.0      6.759214  0.944172
# 2883            NaN           NaN            NaN      1.225204  0.895290
# 3094          144.0      0.409722          144.0      1.120924  0.847693
# 4203            NaN           NaN            NaN      3.076832  0.855392
# 4324           17.0      0.764706           17.0      1.066734  0.913026
# 5083            5.0      1.000000            5.0      0.739265  0.995561
# 5160            4.0      0.750000            4.0      0.944332  0.811548
# 5211           30.0      0.266667           30.0      5.028526  0.941066
# 5373            1.0      1.000000            1.0      1.732492  0.979801
# 5471            2.0      1.000000            2.0      9.180652  0.814456
# 5481            5.0      1.000000            1.0      1.052602  0.931192
# 5484           12.0      1.000000            4.0      1.076415  0.913881
# 5496            NaN           NaN            NaN      6.164492  0.810001
# 5497            NaN           NaN            NaN      6.160767  0.817826
# 5560            4.0      1.000000            3.0      4.853843  0.953159
# 5940            1.0      1.000000            1.0      1.137888  0.899890
# 6173           13.0      1.000000           13.0      0.893934  0.938781
# 6193            NaN           NaN            NaN      8.058228  0.934643
# 6526            NaN           NaN            NaN      4.062572  0.854589
# 7032          826.0      0.914044          826.0      2.403581  0.897474
# ...             ...           ...            ...           ...       ...
# 307584         39.0      1.000000            2.0      0.581397  0.856983
# 307644          NaN           NaN            NaN      1.622163  0.865883
# 307833         45.0      0.866667           45.0      1.995908  0.974752
# 308423          7.0      1.000000            7.0      0.884865  0.996388
# 308457        227.0      0.850220          227.0      1.568144  0.877973
# 308793          NaN           NaN            NaN      0.837372  0.903039
# 308810          NaN           NaN            NaN      0.916963  0.811670
# 308849          5.0      1.000000            5.0      1.124597  0.994100
# 308925          NaN           NaN            NaN      0.893222  0.877184
# 309072          1.0      1.000000            1.0      1.733219  0.830289
# 309549        169.0      0.928994          169.0      1.127269  0.961066
# 310025          4.0      1.000000            2.0      0.849946  0.972452
# 310379          4.0      1.000000            4.0      0.638350  0.868769
# 310447          2.0      1.000000            1.0      1.509792  0.882064
# 310456          2.0      1.000000            2.0      1.378276  0.942642
# 310611          7.0      1.000000            7.0      2.544882  0.943359
# 310809        122.0      1.000000          122.0      2.566637  0.999640
# 311060          3.0      1.000000            3.0      0.961251  0.866954
# 311163          NaN           NaN            NaN      1.639728  0.825529
# 311305         93.0      0.827957           93.0      3.801269  0.894092
# 311405          9.0      0.888889            9.0      1.148333  0.901825
# 311856          NaN           NaN            NaN      1.228151  0.816759
# 312251          1.0      1.000000            1.0      8.304399  0.808884
# 312336          1.0      1.000000            1.0      2.414405  0.847415
# 312648          7.0      1.000000            7.0      0.775427  0.988515
# 312779          1.0      0.000000            1.0      4.344709  0.856714
# 313021          NaN           NaN            NaN      9.616705  0.802593
# 313156         12.0      0.750000           12.0      6.501532  0.828294
# 313245          NaN           NaN            NaN      2.099416  0.995730
# 313269        313.0      0.987220          313.0      1.083861  0.984927
#
# [1204 rows x 11 columns]

# %%
a[(a.label_mean>=0.99)&(a.label_count>10)]

# %%
val_data[(val_data.m_label_count>10)&(val_data.m_label_mean==1)&(val_data.positive!=val_data.label)]\
[['text_id','kb_id','train_mention','num_candidates','label','label_mean','label_count','m_label_mean','m_label_count',
          'pred']]

# %%
val_data[(val_data.m_label_count>10)&(val_data.m_label_mean==1)&(val_data.positive!=val_data.label)]\
[['text_id','kb_id','train_mention','num_candidates','label','label_mean','label_count','m_label_mean','m_label_count',
          'pred']]

# %%
val_data[val_data.positive!=val_data.label].shape

# %%
val_data.shape

# %%
# a = val_data[val_data.positive!=val_data.label][['text_id','kb_id','train_mention','num_candidates','label','label_mean','label_count','m_label_mean','m_label_count',
#           'pred']]
# a[a.pred>0.8]

# %%
# val_data[['text_id','kb_id','train_mention','label','label_mean','label_count','m_label_mean','m_label_count',
#           'cos_distance','rank_cos_distance','pred']]

# %%
# span = list(np.linspace(0,1, 100))
# scores = []
# for i in span:
#     predict_y =  np.where(pred >= i, 1,0)
#     score = f1_score(val_data['label'], predict_y)
#     #print(i,score)
#     scores.append(score)
# best_score = max(scores)
# n = scores.index(best_score)/100
# print(n)

# %%
############################## for submit  #####################################

train = lgb.Dataset(data[predictor2],label=data['label'])
param = {
    #'num_leaves':100,
    'objective':'binary',
    'metric':'binary_logloss',
    'metric_freq':20,
    'learning_rate': 0.05,
    'num_threads':6,
    #'min_sum_hessian_in_leaf':10,
    'boosting_type':'gbdt',
    'subsample':0.9,
    #'xgboost_dart_mode':True,
    'colsample_bytree':0.8,
    'n_estimators':2000,
    'min_child_weight':2,
    'subsample_freq':2,
    'num_leaves':32,
    'n_jobs':-1,
}


bst = lgb.train(param, train)
from sklearn.externals import joblib
joblib.dump(bst, 'model_link/lgb.pkl')

# save model
# load model
#gbm_pickle = joblib.load('lgb.pkl')
# break

# %%
predictor2

# %%
# val_data

# %%
best_features.sort_values(by=['importance'])

# %%
data[['text_id','kb_id','train_mention','label','label_mean','label_count','kbid_rank_label_mean']].sort_values(by='kb_id')

# %%
max(data['m_id'])

# %%
fold_importance_df = pd.DataFrame()
fold_importance_df["feature"] = predictor2
fold_importance_df["importance"] = bst.feature_importance()
cols = (fold_importance_df[["feature", "importance"]]
        .groupby("feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:100].index)

best_features = fold_importance_df.loc[fold_importance_df.feature.isin(cols)]

plt.figure(figsize=(14,25))
sns.barplot(x="importance",
            y="feature",
            data=best_features.sort_values(by="importance",
                                           ascending=False))
plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()
plt.savefig('lgbm_importances.png')

# %%
fold_importance_df = pd.DataFrame()
fold_importance_df["feature"] = predictor2
fold_importance_df["importance"] = bst.feature_importance()
cols = (fold_importance_df[["feature", "importance"]]
        .groupby("feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)

best_features = fold_importance_df.loc[fold_importance_df.feature.isin(cols)]

plt.figure(figsize=(14,25))
sns.barplot(x="importance",
            y="feature",
            data=best_features.sort_values(by="importance",
                                           ascending=False))
plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()
plt.savefig('lgbm_importances.png')

# %%
fold_importance_df = pd.DataFrame()
fold_importance_df["feature"] = predictor2
fold_importance_df["importance"] = bst.feature_importance()
cols = (fold_importance_df[["feature", "importance"]]
        .groupby("feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)

best_features = fold_importance_df.loc[fold_importance_df.feature.isin(cols)]

plt.figure(figsize=(14,25))
sns.barplot(x="importance",
            y="feature",
            data=best_features.sort_values(by="importance",
                                           ascending=False))
plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()
plt.savefig('lgbm_importances.png')
