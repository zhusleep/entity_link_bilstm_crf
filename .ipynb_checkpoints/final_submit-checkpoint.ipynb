# %%
# coding:u8
import json
import numpy as np
import pandas as pd
from tqdm import tqdm as tqdm
import gc
from gensim.models import Word2Vec
from sklearn.model_selection import KFold
from sklearn.externals import joblib

import pickle
# Out:
# /home/zhukaihua/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
train_data = []
train_data_dict = {}
with open('data/raw_data/train.json', 'r') as f:
    for line in f:
        raw = eval(str(json.loads(line)).lower())
        train_data.append(raw)
        #train_data_dict[raw['text_id']] = raw
kb = {}
with open('data/raw_data/kb_data', 'r') as f:
    for line in f:
        item = eval(str(json.loads(line)).lower())
        kb[item['subject_id']] = item

name_id = {}
for kb_id in kb:
    for item in kb[kb_id]['alias']:
        if item not in name_id:
            name_id[item] = [kb_id]
        else:
            name_id[item].append(kb_id)
    if kb[kb_id]['subject'] not in name_id:
        name_id[kb[kb_id]['subject']] = [kb_id]
    else:
        name_id[kb[kb_id]['subject']].append(kb_id)
for id in name_id:
    name_id[id] = sorted(list(set(name_id[id])))

# %%
testfile_name = 'data/raw_data/eval722.json'
raw_submit = []
text_idto_text = {}
with open(testfile_name, 'r') as f:
    for line in tqdm(f):
        s = json.loads(line)
        text_idto_text[s['text_id']] = s['text']
        raw_submit.append(s)
# Out:
# 30000it [00:00, 35128.07it/s]

# %%
data = pd.read_pickle('data/step1_5_test.pkl') #nume

# %%
data2 = pd.read_pickle('data/step2_test.pkl') #ctr
data3 = pd.read_pickle('data/step5_test.pkl') # deep cosine

# %%
data4 = pd.read_pickle('data/step3_test.pkl') # tfidf 
data5 = pd.read_pickle('data/step7_test.pkl') # bert distance

# %%
data6 = pd.read_pickle('data/step4_test.pkl') #deepmatch
data7 = pd.read_pickle('data/step6_feature_test.pkl') # deeptype

# %%
data8 = pd.read_pickle('data/step6_v2_feature_test.pkl') # deeptype

# %%
exclude = ['text_id',
 'kb_id',
 'train_mention',
 'label',
 'm_id','type','type_vectors']
for item in data8.columns:
    if item not in exclude:
        data8.rename(columns={item:'v2_'+item},inplace=True)

# %%
data8['type_loss_all'] = (data8['v2_type_loss']+data7['type_loss'])/2

# %%
for df in [data2,data3,data4,data5,data6,data7,data8]:
    
    for c in df.columns:
        if c not in data.columns:
            data[c] = df[c]
    del df
    gc.collect()
# for c in data4.columns:
#     if c not in data.columns:
#         data[c] = data4[c]

# %%
predictor=data.columns
exclude = ['text_id',
 'kb_id',
 'train_mention',
 'label',
 'm_id','type','type_vectors']
# exclude = []
temp = []
for x in predictor:
    if x not in exclude :temp.append(x)
predictor2 = temp

# %%
grades = np.zeros((len(data),4))
for i in range(4):
    gbm_pickle = joblib.load('model_link/lgb_gbdt_%d.pkl'%i)
    grades[:,i]=gbm_pickle.predict(data[predictor2])
    assert len(gbm_pickle.feature_name()) == len(predictor2)

# %%
data['text_id'].head()
# Out:
# 0    1
# 1    2
# 2    2
# 3    2
# 4    2
# Name: text_id, dtype: object

# %%
data['link_grade'] = np.mean(grades,axis=1)

# %%
data['link_grade'].head(5)
# Out:
# 0    0.996788
# 1    0.003224
# 2    0.000347
# 3    0.002200
# 4    0.043198
# Name: link_grade, dtype: float64

# %%
data.shape
# Out:
# (764217, 783)

# %%
data.iloc[0:10000,:].describe().loc['mean',:].to_csv('data/mean_feature2.csv',sep='\t')
# Out:
# /home/zhukaihua/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.

# %%
# 过滤低预测值数据
valid_data = data[data.link_grade>0.4]
submit = valid_data.groupby('m_id',as_index=False)['link_grade'].agg({'label_id_max':'idxmax'})
m = submit.shape[0]

# %%
data['m_id'].nunique()
# Out:
# 95776

# %%
submit.shape
# Out:
# (91086, 2)

# %%
data[['text_id','kb_id','train_mention','label_mean','label_count','m_label_mean',
                                 'm_label_count','link_grade']].head(20)
# Out:
#    text_id   kb_id train_mention  label_mean  label_count  m_label_mean  \
# 0        1   43362          个人主页    0.992701        137.0      0.992701
# 1        2  101382          野蛮女友         NaN          NaN           NaN
# 2        2  104143          野蛮女友         NaN          NaN           NaN
# 3        2  107628          野蛮女友         NaN          NaN           NaN
# 4        2  137924          野蛮女友    0.000000          4.0           NaN
# 5        2   13889          野蛮女友         NaN          NaN           NaN
# 6        2   16345          野蛮女友         NaN          NaN           NaN
# 7        2  260196          野蛮女友         NaN          NaN           NaN
# 8        2  327016          野蛮女友         NaN          NaN           NaN
# 9        2   71447          野蛮女友    0.750000          4.0           NaN
# 10       2  152760            人物    0.795380        303.0      0.795380
# 11       2  222547            人物    0.000000        303.0      0.000000
# 12       2  283650            人物    0.191419        303.0      0.191419
# 13       2  315478            人物    0.000000        303.0      0.000000
# 14       2  328122            人物    0.000000        331.0      0.000000
# 15       2  388116            人物    0.000000        514.0      0.000000
# 16       2  389684            人物    0.000000        303.0      0.000000
# 17       2   67464            人物    0.009901        303.0      0.009901
# 18       2  103704            故事    0.000000        413.0      0.000000
# 19       2  108128            故事    0.000000        413.0      0.000000
#
#     m_label_count  link_grade
# 0           137.0    0.996788
# 1             NaN    0.003224
# 2             NaN    0.000347
# 3             NaN    0.002200
# 4             NaN    0.043198
# 5             NaN    0.010164
# 6             NaN    0.002753
# 7             NaN    0.002346
# 8             NaN    0.032471
# 9             NaN    0.763314
# 10          303.0    0.815858
# 11          303.0    0.000366
# 12          303.0    0.188728
# 13          303.0    0.000089
# 14          303.0    0.000047
# 15          303.0    0.000053
# 16          303.0    0.000538
# 17          303.0    0.004517
# 18          413.0    0.000006
# 19          413.0    0.000007

# %%
data[['text_id','kb_id','train_mention','label_mean','label_count','m_label_mean',
                                 'm_label_count','link_grade']].head(20)
# Out:
#    text_id   kb_id train_mention  label_mean  label_count  m_label_mean  \
# 0        1  340082         中国新歌声    0.967742         31.0          1.00
# 1        1   24209          快乐男声    0.000000         15.0          0.00
# 2        1  246979          快乐男声    1.000000         22.0          1.00
# 3        1  364450          快乐男声    0.000000         15.0          0.00
# 4        2  171897          林学概论         NaN          NaN           NaN
# 5        2   57478          林学概论         NaN          NaN           NaN
# 6        2   20282            简介    0.000000       1488.0          0.00
# 7        2  269667            简介    1.000000       1488.0          1.00
# 8        2  306472            简介    0.000000       1488.0          0.00
# 9        3  396325           小彩旗    1.000000          2.0          1.00
# 10       3  114125           杨丽萍    0.000000          8.0          0.00
# 11       3  126589           杨丽萍    0.000000          8.0          0.00
# 12       3  136663           杨丽萍    0.000000          8.0          0.00
# 13       3  161091           杨丽萍    0.000000          8.0          0.00
# 14       3  169146           杨丽萍    0.000000          8.0          0.00
# 15       3  180176           杨丽萍    0.000000          8.0          0.00
# 16       3  230875           杨丽萍    0.000000          8.0          0.00
# 17       3  245774           杨丽萍    0.000000          8.0          0.00
# 18       3   24836           杨丽萍    0.000000          8.0          0.00
# 19       3  255867           杨丽萍    0.666667          9.0          0.75
#
#     m_label_count  link_grade
# 0            30.0    0.991830
# 1            15.0    0.004542
# 2            15.0    0.991998
# 3            15.0    0.003561
# 4             NaN    0.479529
# 5             NaN    0.591996
# 6          1488.0    0.000024
# 7          1488.0    0.999429
# 8          1488.0    0.000010
# 9             2.0    0.997547
# 10            8.0    0.000095
# 11            8.0    0.000785
# 12            8.0    0.000493
# 13            8.0    0.000345
# 14            8.0    0.000563
# 15            8.0    0.000332
# 16            8.0    0.000093
# 17            8.0    0.000940
# 18            8.0    0.000631
# 19            8.0    0.972239

# %%
valid_data.shape
# Out:
# (93100, 703)

# %%
hit = valid_data.loc[submit['label_id_max'],:]
print(hit.head())
valid_data = hit
# Out:
#     create_works  end_with_line  end_with_line2  end_with_point  \
# 0              0              0               0               0
# 9              1              0               0               0
# 10             0              0               0               0
# 31             0              0               0               0
# 60             0              0               0               0
#
#     end_with_shuminghao  entity_common   kb_id  label  len_mention    m_id  \
# 0                     0              1   43362     -1            4  257734
# 9                     1              2   71447     -1            4  257735
# 10                    1              1  152760     -1            2  257736
# 31                    1              1  242292     -1            2  257737
# 60                    0              1   81295     -1            3  257738
#
#     ...  v2_mid_type_equal_var  v2_mid_type_equal_mean  v2_mid_type_equal_max  \
# 0   ...                    NaN                1.000000                      1
# 9   ...               0.194444                0.222222                      1
# 10  ...               0.125000                0.125000                      1
# 31  ...               0.253775                0.452381                      1
# 60  ...                    NaN                0.000000                      0
#
#     v2_mid_type_equal_min  v2_mid_var_loss_var  v2_mid_var_loss_mean  \
# 0                       1                  NaN              1.000000
# 9                       0             0.194444              0.222222
# 10                      0             0.125000              0.125000
# 31                      0             0.253775              0.452381
# 60                      0                  NaN              0.000000
#
#     v2_mid_var_loss_max  v2_mid_var_loss_min  type_loss_all  link_grade
# 0                     1                    1       0.000126    0.996788
# 9                     1                    0       0.013588    0.763314
# 10                    1                    0       0.140779    0.815858
# 31                    1                    0       0.001034    0.953658
# 60                    0                    0       3.916068    0.985838
#
# [5 rows x 783 columns]

# %%
kbid_finder = {}
for index,row in valid_data.iterrows():
    kbid_finder[str(row['text_id'])+row['train_mention']] = str(row['kb_id'])

# %%
# 戴安楠ner
# ner_result = pd.read_csv('result/el_dev_result(1).csv', sep='\t')
# ner_result['offset'] = ner_result['offset'].apply(lambda x: eval(x.lower()))
# ner_result['mention'] = ner_result['mention'].apply(lambda x: eval(x.lower()))
# ner_result = ner_result.rename(columns={'mention': 'pred', 'offset': 'pos'})
# my ner
ner_result = pd.read_pickle('result/ner_bert_result.pkl')
ner_result['text'] = ner_result['text'].apply(lambda x:''.join(x[1:-1]))
ner_result['pos'] = ner_result['pos'].apply(lambda x:[k[0]-1 for k in x])
ner_result['text_id'] = ner_result.index+1
test_data = []
for index, row in ner_result.iterrows():
    item = {}
    item['text_id'] = row['text_id']
    item['text'] = row['text']
    item['mention_data'] = []
    for i, p in enumerate(row['pos']):
        if row['pred'][i] not in name_id:continue
        item['mention_data'].append({'mention': row['pred'][i], 'offset': str(p)})
    test_data.append(item)

# %%
kbid_finder
# Out:
# {'1个人主页': '43362',
#  '2野蛮女友': '71447',
#  '2人物': '152760',
#  '2故事': '242292',
#  '3陈楚生': '81295',
#  '3上班': '219622',
#  '3遇到': '367388',
#  '3解决': '289126',
#  '3前辈': '396131',
#  '3肯定': '389929',
#  '4绝句': '14566',
#  '4成都': '188382',
#  '4诗词': '244562',
#  '6开展': '159223',
#  '6全国': '302011',
#  '6修改': '64063',
#  '6条例': '164667',
#  '8三彩女立俑': '130615',
#  '8朝代': '18571',
#  '8作品': '175316',
#  '9谢谢': '393397',
#  '9奉献': '202404',
#  '9辉煌': '92018',
#  '9荣耀': '243525',
#  '10上海': '88418',
#  '10吃播': '144689',
#  '10美女': '336595',
#  '11嫌弃': '15507',
#  '11轻松': '125691',
#  '11实用': '120285',
#  '12母女': '230387',
#  '12戴野驴': '263660',
#  '12豆子': '372164',
#  '12功夫': '19652',
#  '13视频': '150546',
#  '13不要用我的爱来伤害我': '323453',
#  '14防弹少年团': '306190',
#  '14中国行': '209949',
#  '14纪实': '334261',
#  '14鞋': '176056',
#  '14马桶': '179573',
#  '15新款': '364888',
#  '15自动化': '109825',
#  '15师傅': '154174',
#  '16温德河': '98207',
#  '16洪峰': '381884',
#  '16顺利': '211702',
#  '16通过': '114385',
#  '16永吉县': '25501',
#  '16口前镇': '38505',
#  '16社会新闻': '76077',
#  '17高手': '340628',
#  '17龙卷风': '146089',
#  '17性命': '333134',
#  '17城主': '202289',
#  '17及时': '161013',
#  '18小米公司': '229064',
#  '18上市': '210635',
#  '18申请': '366594',
#  '18雷军': '360806',
#  '18小米': '229064',
#  '19情归何处': '226798',
#  '20老板': '202867',
#  '20美女': '336595',
#  '20失去': '267351',
#  '20原则': '385547',
#  '20涂磊': '227575',
#  '20观众': '34443',
#  '21手机': '393327',
#  '21打开': '376662',
#  '21开关': '32920',
#  '22加拿大': '379820',
#  '22高温': '393867',
#  '22魁北克省': '393412',
#  '22死亡': '229263',
#  '23预告片': '224395',
#  '23电影': '148097',
#  '25王者荣耀': '43232',
#  '25韩信': '386708',
#  '25王者': '205448',
#  '25刺客': '242056',
#  '26桌上足球': '112569',
#  '26手': '278397',
#  '27张小斐': '344364',
#  '27崔志佳': '241951',
#  '27潘斌龙': '91988',
#  '27小品': '118737',
#  '27江湖恩仇录': '381109',
#  '28面子': '134956',
#  '28角色': '182918',
#  '28红发': '35407',
#  '28打脸': '396883',
#  '29银联': '176198',
#  '29发布': '388991',
#  '29五一': '159988',
#  '29数据': '65300',
#  '30北齐后妃传': '284524',
#  '31团长': '275581',
#  '31战争': '98925',
#  '31年代': '196775',
#  '31猪肉': '296940',
#  '31队伍': '317989',
#  '32老公': '379971',
#  '33题目': '385800',
#  '33现场': '150318',
#  '33心理学': '57773',
#  '33战术': '290379',
#  '33对手': '21473',
#  '33紧张': '290045',
#  '34鸟之诗': '288750',
#  '34钢琴': '378404',
#  '35恋爱': '305156',
#  '35体验': '339036',
#  '35感觉': '139863',
#  '36董子健': '336697',
#  '36坚持': '211277',
#  '36节目': '291480',
#  '36严重': '146454',
#  '36助理': '105994',
#  '36调侃': '115383',
#  '37马致远': '365404',
#  '37杂剧': '373607',
#  '37黄粱梦': '216900',
#  '38守望者': '402793',
#  '38影评': '22265',
#  '39海洋': '62128',
#  '39文化': '240445',
#  '39杨丽萍': '255867',
#  '39新作': '274650',
#  '40卡瓦·雷蒙德': '355843',
#  '40资料': '153973',
#  '40图片': '381220',
#  '40视频': '150546',
#  '41书名': '25649',
#  '42微微一笑很倾城': '300950',
#  '42微微': '38805',
#  '42诈骗': '173453',
#  '42短信': '277048',
#  '42肖奈': '331000',
#  '42心思': '265504',
#  '43司机': '87496',
#  '43注意': '297839',
#  '43新规': '215383',
#  '43实施': '245482',
#  '44小沈阳': '364158',
#  '44歌词': '237619',
#  '45人': '368121',
#  '46公司': '119928',
#  '46老总': '210942',
#  '46同学': '205490',
#  '46聚会': '38798',
#  '46亮点': '225580',
#  '47概率论与数理统计': '79212',
#  '47金义明': '315345',
#  '47主编': '221370',
#  '47简介': '269667',
#  '47书评': '23971',
#  '48临江仙': '175953',
#  '48诗词': '244562',
#  '49王菲': '159850',
#  '49片酬': '378958',
#  '49微博': '162139',
#  '49谢霆锋': '146051',
#  '49原因': '386591',
#  '49曝光': '45313',
#  '50德国': '253479',
#  '50型男': '326247',
#  '50院子': '10386',
#  '51动画': '85224',
#  '52大鹏': '53754',
#  '52老板': '202867',
#  '52笔记本电脑': '242379',
#  '52心思': '265504',
#  '52结果': '87859',
#  '52尴尬': '68501',
#  '53原生态': '373274',
#  '53草原': '370092',
#  '53歌曲': '35295',
#  '53如痴如醉': '320131',
#  '54天气': '43409',
#  '54老板': '202867',
#  '55谢霆锋': '146051',
#  '55自拍照': '208396',
#  '55容祖儿': '85913',
#  '55网友': '228790',
#  '56电影': '148097',
#  '56三傻大闹宝莱坞': '22361',
#  '57揭秘': '214956',
#  '57代购': '62792',
#  '58大伙': '19398',
#  '58泡菜': '127781',
#  '58味道': '215459',
#  '59小孩': '197283',
#  '59流泪': '374570',
#  '59功夫': '19652',
#  '60还来得及': '238301',
#  '60电影': '148097',
#  '60鲛珠传': '168718',
#  '60宣传曲': '63295',
#  '60黄子韬': '160424',
#  '60音乐作品': '30299',
#  '61黄渤': '238575',
#  '61杨颖': '366193',
#  '61倪妮': '164995',
#  '61明白': '296461',
#  '62女高怪谈': '346494',
#  '63王一博': '172362',
#  '63冯提莫': '53329',
#  '64日本': '364373',
#  '64暴雨': '206629',
#  '64遇难': '130691',
#  '64人数': '63613',
#  '65别再犹豫': '394151',
#  '65电视剧': '202048',
#  '67英国': '164807',
#  '67哈里王子': '29846',
#  '67婚礼': '90942',
#  '67细节': '91325',
#  '67曝光': '45313',
#  '68方法': '333901',
#  '68简单': '338785',
#  '68健康': '125111',
#  '68好吃': '172599',
#  '69王者荣耀': '43232',
#  '69露娜': '35148',
#  '69手速': '233229',
#  '69对手': '21473',
#  '69泪流满面': '113567',
#  '69瞬间': '192687',
#  '69团灭': '294070',
#  '70陆明华': '362180',
#  '70读书笔记': '307525',
#  '71绅士': '158532',
#  '71逆天': '64694',
#  '71进球': '345856',
#  '71球迷': '210696',
#  '71掌声': '367555',
#  '71c罗': '210171',
#  '71庆祝': '287255',
#  '71感谢': '74183',
#  '72蝙蝠侠': '25817',
#  '73屌丝': '61016',
#  '73逆袭': '117324',
#  '74吉他谱': '61539',
#  '74黄家伟': '268342',
#  '74吉他': '143934',
#  '74爱好者': '33148',
#  '75孙俪': '252389',
#  '75儿子': '138796',
#  '75妈妈': '251471',
#  '76歌手': '314340',
#  '76李泉': '20950',
#  '77惊现': '208941',
#  '77釜山': '28196',
#  '77战斗': '116680',
#  '78火锅': '331890',
#  '79唐朝乐队': '83494',
#  '79梦回唐朝': '229320',
#  '79音乐': '130934',
#  '80新葫芦兄弟': '103684',
#  '80贫民': '192715',
#  '80妖怪': '312905',
#  '81夏铃': '335838',
#  '81镇魂街': '349460',
#  '82欧阳倩': '111315',
#  '82特种兵之火凤凰': '32379',
#  '82角色': '182918',
#  '83解谜游戏': '279471',
#  '83专业': '138787',
#  '83运动员': '275055',
#  '83区别': '94908',
#  '84年轻人': '288292',
#  '84态度': '70983',
#  '84纹身': '272558',
#  '85庄心妍': '42608',
#  '86小品': '118737',
#  '86贾玲': '387138',
#  '86观众': '34443',
#  '87那英': '38153',
#  '87歌': '244486',
#  '87一眼千年': '351206',
#  '88林丹': '172955',
#  '88国足': '290490',
#  '88队长': '396992',
#  '88参加': '135992',
#  '88脱口秀': '90431',
#  '89爸爸': '50958',
#  '89礼物': '66225',
#  '90击败': '242857',
#  '90动物': '154674',
#  '90获得': '406319',
#  '90神秘': '78727',
#  '90礼物': '66225',
#  '90植物': '182588',
#  '90僵尸': '53156',
#  '90手游': '236191',
#  '91视频头条': '319047',
#  '92科幻': '220258',
#  '92大片': '324990',
#  '92逃生': '198658',
#  '92视觉': '31803',
#  '92体验': '339036',
#  '93我要成为世界最强偶像': '383324',
#  '93动漫': '135659',
#  '94吴江': '259341',
#  '94中国网': '294098',
#  '95美国': '396835',
#  '95贸易战': '386354',
#  '95消费者': '83840',
#  '96关智斌': '336492',
#  '96歌': '244486',
#  '96朋友': '21835',
#  '97婆婆': '114463',
#  '97介入': '34154',
#  '97夫妻': '237844',
#  '97生活': '134933',
#  '97妻子': '83004',
#  '97丈夫': '92888',
#  '98媳妇': '135443',
#  '98现身': '315140',
#  '98化妆品': '78197',
#  '98陪同': '238950',
#  '99张红娟': '103991',
#  '99病人': '264064',
#  '99医生': '256765',
#  '99央视新闻': '317813',
#  '99新闻': '233354',
#  '99新闻联播': '35572',
#  '100约会': '181971',
#  '100电影': '148097',
#  '100笑话': '262861',
#  '101贫民窟的百万富翁': '374520',
#  '101电影': '148097',
#  '102心疼': '404809',
#  '102安迪': '146270',
#  '102黄圣依': '354832',
#  '102生病': '371749',
#  '102贴心': '78808',
#  '102照顾': '290730',
#  '103表情': '84665',
#  '103运动员': '275055',
#  '103电视': '381664',
#  '104农村': '393445',
#  '104大爷': '268008',
#  '104技术': '351951',
#  '104鱼': '287970',
#  '105扶华': '183282',
#  '105原创小说': '215143',
#  '105言情小说': '35750',
#  '106三国神将传': '11789',
#  '106英雄': '77320',
#  '106三国': '298606',
#  '107货车': '125225',
#  '107调皮': '244070',
#  '107车主': '290762',
#  '108中国': '199071',
#  '108爆料': '389838',
#  '108娱乐圈': '186914',
#  '108经历': '12530',
#  '108知名': '200068',
#  '108导演': '152557',
#  '108录像带': '318491',
#  '109凤凰女': '85861',
#  '109万磁王': '110464',
#  '109惊呆': '60529',
#  '110小姐姐': '130208',
#  '110走着走着就散了': '193218',
#  '111张宇': '300478',
#  '111用心良苦': '58924',
#  '111情歌': '149032',
#  '111男人': '163190',
#  '112表演': '161061',
#  '112谢广坤': '152569',
#  '112刘老根大舞台': '36014',
#  '112演出': '186311',
#  '113猎毒人': '245125',
#  '113于和伟': '203637',
#  '113消息': '354215',
#  '113侯梦莎': '20957',
#  '114绝密': '346589',
#  '114战斗': '116680',
#  '114政委': '102576',
#  '114邀功': '347587',
#  '115官途刘飞': '179693',
#  '115小说': '64589',
#  '115作者': '402535',
#  '116方法': '333901',
#  '116美味': '191468',
#  '117猫咪': '371715',
#  '117喜欢': '71175',
#  '117老鼠': '211432',
#  '117玩具': '354864',
#  '117画风': '256424',
#  '117风格': '300927',
#  '119滨虎': '222241',
#  '119超能力者': '85703',
#  '120姑娘': '386376',
#  '120背诵': '88966',
#  '120唐诗': '262243',
#  '120爸爸': '50958',
#  '122风景': '202892',
#  '122生日': '20468',
#  '123特务': '152497',
#  '123旅长': '216128',
#  '123迫害': '62091',
#  '124景德镇': '342672',
#  '125鬼谷子': '368009',
#  '125物品': '59147',
#  '126时间的针脚': '126614',
#  '126百度': '317062',
#  '126吉吉影音': '385803',
#  '127拳皇97': '204453',
#  '127世界': '368793',
#  '127见识': '62954',
#  '127实力': '94358',
#  '128杨秀珠': '397639',
#  '128都市快报': '49479',
#  '129勇气': '264063',
#  '129父亲': '377053',
#  '129节目': '291480',
#  '131动画': '85224',
#  '131遥的接球': '345470',
#  '131主角': '239751',
#  '131人设': '22802',
#  '131声优': '387860',
#  '132成吉思汗': '268450',
#  '132简直': '21585',
#  '132无敌': '291729',
#  '133种啥得啥': '69213',
#  '133央视': '37295',
#  '133作家': '44038',
#  '134男人': '163190',
#  '134心': '162172',
#  '134歌': '244486',
#  '135心愿便利贴': '170805',
#  '135音乐': '130934',
#  '136狮子': '111064',
#  '136同伴': '64684',
#  '136厉害': '372145',
#  '137素描少女': '250871',
#  '137韩国': '129281',
#  '137电影': '148097',
#  '138薛之谦': '188215',
#  '138毛不易': '367607',
#  '138完美': '85692',
#  '138诠释': '340511',
#  '139赵本山': '272727',
#  '139徒弟': '135283',
#  '139收藏': '312980',
#  '139干爹': '133334',
#  '139忽悠': '363747',
#  '140乔丹': '259711',
#  '140决裂': '196885',
#  '140内幕': '368168',
#  '141图片': '381220',
#  '141装备': '191343',
#  '141攻略': '263053',
#  '142誓言': '31360',
#  '142心系': '132096',
#  '142近况': '129739',
#  '14312星座': '385941',
#  '143发现': '408248',
#  '143星座': '296028',
#  '144张宇': '300478',
#  '144雨一直下': '167641',
#  '144音乐': '130934',
#  '145中国人民银行': '199602',
#  '145青年': '382301',
#  '145风采': '378221',
#  '146举报': '272374',
#  '146警车': '55547',
#  '146曝光': '45313',
#  '147唐伯虎': '348031',
#  '148公孙离': '137888',
#  '148车祸': '338420',
#  '148现场': '150318',
#  '148皮肤': '44161',
#  '149医师': '35599',
#  '149医生': '256765',
#  '149健客网': '342397',
#  '150董秀娟': '358647',
#  '151流星花园': '21862',
#  '151杉菜': '327979',
#  '151道明寺': '247755',
#  '152国内': '66269',
#  '152宝贝': '151847',
#  '152老外': '89365',
#  '152实验': '393860',
#  '153崔满红': '250861',
#  '153主编': '204720',
#  '153简介': '269667',
#  '154名侦探柯南': '407348',
#  '155青恋': '212993',
#  '155cctv': '37295',
#  '155节目': '291480',
#  '155官网': '189944',
#  '155电视剧': '202048',
#  '156名侦探柯南': '407348',
#  '157朋友': '21835',
#  '157手机屏幕': '336305',
#  '157屏幕': '143636',
#  '157显示': '113482',
#  '157微信': '390206',
#  '157聊天': '151127',
#  '157内容': '130828',
#  '157尴尬': '68501',
#  '157设置': '119470',
#  '159焕然一新': '318554',
#  '161他其实没那么喜欢你': '97244',
#  '162余罪': '283767',
#  '162卧底': '244588',
#  '162任务': '322335',
#  '162奖金': '316241',
#  '163远方': '357114',
#  '163梦': '396969',
#  '163苍茫': '204352',
#  '163潸然泪下': '113052',
#  '164短视频': '369954',
#  '164丈夫': '92888',
#  '164妻子': '83004',
#  '164笑话': '262861',
#  '164柜子': '122843',
#  '165恰如其分': '118557',
#  '165菡萏花开': '394263',
#  '166现场': '150318',
#  '166说法': '173609',
#  '167高晓松': '181510',
#  '167盛赞': '135933',
#  '167吴亦凡': '385249',
#  '167孩子': '148142',
#  '167小事': '77083',
#  '168姐夫': '306096',
#  '168小三': '407582',
#  '168姐姐': '47643',
#  '168打': '184301',
#  '168重伤': '99504',
#  '168妹妹': '40340',
#  '168耳朵': '159097',
#  '169记忆的证明': '353081',
#  '170声线': '183741',
#  '170林俊杰': '381744',
#  '170你好不好': '377748',
#  '171演绎': '218940',
#  '172领导': '57443',
#  '173纸': '137755',
#  '173冰箱': '173117',
#  '173电费': '275235',
#  '173现在': '112763',
#  '173知道': '234421',
#  '174圣诞节': '379039',
#  '174圣诞老人': '221174',
#  '174礼物': '66225',
#  '174结果': '87859',
#  '175人情': '271873',
#  '175人文主义': '276382',
#  '175摄影家': '23811',
#  '175罗贝尔·杜瓦诺': '219549',
#  '177外来媳妇本地郎': '216588',
#  '177上当': '96710',
#  '177广州': '189161',
#  '177山寨': '77655',
#  '178男子': '249107',
#  '178高速': '392329',
#  '178移动': '296495',
#  '178铜钱': '219112',
#  '179菜刀': '364358',
#  '179大家': '351372',
#  '180朱元璋传': '46719',
#  '180吴晗': '21742',
#  '180简介': '269667',
#  '180书评': '23971',
#  '181王俊凯': '162176',
#  '181日常': '185689',
#  '181花絮': '124757',
#  '181日本': '364373',
#  '181阳光': '186377',
#  '181模样': '130574',
#  '183图片': '381220',
#  '183文人': '314706',
#  '183紫砂': '29116',
#  '183巅峰': '240476',
#  '183顾景舟': '11747',
#  '183石瓢': '167293',
#  '184女子': '350862',
#  '184垃圾桶': '59943',
#  '184狗狗': '179570',
#  '184帅气': '202034',
#  '185男女': '235632',
#  '185友谊': '140594',
#  '186主人': '225125',
#  '187赵丽颖': '258739',
#  '187金星': '236766',
#  '187不可思议': '185337',
#  '189美少女': '241191',
#  '189火': '49014',
#  '189发型': '134309',
#  '189高贵': '56516',
#  '189气质': '60399',
#  '190简介': '269667',
#  '191福原爱': '407447',
#  '191邀请': '33287',
#  '191大s': '119580',
#  '191晚餐': '129191',
#  '192中国制造': '75494',
#  '192制造': '101373',
#  '192车': '163212',
#  '192欧美': '287693',
#  '192买': '177563',
#  '192中国': '199071',
#  '192订单': '232484',
#  '192手软': '394143',
#  '193安迪·博加德': '147744',
#  '193国外': '215326',
#  '193二次元': '27753',
#  '193男神': '16244',
#  '194公交车': '137751',
#  '195父母': '123805',
#  '195女儿': '232603',
#  '195公主': '184577',
#  '195结果': '87859',
#  '196天津': '209470',
#  '196曝光': '45313',
#  '196天津港': '52802',
#  '196口岸': '220127',
#  '196违法': '376947',
#  '196企业': '199991',
#  '197推荐': '33133',
#  '197大家': '351372',
#  '197下载': '381296',
#  '197qq飞车': '237855',
#  '197手游': '236191',
#  '198作者': '402535',
#  '199逃亡兔': '395433',
#  '200现代': '235594',
#  '200疯狂': '280537',
#  '200追求': '22642',
#  '200凤九': '373933',
#  '200程咬金': '383069',
#  '200尴尬': '68501',
#  '201人民币': '164998',
#  '201银行': '293677',
#  '201结果': '87859',
#  '201肯定': '389929',
#  '202同学两亿岁': '81675',
#  '203钱': '391531',
#  '204福清': '345985',
#  '204兄弟挺你': '156228',
#  '205露娜': '35148',
#  '205极限': '146316',
#  '206现场': '150318',
#  '206说法': '173609',
#  '206室友': '11978',
#  '207嗨小冷': '348187',
#  '208解晓东': '405798',
#  '209电影': '148097',
#  '209美国': '396835',
#  '209恐怖片': '49430',
#  '209恐怖列车': '209383',
#  '211妈妈': '251471',
#  '211供应': '33459',
#  '211女儿': '232603',
#  '211嫌弃': '15507',
#  '211主持人': '258046',
#  '212山': '245346',
#  '212水': '276050',
#  '212灵气': '34303',
#  '212风水': '299586',
#  '214王祖蓝': '17548',
#  '214分享': '10737',
#  '214营养': '85433',
#  '214早餐': '355674',
#  '214粉丝': '168919',
#  '214担心': '159137',
#  '214发际线': '355935',
#  '215扶摇': '300571',
#  '215无极': '78914',
#  '215女人': '279276',
#  '216保持': '265142',
#  '216目标': '82596',
#  '216女性': '319731',
#  '216卫生巾': '173967',
#  '216技巧': '400440',
#  '216发现': '408248',
#  '217美国电影': '239429',
#  '217电影': '148097',
#  '217小喽啰': '333888',
#  '217正片': '323873',
#  '217车震': '376972',
#  '217优酷网': '202883',
#  '217视频': '150546',
#  '219任达华': '73489',
#  '219现场': '150318',
#  '219鲁豫': '365334',
#  '219嘴': '30062',
#  '219刀片': '169031',
#  '219前辈': '396131',
#  '220书记': '341992',
#  '220传奇': '291674',
#  '221自古': '397657',
#  '221英雄': '77320',
#  '221少年': '263248',
#  '221搞怪': '102091',
#  '222火影忍者': '255245',
#  '222奥义': '164935',
#  '223韩国': '129281',
#  '223歌曲': '35295',
#  '223给你看': '248638',
#  '223中文': '13267',
#  '224生化危机6': '305560',
#  '225国家': '226535',
#  '225西兰公国': '132177',
#  '225生活': '134933',
#  '226垃圾': '213603',
#  '226中关村': '89110',
#  '227张嘉译': '115705',
#  '227靳东': '150257',
#  '227男神': '16244',
#  '227出现': '89780',
#  '228车继铃': '66197',
#  '228最远的你是我最近的爱': '78071',
#  '229电影': '148097',
#  '229主题曲': '140111',
#  '229造型': '200252',
#  '230句子': '387193',
#  '230经典语录': '287030',
#  '230名言': '330338',
#  '230句集': '48518',
#  '231阿娇': '322627',
#  '231闺蜜': '383076',
#  '231打卡': '73088',
#  '231婚礼': '90942',
#  '231行踪': '12389',
#  '232李钟硕': '140717',
#  '232来到我身边': '114802',
#  '232歌词': '237619',
#  '233笛子': '299562',
#  '233旋律': '73705',
#  '234草地': '177850',
#  '234玩耍': '316939',
#  '234可爱': '29057',
#  '235制作': '303147',
#  '235秘籍': '393969',
#  '235完美': '85692',
#  '235搭配': '308954',
#  '236黄志华': '85958',
#  '236林夕': '92426',
#  '236两杯茶': '355393',
#  '237手指': '223475',
#  '237刺': '16473',
#  '237消失': '160730',
#  '238女神': '183384',
#  '238大幂幂': '293827',
#  '238点名': '76513',
#  '238代言': '391475',
#  '239爱在前方': '41852',
#  '239电影': '148097',
#  '239大陆': '392547',
#  '239爱情': '57068',
#  '240儿子': '138796',
#  '240孩子': '148142',
#  '240平安': '344491',
#  '240出生': '293644',
#  '240孕妇': '336584',
#  '240离开': '261965',
#  '241仁王': '393052',
#  '241丰臣秀赖': '394914',
#  '242上海': '88418',
#  '242留学生': '55485',
#  '243世界杯': '235364',
#  '243欣赏': '162928',
#  '243梅西': '221802',
#  '244韩国人': '225161',
#  '244泡面': '247718',
#  '244害怕': '125631',
#  '244知识': '34073',
#  '245太平洋': '52965',
#  '245大西洋': '314427',
#  '245融合': '214232',
#  '245今天': '214121',
#  '245知道': '234421',
#  '246身体': '42408',
#  '246卫慧': '326025',
#  '247张世豪': '114934',
#  '247兄弟': '354592',
#  '247大哥': '186645',
#  '248晋江文学城': '153165',
#  '248网文': '21699',
#  '248帝王攻略': '370893',
#  '248动画': '85224',
#  '249拳皇': '371536',
#  '249暴走八神': '269558',
#  '250赵丽颖': '258739',
#  '250张含韵': '131769',
#  '250包子': '364692',
#  '250谢娜': '194342',
#  '251林海雪原': '327945',
#  '251侯殿坤': '294697',
#  '251叛徒': '37917',
#  '252视频': '150546',
#  '252天气预报': '255964',
#  '253手套': '323810',
#  '253手机': '393327',
#  '253华为': '391678',
#  '253模式': '177915',
#  '253意外': '171286',
#  '253惊喜': '39392',
#  '254老爷': '335289',
#  '254反派': '87365',
#  '255马塞尔·杜桑': '26506',
#  '255美术': '176893',
#  '255百科': '46687',
#  '256张歆艺': '361147',
#  '256自曝': '392856',
#  '256袁弘': '358368',
#  '256父母': '123805',
#  '256睡觉': '102579',
#  '256锅': '292274',
#  '258苹果': '335086',
#  '259胡一菲': '405637',
#  '259参加': '135992',
#  '259综艺节目': '185158',
#  '259模仿': '77009',
#  '259电话': '268869',
#  '259对方': '195626',
#  '259回答': '17179',
#  '260日常': '185689',
#  '260视频': '150546',
#  '260小姐姐': '130208',
#  '261饭': '100459',
#  '261含': '156725',
#  '261学霸': '12847',
#  '261安迪': '146270',
#  '262父亲': '377053',
#  '263资料': '153973',
#  '263话剧': '60991',
#  '263主创': '90847',
#  '264图': '167552',
#  '264猜': '131431',
#  '264成语': '191243',
#  '264字': '330967',
#  '265佟丽娅': '97759',
#  '265男友': '217237',
#  '265小三': '407582',
#  '266电影': '148097',
#  '266谁说大象不能跳舞': '277514',
#  '266预告片': '224395',
#  '267胡彦斌': '131394',
#  '268金高恩': '185208',
#  '268剧照': '337237',
#  '268短发': '66774',
#  '268小子': '250917',
#  '269小白龙': '283141',
#  '269脱身': '232340',
#  '270亚当': '351067',
#  '270夏娃': '373688',
#  '270游戏': '23513',
#  '271电视': '381664',
#  '271歌仔戏': '177968',
#  '271薛丁山与樊梨花': '180478',
#  '271视频': '150546',
#  '271戏曲': '336530',
#  '272美女': '336595',
#  '272导致': '310512',
#  '272迟到': '116209',
#  '272男子': '249107',
#  '272无情': '238465',
#  '272排练室': '19455',
#  '273杨钰莹': '353877',
#  '273歌曲': '35295',
#  '273一片艳阳天': '352489',
#  '274沈阳': '68507',
#  '274高峰期': '276750',
#  '274危险': '286425',
#  '274首位': '337684',
#  '275流浪': '380753',
#  '275孤儿': '349986',
#  '277歌词': '237619',
#  '277手机': '393327',
#  '279撒娇': '204472',
#  '279金钟国': '340318',
#  '279宋智孝': '79214',
#  '280赵本山': '272727',
#  '280沈阳': '68507',
#  '281刘德华': '199676',
#  '281错的都是我': '309851',
#  '281音乐': '130934',
#  '282国外': '215326',
#  '282吃播': '144689',
#  '282阿姨': '350317',
#  '282沙拉': '196370',
#  '282蔬菜': '313848',
#  '283孙红雷': '142956',
#  '283美女': '336595',
#  '283吃饭': '218010',
#  '283女友': '51536',
#  '283发现': '408248',
#  '283后果': '351058',
#  '284央视': '37295',
#  '284纪录片': '195304',
#  '284最后的猎手': '353841',
#  '284国语': '128390',
#  '285孙涛': '187704',
#  '285媳妇': '135443',
#  '285化妆': '204030',
#  '285套路': '134399',
#  '285邵峰': '368753',
#  '285嘴': '30062',
#  '286煤气罐': '369952',
#  '287法制': '312547',
#  '287教育': '160301',
#  '287电影': '148097',
#  '287优酷网': '202883',
#  '287视频': '150546',
#  '288秦天宇': '300731',
#  '288治愈系': '179829',
#  '289交警': '156332',
#  '289帮助': '389029',
#  '289老人': '377648',
#  '289马路': '396529',
#  '289点赞': '287400',
#  '290鸡毛飞上天': '285728',
#  '290陈江河': '48387',
#  '291正宗': '250193',
#  '291详细': '407211',
#  '291做法': '158029',
#  '292铁木真': '179032',
#  '292郭靖': '352518',
#  '292一箭双雕': '80040',
#  '293香港': '320750',
#  '293女星': '209950',
#  '293颜值': '338974',
#  '293巅峰': '240476',
#  '293美': '224434',
#  '293时代': '273030',
#  '293象征': '132528',
#  '294神奇动物在哪里': '266337',
#  '295恐龙快打': '334568',
#  '295围攻': '232046',
#  '295游戏': '23513',
#  '296张杰': '389757',
#  '296节目': '291480',
#  '296照顾': '290730',
#  '296小孩': '197283',
#  '297皇帝': '120605',
#  '297喜欢': '71175',
#  '297反抗': '173218',
#  '297女人': '279276',
#  '298易视云': '63428',
#  '298官网': '189944',
#  '299日本': '364373',
#  '299历史': '111044',
#  '300当年': '353020',
#  '300琼瑶剧': '29450',
#  '300时光': '382729',
#  '301采薇': '104881',
#  '301诗经': '96870',
#  '301诗': '213227',
#  '301先秦': '108012',
#  '301诗人': '211232',
#  '302戚薇': '160371',
#  '302冰箱': '173117',
#  '302香水': '203578',
#  '302知道': '234421',
#  '302价格': '158903',
#  '303世界': '368793',
#  '303勒鲁瓦': '361719',
#  '303铁血网': '362106',
#  '305王志毅': '346396',
#  '305个人主页': '43362',
#  '306世界': '368793',
#  '306水母': '281125',
#  '306触手': '296355',
#  '306杀死': '121181',
#  '307冷库运行管理与维修': '160590',
#  '307简介': '269667',
#  '307书评': '23971',
#  '308电影': '148097',
#  '308主题曲': '140111',
#  '310室内设计': '365011',
#  '310教程': '147300',
#  '310高级': '235692',
#  '310实木地板': '20133',
#  '310应用': '113650',
#  '310分类': '149430',
#  '311爱寻迷': '294369',
#  '311当代': '331887',
#  '311都市': '100127',
#  '311欲望': '95126',
#  '311娱乐': '371752',
#  '312男子': '249107',
#  '312自动': '308759',
#  '312商家': '72804',
#  '312太阳': '343770',
#  '313怪兽': '146283',
#  '313对象': '342417',
#  '313赛罗': '173709',
#  '314猜心': '101906',
#  '315银行': '293677',
#  '315柜台': '215820',
#  '315排队': '241436',
#  ...}

# %%
for item in test_data:
    # if item['kb_id']=='nil':continue
    item['text_id']=str(item['text_id'])
    item['text']=text_idto_text[item['text_id']]
    for m in item['mention_data']:
        try:
            m['kb_id']=kbid_finder[str(item['text_id'])+m['mention']]
        except:
            #print(item,m)
            m['kb_id'] = 'NIL' # 去掉某些ner
        m['mention'] = item['text'][int(m['offset']):int(m['offset'])+len(m['mention'])]
submit_data = test_data

# %%
new_submit = []
for item in submit_data:
    new_item = {}
    new_item['text_id'] = item['text_id']
    new_item['text'] = item['text']
    new_item['mention_data'] = []
    for m in item['mention_data']:
        if m['kb_id']=='NIL':continue
        new_item['mention_data'].append(m)
    new_submit.append(new_item)

# %%
import json
with open('submit/result_9.json', 'w') as f:
    for line in new_submit:
        json.dump(line,f,ensure_ascii=False)
        f.write('\n')

# %%
data[['text_id','kb_id','train_mention','label_mean','label_count','m_label_mean',
                                 'm_label_count','link_grade']]
# Out:
#        text_id   kb_id train_mention  label_mean  label_count  m_label_mean  \
# 0            1   43362          个人主页    0.992701        137.0      0.992701
# 1            2  101382          野蛮女友         NaN          NaN           NaN
# 2            2  104143          野蛮女友         NaN          NaN           NaN
# 3            2  107628          野蛮女友         NaN          NaN           NaN
# 4            2  137924          野蛮女友    0.000000          4.0           NaN
# 5            2   13889          野蛮女友         NaN          NaN           NaN
# 6            2   16345          野蛮女友         NaN          NaN           NaN
# 7            2  260196          野蛮女友         NaN          NaN           NaN
# 8            2  327016          野蛮女友         NaN          NaN           NaN
# 9            2   71447          野蛮女友    0.750000          4.0           NaN
# 10           2  152760            人物    0.795380        303.0      0.795380
# 11           2  222547            人物    0.000000        303.0      0.000000
# 12           2  283650            人物    0.191419        303.0      0.191419
# 13           2  315478            人物    0.000000        303.0      0.000000
# 14           2  328122            人物    0.000000        331.0      0.000000
# 15           2  388116            人物    0.000000        514.0      0.000000
# 16           2  389684            人物    0.000000        303.0      0.000000
# 17           2   67464            人物    0.009901        303.0      0.009901
# 18           2  103704            故事    0.000000        413.0      0.000000
# 19           2  108128            故事    0.000000        413.0      0.000000
# 20           2  124637            故事    0.000000        413.0      0.000000
# 21           2  125373            故事    0.000000        413.0      0.000000
# 22           2  126283            故事    0.000000        413.0      0.000000
# 23           2  150407            故事    0.000000        413.0      0.000000
# 24           2   15656            故事    0.000000        413.0      0.000000
# 25           2  172137            故事    0.000000        413.0      0.000000
# 26           2   18215            故事    0.002421        413.0      0.002421
# 27           2  187223            故事    0.000000        413.0      0.000000
# 28           2  217681            故事    0.067797        413.0      0.067797
# 29           2  228892            故事    0.000000        413.0      0.000000
# ...        ...     ...           ...         ...          ...           ...
# 764187   29999  277398            戏子    0.000000          2.0      0.000000
# 764188   29999  278407            戏子    0.000000          2.0      0.000000
# 764189   29999  282265            戏子    0.000000          2.0      0.000000
# 764190   29999  304450            戏子    0.000000          2.0      0.000000
# 764191   29999  306690            戏子    0.000000          2.0      0.000000
# 764192   29999   31522            戏子    0.000000          2.0      0.000000
# 764193   29999  394766            戏子    1.000000          2.0      1.000000
# 764194   30000  101616            表白    0.000000         10.0      0.000000
# 764195   30000  119994            表白    0.000000         10.0      0.000000
# 764196   30000  133206            表白    0.000000         10.0      0.000000
# 764197   30000  146644            表白    1.000000         10.0      1.000000
# 764198   30000  171511            表白    0.000000         10.0      0.000000
# 764199   30000  208077            表白    0.000000         10.0      0.000000
# 764200   30000  221194            表白    0.000000         10.0      0.000000
# 764201   30000  238795            表白    0.000000         10.0      0.000000
# 764202   30000   24219            表白    0.000000         10.0      0.000000
# 764203   30000  246175            表白    0.000000         10.0      0.000000
# 764204   30000  251479            表白    0.000000         10.0      0.000000
# 764205   30000  251753            表白    0.000000         10.0      0.000000
# 764206   30000  265934            表白    0.000000         10.0      0.000000
# 764207   30000  266801            表白    0.000000         10.0      0.000000
# 764208   30000  306532            表白    0.000000         10.0      0.000000
# 764209   30000  379426            表白    0.000000         10.0      0.000000
# 764210   30000  380378            表白    0.000000         10.0      0.000000
# 764211   30000   40320            表白    0.000000         10.0      0.000000
# 764212   30000   47249            表白    0.000000         10.0      0.000000
# 764213   30000   68401            表白    0.000000         10.0      0.000000
# 764214   30000   89000            表白    0.000000         20.0      0.000000
# 764215   30000   91388            表白    0.000000         10.0      0.000000
# 764216   30000  169331            待遇    1.000000          7.0      1.000000
#
#         m_label_count  link_grade
# 0               137.0    0.996788
# 1                 NaN    0.003224
# 2                 NaN    0.000347
# 3                 NaN    0.002200
# 4                 NaN    0.043198
# 5                 NaN    0.010164
# 6                 NaN    0.002753
# 7                 NaN    0.002346
# 8                 NaN    0.032471
# 9                 NaN    0.763314
# 10              303.0    0.815858
# 11              303.0    0.000366
# 12              303.0    0.188728
# 13              303.0    0.000089
# 14              303.0    0.000047
# 15              303.0    0.000053
# 16              303.0    0.000538
# 17              303.0    0.004517
# 18              413.0    0.000006
# 19              413.0    0.000007
# 20              413.0    0.000005
# 21              413.0    0.000026
# 22              413.0    0.000007
# 23              413.0    0.000008
# 24              413.0    0.000007
# 25              413.0    0.000069
# 26              413.0    0.000252
# 27              413.0    0.000009
# 28              413.0    0.048283
# 29              413.0    0.000109
# ...               ...         ...
# 764187            2.0    0.017163
# 764188            2.0    0.001170
# 764189            2.0    0.000105
# 764190            2.0    0.003159
# 764191            2.0    0.000724
# 764192            2.0    0.001481
# 764193            2.0    0.959790
# 764194           10.0    0.000008
# 764195           10.0    0.000008
# 764196           10.0    0.000048
# 764197           10.0    0.995976
# 764198           10.0    0.000179
# 764199           10.0    0.000126
# 764200           10.0    0.000007
# 764201           10.0    0.000070
# 764202           10.0    0.000184
# 764203           10.0    0.000288
# 764204           10.0    0.000007
# 764205           10.0    0.000063
# 764206           10.0    0.000011
# 764207           10.0    0.000017
# 764208           10.0    0.000165
# 764209           10.0    0.000013
# 764210           10.0    0.000008
# 764211           10.0    0.000032
# 764212           10.0    0.000013
# 764213           10.0    0.000007
# 764214           10.0    0.001515
# 764215           10.0    0.000206
# 764216            7.0    0.998416
#
# [764217 rows x 8 columns]

# %%
data[['text_id','kb_id','train_mention','label_mean','label_count','m_label_mean',
                                 'm_label_count','link_grade']]
# Out:
#        text_id   kb_id train_mention  label_mean  label_count  m_label_mean  \
# 0            1   43362          个人主页    0.992701        137.0      0.992701
# 1            2  101382          野蛮女友         NaN          NaN           NaN
# 2            2  104143          野蛮女友         NaN          NaN           NaN
# 3            2  107628          野蛮女友         NaN          NaN           NaN
# 4            2  137924          野蛮女友    0.000000          4.0           NaN
# 5            2   13889          野蛮女友         NaN          NaN           NaN
# 6            2   16345          野蛮女友         NaN          NaN           NaN
# 7            2  260196          野蛮女友         NaN          NaN           NaN
# 8            2  327016          野蛮女友         NaN          NaN           NaN
# 9            2   71447          野蛮女友    0.750000          4.0           NaN
# 10           2  152760            人物    0.795380        303.0      0.795380
# 11           2  222547            人物    0.000000        303.0      0.000000
# 12           2  283650            人物    0.191419        303.0      0.191419
# 13           2  315478            人物    0.000000        303.0      0.000000
# 14           2  328122            人物    0.000000        331.0      0.000000
# 15           2  388116            人物    0.000000        514.0      0.000000
# 16           2  389684            人物    0.000000        303.0      0.000000
# 17           2   67464            人物    0.009901        303.0      0.009901
# 18           2  103704            故事    0.000000        413.0      0.000000
# 19           2  108128            故事    0.000000        413.0      0.000000
# 20           2  124637            故事    0.000000        413.0      0.000000
# 21           2  125373            故事    0.000000        413.0      0.000000
# 22           2  126283            故事    0.000000        413.0      0.000000
# 23           2  150407            故事    0.000000        413.0      0.000000
# 24           2   15656            故事    0.000000        413.0      0.000000
# 25           2  172137            故事    0.000000        413.0      0.000000
# 26           2   18215            故事    0.002421        413.0      0.002421
# 27           2  187223            故事    0.000000        413.0      0.000000
# 28           2  217681            故事    0.067797        413.0      0.067797
# 29           2  228892            故事    0.000000        413.0      0.000000
# ...        ...     ...           ...         ...          ...           ...
# 764187   29999  277398            戏子    0.000000          2.0      0.000000
# 764188   29999  278407            戏子    0.000000          2.0      0.000000
# 764189   29999  282265            戏子    0.000000          2.0      0.000000
# 764190   29999  304450            戏子    0.000000          2.0      0.000000
# 764191   29999  306690            戏子    0.000000          2.0      0.000000
# 764192   29999   31522            戏子    0.000000          2.0      0.000000
# 764193   29999  394766            戏子    1.000000          2.0      1.000000
# 764194   30000  101616            表白    0.000000         10.0      0.000000
# 764195   30000  119994            表白    0.000000         10.0      0.000000
# 764196   30000  133206            表白    0.000000         10.0      0.000000
# 764197   30000  146644            表白    1.000000         10.0      1.000000
# 764198   30000  171511            表白    0.000000         10.0      0.000000
# 764199   30000  208077            表白    0.000000         10.0      0.000000
# 764200   30000  221194            表白    0.000000         10.0      0.000000
# 764201   30000  238795            表白    0.000000         10.0      0.000000
# 764202   30000   24219            表白    0.000000         10.0      0.000000
# 764203   30000  246175            表白    0.000000         10.0      0.000000
# 764204   30000  251479            表白    0.000000         10.0      0.000000
# 764205   30000  251753            表白    0.000000         10.0      0.000000
# 764206   30000  265934            表白    0.000000         10.0      0.000000
# 764207   30000  266801            表白    0.000000         10.0      0.000000
# 764208   30000  306532            表白    0.000000         10.0      0.000000
# 764209   30000  379426            表白    0.000000         10.0      0.000000
# 764210   30000  380378            表白    0.000000         10.0      0.000000
# 764211   30000   40320            表白    0.000000         10.0      0.000000
# 764212   30000   47249            表白    0.000000         10.0      0.000000
# 764213   30000   68401            表白    0.000000         10.0      0.000000
# 764214   30000   89000            表白    0.000000         20.0      0.000000
# 764215   30000   91388            表白    0.000000         10.0      0.000000
# 764216   30000  169331            待遇    1.000000          7.0      1.000000
#
#         m_label_count  link_grade
# 0               137.0    0.994676
# 1                 NaN    0.008357
# 2                 NaN    0.001035
# 3                 NaN    0.016172
# 4                 NaN    0.116071
# 5                 NaN    0.011626
# 6                 NaN    0.012276
# 7                 NaN    0.007368
# 8                 NaN    0.008997
# 9                 NaN    0.603381
# 10              303.0    0.805947
# 11              303.0    0.000153
# 12              303.0    0.160872
# 13              303.0    0.000090
# 14              303.0    0.000055
# 15              303.0    0.000149
# 16              303.0    0.000281
# 17              303.0    0.002926
# 18              413.0    0.000002
# 19              413.0    0.000010
# 20              413.0    0.000003
# 21              413.0    0.000041
# 22              413.0    0.000002
# 23              413.0    0.000008
# 24              413.0    0.000003
# 25              413.0    0.000052
# 26              413.0    0.000477
# 27              413.0    0.000006
# 28              413.0    0.051379
# 29              413.0    0.000032
# ...               ...         ...
# 764187            2.0    0.017955
# 764188            2.0    0.004753
# 764189            2.0    0.000222
# 764190            2.0    0.033790
# 764191            2.0    0.000344
# 764192            2.0    0.000406
# 764193            2.0    0.639922
# 764194           10.0    0.000018
# 764195           10.0    0.000017
# 764196           10.0    0.000084
# 764197           10.0    0.993456
# 764198           10.0    0.000051
# 764199           10.0    0.000386
# 764200           10.0    0.000014
# 764201           10.0    0.000175
# 764202           10.0    0.000293
# 764203           10.0    0.000125
# 764204           10.0    0.000035
# 764205           10.0    0.000172
# 764206           10.0    0.000017
# 764207           10.0    0.000081
# 764208           10.0    0.000168
# 764209           10.0    0.000047
# 764210           10.0    0.000027
# 764211           10.0    0.000122
# 764212           10.0    0.000019
# 764213           10.0    0.000020
# 764214           10.0    0.001327
# 764215           10.0    0.000249
# 764216            7.0    0.997059
#
# [764217 rows x 8 columns]
