# %%
# coding:u8
import pandas as pd
import numpy as np
import copy,gc
import lightgbm as lgb
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import f1_score,classification_report
import matplotlib.pyplot as plt
from tqdm import tqdm as tqdm
import seaborn as sns

# %%
data = pd.read_pickle('features/1_stat_feature.pkl')

# %%
predictor = [ 'num_attrs',
       'num_abstract_words', 'num_alias', 'num_candidates',
       'mention_equal_subject', 'shuminghao', 'entity_common', 'len_mention',
       'mention_start', 'cos_distance', 'mse_distance',
       'type_label_mean', 'type_label_count', 'label_mean', 'label_count',
       'm_label_mean', 'm_label_count', 'rank_num_attrs',
       'rank_num_abstract_words', 'rank_num_alias', 'rank_label_mean',
       'rank_label_count', 'rank_m_label_mean', 'rank_m_label_count',
       'rank_num_candidates', 'rank_mention_equal_subject', 'rank_shuminghao',
       'rank_entity_common', 'rank_type_label_mean', 'rank_cos_distance',
       'rank_mse_distance', 'num_attrs_var', 'num_attrs_mean', 'num_attrs_max',
       'num_abstract_words_var', 'num_abstract_words_mean',
       'num_abstract_words_max', 'num_alias_var', 'num_alias_mean',
       'num_alias_max', 'label_mean_var', 'label_mean_mean', 'label_mean_max',
       'label_count_var', 'label_count_mean', 'label_count_max',
       'm_label_mean_var', 'm_label_mean_mean', 'm_label_mean_max',
       'm_label_count_var', 'm_label_count_mean', 'm_label_count_max',
       'num_candidates_var', 'num_candidates_mean', 'num_candidates_max',
       'mention_equal_subject_var', 'mention_equal_subject_mean',
       'mention_equal_subject_max', 'shuminghao_var', 'shuminghao_mean',
       'shuminghao_max', 'entity_common_var', 'entity_common_mean',
       'entity_common_max', 'cos_distance_var', 'cos_distance_mean',
       'cos_distance_max', 'mse_distance_var', 'mse_distance_mean',
       'mse_distance_max', 'type_label_mean_var', 'type_label_mean_mean',
       'type_label_mean_max']
exclude = []
# exclude = []
temp = []
for x in predictor:
    if x not in exclude:temp.append(x)
predictor2 = temp

# %%
param = {
    #'num_leaves':100,
    'objective':'binary',
    'metric':'binary_logloss',
    'metric_freq':20,
    'learning_rate': 0.05,
    'num_threads':6,
    #'min_sum_hessian_in_leaf':10,
    'boosting_type':'gbdt',
    'subsample':0.9,
    #'xgboost_dart_mode':True,
    'colsample_bytree':0.8,
    'n_estimators':2000,
    'min_child_weight':2,
    'subsample_freq':2,
    'num_leaves':64,
    'n_jobs':-1,
}
train = lgb.Dataset(data[predictor2],label=data['label'])

bst = lgb.train(param, train)
# Out:
# /home/zhu/.local/lib/python3.6/site-packages/lightgbm/engine.py:118: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))

# %%
pred = bst.predict(data[predictor2])
data['pred'] = pred
span = list(np.linspace(0,1, 40))
scores = []
for i in span:
#     predict_y =  np.where(pred >= i, 1,0)
#     score = f1_score(val_data['label'], predict_y)
#     #print(i,score)
#     scores.append(score)
#     best_score = max(scores)
    n = i
    train_data_filter = data[data.pred>n]
    submit = train_data_filter.groupby('m_id',as_index=False)['pred'].agg({'label_id_max':'idxmax'})
    m = submit.shape[0]
    n = sum(data.groupby('m_id')['label'].sum())
    hit = data.loc[submit['label_id_max'],:]['label'].sum()
    print(m,n,hit)
    acc = hit/m
    recall = hit/n
    print(i,acc,recall,2*acc*recall/(acc+recall))
# 0.358974358974359 0.9101532161265269 0.9038036809815951 0.9069673356669188
# 0.3846153846153846 0.9066765421648503 0.9012094653812445 0.9039347375083512
# 0.41025641025641024 0.9124173245146149 0.8995267309377739 0.9059261743781665
# Out:
# 269361 257078 243312
# 0.0 0.9032933498167887 0.9464520495725033 0.9243692051690701
# 268479 257078 243310
# 0.02564102564102564 0.90625337549678 0.9464442698325022 0.9259128886115112
# 267969 257078 243307
# 0.05128205128205128 0.9079669663281946 0.9464326002225005 0.9268008387820519
# 267549 257078 243301
# 0.07692307692307693 0.9093698724345821 0.9464092610024973 0.92751993320969
# 267073 257078 243274
# 0.10256410256410256 0.9108895320754999 0.9463042345124826 0.9282592230101632
# 266535 257078 243245
# 0.1282051282051282 0.9126193558069297 0.9461914282824668 0.9291022186232962
# 265999 257078 243193
# 0.15384615384615385 0.9142628355745698 0.9459891550424385 0.9298554514918453
# 265327 257078 243096
# 0.1794871794871795 0.9162128241754515 0.9456118376523857 0.9306802193700291
# 264582 257078 242966
# 0.20512820512820512 0.918301320573584 0.9451061545523148 0.9315109458267837
# 263753 257078 242792
# 0.23076923076923075 0.9205279181658598 0.9444293171722201 0.9323254568180466
# 262794 257078 242531
# 0.2564102564102564 0.9228939777924915 0.9434140611020779 0.9330412101440354
# 261826 257078 242227
# 0.28205128205128205 0.9251449435884901 0.9422315406219124 0.9336100704561922
# 260775 257078 241860
# 0.3076923076923077 0.9274662064998562 0.9408039583317126 0.9340874726997818
# 259673 257078 241478
# 0.3333333333333333 0.9299311056598106 0.9393180279915045 0.934600997385588
# 258439 257078 240976
# 0.358974358974359 0.9324289290703028 0.9373653132512312 0.9348906049655006
# 257103 257078 240423
# 0.3846153846153846 0.9351232774413367 0.93521421514093 0.9351687440803919
# 255649 257078 239715
# 0.41025641025641024 0.9376723554561136 0.9324601871805445 0.9350590080101105
# 254056 257078 238913
# 0.4358974358974359 0.9403950310167837 0.9293405114401077 0.9348350921676115
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-f9d9aeedf225> in <module>
#      11     n = i
#      12     train_data_filter = data[data.pred>n]
# ---> 13     submit = train_data_filter.groupby('m_id',as_index=False)['pred'].agg({'label_id_max':'idxmax'})
#      14     m = submit.shape[0]
#      15     n = sum(data.groupby('m_id')['label'].sum())
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/groupby/generic.py in aggregate(self, arg, *args, **kwargs)
#    1313     @Appender(_shared_docs['aggregate'])
#    1314     def aggregate(self, arg, *args, **kwargs):
# -> 1315         return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#    1316
#    1317     agg = aggregate
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/groupby/generic.py in aggregate(self, arg, *args, **kwargs)
#     184
#     185         _level = kwargs.pop('_level', None)
# --> 186         result, how = self._aggregate(arg, _level=_level, *args, **kwargs)
#     187         if how is None:
#     188             return result
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/base.py in _aggregate(self, arg, *args, **kwargs)
#     479                 if len(sl) == 1:
#     480
# --> 481                     result = _agg(arg, lambda fname,
#     482                                   agg_how: _agg_1dim(self._selection, agg_how))
#     483
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/base.py in _agg(arg, func)
#     447                 result = compat.OrderedDict()
#     448                 for fname, agg_how in compat.iteritems(arg):
# --> 449                     result[fname] = func(fname, agg_how)
#     450                 return result
#     451
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/base.py in <lambda>(fname, agg_how)
#     480
#     481                     result = _agg(arg, lambda fname,
# --> 482                                   agg_how: _agg_1dim(self._selection, agg_how))
#     483
#     484                 # we are selecting the same set as we are aggregating
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/base.py in _agg_1dim(name, how, subset)
#     430                     raise SpecificationError("nested dictionary is ambiguous "
#     431                                              "in aggregation")
# --> 432                 return colg.aggregate(how, _level=(_level or 0) + 1)
#     433
#     434             def _agg_2dim(name, how):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/groupby/generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     758         _level = kwargs.pop('_level', None)
#     759         if isinstance(func_or_funcs, compat.string_types):
# --> 760             return getattr(self, func_or_funcs)(*args, **kwargs)
#     761
#     762         if isinstance(func_or_funcs, compat.Iterable):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/groupby/groupby.py in wrapper(*args, **kwargs)
#     604
#     605             try:
# --> 606                 return self.apply(curried_with_axis)
#     607             except Exception:
#     608                 try:
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/groupby/generic.py in apply(self, func, *args, **kwargs)
#     747                       examples=_apply_docs['series_examples']))
#     748     def apply(self, func, *args, **kwargs):
# --> 749         return super(SeriesGroupBy, self).apply(func, *args, **kwargs)
#     750
#     751     @Substitution(see_also=_agg_see_also_doc,
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     687         with option_context('mode.chained_assignment', None):
#     688             try:
# --> 689                 result = self._python_apply_general(f)
#     690             except Exception:
#     691
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f)
#     705     def _python_apply_general(self, f):
#     706         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 707                                                    self.axis)
#     708
#     709         return self._wrap_applied_output(
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/groupby/ops.py in apply(self, f, data, axis)
#     188             # group might be modified
#     189             group_axes = _get_axes(group)
# --> 190             res = f(group)
#     191             if not _is_indexed_like(res, group_axes):
#     192                 mutated = True
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/groupby/groupby.py in curried_with_axis(x)
#     589
#     590             def curried_with_axis(x):
# --> 591                 return f(x, *args, **kwargs_with_axis)
#     592
#     593             def curried(x):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py in idxmax(self, axis, skipna, *args, **kwargs)
#    1949         """
#    1950         skipna = nv.validate_argmax_with_skipna(skipna, args, kwargs)
# -> 1951         i = nanops.nanargmax(com.values_from_object(self), skipna=skipna)
#    1952         if i == -1:
#    1953             return np.nan
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      74             try:
#      75                 with np.errstate(invalid='ignore'):
# ---> 76                     return f(*args, **kwargs)
#      77             except ValueError as e:
#      78                 # we want to transform an object array
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/nanops.py in nanargmax(values, axis, skipna, mask)
#     777     """
#     778     values, mask, dtype, _, _ = _get_values(
# --> 779         values, skipna, fill_value_typ='-inf', mask=mask)
#     780     result = values.argmax(axis)
#     781     result = _maybe_arg_null_out(result, axis, mask, skipna)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/nanops.py in _get_values(values, skipna, fill_value, fill_value_typ, isfinite, copy, mask)
#     221             mask = _isfinite(values)
#     222         else:
# --> 223             mask = isna(values)
#     224
#     225     if is_datetime_or_timedelta_dtype(values) or is_datetime64tz_dtype(values):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/dtypes/missing.py in isna(obj)
#      97     Name: 1, dtype: bool
#      98     """
# ---> 99     return _isna(obj)
#     100
#     101
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/dtypes/missing.py in _isna_new(obj)
#     112                           ABCExtensionArray,
#     113                           ABCDatetimeArray, ABCTimedeltaArray)):
# --> 114         return _isna_ndarraylike(obj)
#     115     elif isinstance(obj, ABCGeneric):
#     116         return obj._constructor(obj._data.isna(func=isna))
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/dtypes/missing.py in _isna_ndarraylike(obj)
#     214             result[...] = vec.reshape(shape)
#     215
# --> 216     elif needs_i8_conversion(dtype):
#     217         # this is the NaT pattern
#     218         result = values.view('i8') == iNaT
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/dtypes/common.py in needs_i8_conversion(arr_or_dtype)
#    1467     return (is_datetime_or_timedelta_dtype(arr_or_dtype) or
#    1468             is_datetime64tz_dtype(arr_or_dtype) or
# -> 1469             is_period_dtype(arr_or_dtype))
#    1470
#    1471
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/dtypes/common.py in is_period_dtype(arr_or_dtype)
#     531     if arr_or_dtype is None:
#     532         return False
# --> 533     return PeriodDtype.is_dtype(arr_or_dtype)
#     534
#     535
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/dtypes/dtypes.py in is_dtype(cls, dtype)
#     845             else:
#     846                 return False
# --> 847         return super(PeriodDtype, cls).is_dtype(dtype)
#     848
#     849     @classmethod
#
# KeyboardInterrupt:

# %%
train_data_f = data[data.pred>0.4]
submit = train_data_f.groupby('m_id',as_index=False)['pred'].agg({'label_id_max':'idxmax'})
data['positive'] = 0
data.loc[submit['label_id_max'],'positive']=1

# %%
observe_item = ['text_id','kb_id','train_mention','num_candidates','label','label_mean','label_count','m_label_mean','m_label_count',
          'cos_distance','pred','positive']

# %%
data.shape
# Out:
# (1834968, 81)

# %%
data[(data.label==0)&(data.pred>0.9)][observe_item]
# Out:
#         text_id   kb_id train_mention  num_candidates  label  label_mean  \
# 966          52  158891            译文               1      0    0.732394
# 1002         54   55422          足球之恋               2      0         NaN
# 1900         90  262605      机械战警2014               1      0         NaN
# 3481        167   88418            上海              18      0    0.956790
# 5856        279  126309         快速问医生               1      0    1.000000
# 6538        320  384113           杨浩宇               1      0         NaN
# 7571        390  127070         让我帮助你               1      0         NaN
# 7619        393  220258            科幻               4      0    0.928571
# 8225        421  381261            全集               6      0    0.898930
# 10767       544  148097            电影              26      0    0.451187
# 11272       566  130934            音乐              17      0    0.286854
# 12409       612  152366          豆瓣阅读               1      0    1.000000
# 1900            1
# 3481            1
# 5856            1
# 6538            1
# 7571            1
# 7619            1
# 8225            1
# 10767           1
# 11272           1
# 12409           1
# 13160           1
# 13289           1
# 13626           1
# 15394           1
# 15648           1
# 16523           1
# 16542           1
# 16889           1
# 18168           1
# 21645           1
# 22849           1
# 25600           1
# 31789           1
# 34019           1
# 37276           1
# 37422           1
# 42582           1
# 45259           1
# ...           ...
# 1800986         1
# 1803933         1
# 1804714         1
# 1804872         1
# 1805480         1
# 1805520         1
# 1806436         1
# 1811348         1
# 1812569         1
# 1813417         1
# 1813564         1
# 1813858         1
# 1814016         1
# 1814454         1
# 1816094         1
# 1817406         1
# 1817429         1
# 1824012         1
# 1824603         1
# 1826172         1
# 1826261         1
# 1827641         1
# 1828807         1
# 1828878         1
# 1829338         1
# 1829956         1
# 1832643         1
# 1833793         1
# 1834354         1
# 1834479         1
#
# [1375 rows x 12 columns]

# %%
data[(data.label==1)&(data.pred>0.9)&(data.positive==0)][observe_item]
# Out:
# Empty DataFrame
# Columns: [text_id, kb_id, train_mention, num_candidates, label, label_mean, label_count, m_label_mean, m_label_count, cos_distance, pred, positive]
# Index: []

# %%
data[(data.label==1)&(data.pred<0.1)][observe_item]
# Out:
#         text_id   kb_id train_mention  num_candidates  label  label_mean  \
# 105          10  116223          少女时代               8      1    0.000000
# 1365         65   87699           赛尔号               8      1    0.100000
# 1618         77  383731            人间              28      1    0.071429
# 2401        111  344807           二进宫               5      1    0.000000
# 3284        149  357564           徐文远               4      1         NaN
# 3490        167  366890            上海              18      1    0.000000
# 3916        197   91488           黄文斌               5      1         NaN
# 5934        283  100910            压力               9      1    0.000000
# 6183        304   37885             祭               9      1    0.000000
# 6196        304  238546            戴涛               7      1    0.000000
# 6309        311   33125            东华               5      1    0.000000
# 6316        311  247153            凤九               4      1    0.076923
# 6420        315   24768         守护者联盟               8      1    0.000000
# 6610        325  226751           随它吧               4      1    0.000000
# 7618        393  293900            科幻               4      1    0.372727
# 8223        421   60617            全集               6      1    0.072289
# 8591        441   85414           王海滨              34      1         NaN
# 8837        456  104832            白眉              10      1         NaN
# 10044       504  154765          花容月貌               5      1    0.000000
# 11280       566   29763            音乐              17      1    0.001460
# 11303       567  380874            牧师              16      1    0.000000
# 13158       630   60617            全集               6      1    0.072289
# 13288       638  271228          原创小说               2      1    0.104638
# 13628       655  379027            南京              10      1    0.000000
# 13996       673   50238           完整版               3      1    0.097421
# 14886       719  407123            张超              97      1    0.000000
# 15981       771  249280            白冰              20      1    0.000000
# 16540       801  355820            攻略               5      1    0.031746
# 17746       874   59364         以爱的名义               6      1    0.000000
# 18004       880  107799          杏花天影               4      1    0.000000
# ...         ...     ...           ...             ...    ...         ...
# 1814868   88967  230636            老婆              27      1    0.000000
# 1814986   88971   30855           徐晓冬               4      1    0.000000
# 1816093   89038  261617            律动               3      1    0.000000
# 1816577   89063  389953             书               4      1    0.118421
# 1816756   89076   86679            沈雷               7      1         NaN
